# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from matplotlib import rc

rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
pip install numpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 21.8 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 15.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.5/503.5 kB 9.0 MB/s eta 0:00:0000:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 10.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 16.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 944.1/944.1 kB 14.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 2.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seabron
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 5.3 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 MB 11.6 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sklearn
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 11.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.0/307.0 kB 6.5 MB/s eta 0:00:00a 0:00:01
# ...
# Using legacy 'setup.py install' for sklearn, since package 'wheel' is not installed.
# ...
#   Running setup.py install for sklearn ... done
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
demo_df = pd.read_csv("LPOINT_BIG_COMP_01_DEMO.csv")
pdde_df = pd.read_csv("LPOINT_BIG_COMP_02_PDDE.csv")
cop_df = pd.read_csv("LPOINT_BIG_COMP_03_COP_U.csv")
pd_df = pd.read_csv("LPOINT_BIG_COMP_04_PD_CLAC.csv")
br_df = pd.read_csv("LPOINT_BIG_COMP_05_BR.csv")
lpay_df = pd.read_csv("LPOINT_BIG_COMP_06_LPAY.csv")
# Out:
# /var/folders/z_/ns3pdgbs27x7bmf6wgkkg19r0000gn/T/ipykernel_2967/4235936177.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   pdde_df = pd.read_csv("LPOINT_BIG_COMP_02_PDDE.csv")

# %%
demo_df
# Out:
#              cust ma_fem_dv ages zon_hlv
# 0      M000034966        여성  40대     Z07
# 1      M000059535        여성  30대     Z12
# 2      M000136117        여성  30대     Z11
# 3      M000201112        여성  50대     Z17
# 4      M000225114        여성  40대     Z17
# ...           ...       ...  ...     ...
# 29908  M999708287        여성  40대     Z10
# 29909  M999770689        여성  30대     Z16
# 29910  M999849895        여성  20대     Z04
# 29911  M999926092        남성  30대     Z08
# 29912  M999962961        여성  50대     Z17
#
# [29913 rows x 4 columns]

# %%
cus_join = pd.merge(demo_df,pdde_df, on="cust", how='inner')
cus_join
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 0        M000034966        여성  40대     Z07  A01016688590        1   A01
# 1        M000034966        여성  40대     Z07  A01016688590        1   A01
# 2        M000034966        여성  40대     Z07  A01016688590        1   A01
# 3        M000034966        여성  40대     Z07  A01016718167        1   A01
# 4        M000034966        여성  40대     Z07  A02357398521        1   A02
# ...             ...       ...  ...     ...           ...      ...   ...
# 4381738  M999962961        여성  50대     Z17  A05001012161        1   A05
# 4381739  M999962961        여성  50대     Z17  E06002810292        2   A06
# 4381740  M999962961        여성  50대     Z17  E06004609359        2   A06
# 4381741  M999962961        여성  50대     Z17  E06025413888        2   A06
# 4381742  M999962961        여성  50대     Z17  E06035713248        2   A06
#
#             br_c    pd_c     de_dt  de_hr    buy_am  buy_ct
# ...

# %%
cus_merge = pd.merge(cus_join,pd_df, on = "pd_c", how='inner' )
cus_merge
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 0        M000034966        여성  40대     Z07  A01016688590        1   A01
# 1        M000034966        여성  40대     Z07  A01016688590        1   A01
# 2        M000136117        여성  30대     Z11  A01294575336        1   A01
# 3        M000261625        여성  40대     Z17  A01117216600        1   A01
# 4        M000419293        여성  40대     Z17  A02041463489        1   A02
# ...             ...       ...  ...     ...           ...      ...   ...
# 4381738  M858719851        여성  60대     Z16  A05001516873        1   A05
# 4381739  M880029153        남성  40대     Z16  E06043468594        2   A06
# 4381740  M986268092        남성  40대     Z09  E06040602652        2   A06
# 4381741  M926014276        남성  40대     Z10  A02105319111        1   A02
# 4381742  M962869931        여성  20대     Z16  E06011348557        2   A06
#
#             br_c    pd_c     de_dt  de_hr    buy_am  buy_ct       pd_nm  \
# ...

# %%
display(len(cus_merge[cus_merge['cop_c'] =='A02']['rct_no'].unique())) # 롯데마트
display(len(cus_merge[cus_merge['cop_c'] =='A03']['rct_no'].unique())) # 롯데슈퍼
# Out:
# 380537
# 192540

# %%
cus_merge.sort_values(by ='buy_am', ascending=False).head(50)
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 4274047  M750310186        남성  40대     Z04  A01027046780        1   A01
# 4119623  M288629527        남성  60대     Z16  A01271693329        1   A01
# 4119624  M288629527        남성  60대     Z16  A01275514864        1   A01
# 635138   M621699711        남성  30대     Z17  A01482823454        1   A01
# 4119731  M724764678        여성  40대     Z01  A01359228680        1   A01
# 4376244  M724764678        여성  40대     Z01  A01361343160        1   A01
# 4273972  M612112783        남성  40대     Z17  A01453231391        1   A01
# 3793817  M055769504        남성  30대     Z10  A01335907881        1   A01
# 3794425  M262120746        여성  40대     Z17  A01045019347        1   A01
# 4141129  M473285301        남성  50대     Z10  A01339676065        1   A01
# 4273731  M319930340        여성  30대     Z17  A01189778223        1   A01
# 610964   M116720573        남성  40대     Z17  A01144030325        1   A01
# ...

# %%
cus_merge.sort_values(by ='buy_am', ascending=True).head(1000)
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 4138944  M752850719        여성  40대     Z10  E05000899028        2   A05
# 3265515  M197460925        여성  40대     Z12  A02271211155        1   A02
# 1069675  M339950075        여성  40대     Z04  A02131078718        1   A02
# 4138901  M567442895        여성  20대     Z10  E05000741965        2   A05
# 4138886  M504707751        여성  40대     Z09  E05000786398        2   A05
# ...             ...       ...  ...     ...           ...      ...   ...
# 1245888  M973746914        여성  30대     Z16  A04004731184        1   A04
# 1245891  M973746914        여성  30대     Z16  A04046504895        1   A04
# 1245892  M973746914        여성  30대     Z16  A04052198132        1   A04
# 1245893  M973746914        여성  30대     Z16  A04060572506        1   A04
# 1245894  M973746914        여성  30대     Z16  A04084110215        1   A04
#
#             br_c    pd_c     de_dt  de_hr  buy_am  buy_ct    pd_nm  \
# ...

# %%
plt.boxplot(cus_merge['buy_am'])
plt.show()
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %%
print(cus_merge['buy_am'].quantile(0.99))
print(cus_merge['buy_am'].quantile(0.01))
# Out:
# 294000.0
# 350.0

# %%
index_1 = cus_merge[ (cus_merge['buy_am']>= 40000000)  & ~(cus_merge['buy_am'] < 20 )].index

# %%
cus_merge.drop(index_1, axis=0, inplace=True)

# %%
cus_merge.sort_values(by ='buy_ct', ascending=False).head(50)
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 2079738  M282697479        여성  40대     Z04  A01217558938        1   A01
# 4101291  M906226236        남성  60대     Z16  E06048834572        2   A06
# 2807930  M103897322        여성  60대     Z11  A04096728782        1   A04
# 89503    M245283859        남성  30대     Z11  A02255408579        1   A02
# 89501    M245283859        남성  30대     Z11  A02254698310        1   A02
# 2079734  M282697479        여성  40대     Z04  A01135093413        1   A01
# 1973387  M220751128        여성  50대     Z10  A02184946295        1   A02
# 4240542  M035037103        남성  20대     Z04  A04012132701        1   A04
# 1065932  M768874888        여성  40대     Z16  E06006797437        2   A06
# 4372277  M838622742        남성  40대     Z14  A01033672436        1   A01
# 4103877  M745864268        남성  60대     Z16  A02246841871        1   A02
# 928244   M927998831        남성  30대     Z10  E06047735952        2   A06
# ...

# %%
plt.boxplot(cus_merge['buy_ct'])
plt.show()

# %%
print(cus_merge['buy_ct'].quantile(0.99))
print(cus_merge['buy_ct'].quantile(0.01))
# Out:
# 6.0
# 1.0

# %%
index_2 = cus_merge[ (cus_merge['buy_ct']> 80) ].index

# %%
cus_merge.drop(index_2 , axis=0, inplace=True)

# %%
cus_merge
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 0        M000034966        여성  40대     Z07  A01016688590        1   A01
# 1        M000034966        여성  40대     Z07  A01016688590        1   A01
# 2        M000136117        여성  30대     Z11  A01294575336        1   A01
# 3        M000261625        여성  40대     Z17  A01117216600        1   A01
# 4        M000419293        여성  40대     Z17  A02041463489        1   A02
# ...             ...       ...  ...     ...           ...      ...   ...
# 4381738  M858719851        여성  60대     Z16  A05001516873        1   A05
# 4381739  M880029153        남성  40대     Z16  E06043468594        2   A06
# 4381740  M986268092        남성  40대     Z09  E06040602652        2   A06
# 4381741  M926014276        남성  40대     Z10  A02105319111        1   A02
# 4381742  M962869931        여성  20대     Z16  E06011348557        2   A06
#
#             br_c    pd_c     de_dt  de_hr    buy_am  buy_ct       pd_nm  \
# ...

# %%
cus_merge['ages'] = cus_merge['ages'].apply(lambda x : int(x.rstrip('대')))

# %%
cus_merge1 = cus_merge.copy()

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder.fit(cus_merge['cust'])
cus_merge['cust'] = encoder.transform(cus_merge['cust'])

# %%
encoder = LabelEncoder()
encoder.fit(cus_merge['ma_fem_dv'])
cus_merge['ma_fem_dv'] = encoder.transform(cus_merge['ma_fem_dv'])

# %%
encoder = LabelEncoder()
encoder.fit(cus_merge['zon_hlv'])
cus_merge['zon_hlv'] = encoder.transform(cus_merge['zon_hlv'])

# %%
encoder = LabelEncoder()
encoder.fit(cus_merge['rct_no'])
cus_merge['rct_no'] = encoder.transform(cus_merge['rct_no'])

# %%
encoder = LabelEncoder()
encoder.fit(cus_merge['cop_c'])
cus_merge['cop_c'] = encoder.transform(cus_merge['cop_c'])

# %%
encoder = LabelEncoder()
encoder.fit(cus_merge['br_c'])
cus_merge['br_c'] = encoder.transform(cus_merge['br_c'])

# %%
encoder = LabelEncoder()
encoder.fit(cus_merge['pd_c'])
cus_merge['pd_c'] = encoder.transform(cus_merge['pd_c'])

# %%
encoder = LabelEncoder()
encoder.fit(cus_merge['pd_nm'])
cus_merge['pd_nm'] = encoder.transform(cus_merge['pd_nm'])

# %%
encoder = LabelEncoder()
encoder.fit(cus_merge['clac_hlv_nm'])
cus_merge['clac_hlv_nm'] = encoder.transform(cus_merge['clac_hlv_nm'])

# %%
encoder = LabelEncoder()
encoder.fit(cus_merge['clac_mcls_nm'])
cus_merge['clac_mcls_nm'] = encoder.transform(cus_merge['clac_mcls_nm'])

# %%
cus_merge
# Out:
#           cust  ma_fem_dv  ages  zon_hlv   rct_no  chnl_dv  cop_c  br_c  pd_c  \
# 0            0          1    40        6    16648        1      0    44   776
# 1            0          1    40        6    16648        1      0    44   776
# 2            1          1    30       10   294245        1      0    17   776
# 3            4          1    40       16   117091        1      0    16   776
# 4            6          1    40       16   543169        1      1    73   776
# ...        ...        ...   ...      ...      ...      ...    ...   ...   ...
# 4381738  23211          1    60       15  1165554        1      4  6386   994
# 4381739  23802          0    40       15  1257866        2      5  6755   916
# 4381740  26550          0    40        8  1255001        2      5  6755   916
# 4381741  25021          0    40        9   605562        1      1    88  1058
# 4381742  25970          1    20       15  1225757        2      5  6755   441
#
# ...

# %%
cus_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4381662 entries, 0 to 4381742
# Data columns (total 16 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   cust          int64
#  1   ma_fem_dv     int64
#  2   ages          int64
#  3   zon_hlv       int64
#  4   rct_no        int64
#  5   chnl_dv       int64
#  6   cop_c         int64
#  7   br_c          int64
#  8   pd_c          int64
#  9   de_dt         int64
#  10  de_hr         int64
#  11  buy_am        float64
#  12  buy_ct        int64
#  13  pd_nm         int64
#  14  clac_hlv_nm   int64
#  15  clac_mcls_nm  int64
# dtypes: float64(1), int64(15)
# memory usage: 568.3 MB

# %%
# cus_merge = cus_merge.apply(LabelEncoder().fit_transform)

# %%
cus_sex = cus_merge.loc[:,["cust","ma_fem_dv","pd_c","pd_nm","clac_hlv_nm","clac_mcls_nm",'buy_am','de_dt','de_hr','buy_ct']]
cus_sex
# Out:
#           cust  ma_fem_dv  pd_c  pd_nm  clac_hlv_nm  clac_mcls_nm    buy_am  \
# 0            0          1   776    336           28            55   59000.0
# 1            0          1   776    336           28            55   19000.0
# 2            1          1   776    336           28            55  239000.0
# 3            4          1   776    336           28            55  179000.0
# 4            6          1   776    336           28            55    3000.0
# ...        ...        ...   ...    ...          ...           ...       ...
# 4381738  23211          1   994    736           35           150  139000.0
# 4381739  23802          0   916    652           31           273  199000.0
# 4381740  26550          0   916    652           31           273  187050.0
# 4381741  25021          0  1058    762           37            89  800000.0
# 4381742  25970          1   441   1504           19           129   49500.0
#
#             de_dt  de_hr  buy_ct
# ...

# %%
cus_sex1 = cus_merge1.loc[:,["cust","ma_fem_dv","pd_c","pd_nm","clac_hlv_nm","clac_mcls_nm",'buy_am','de_dt','de_hr','buy_ct']]
cus_sex1
# Out:
#                cust ma_fem_dv    pd_c       pd_nm clac_hlv_nm clac_mcls_nm  \
# 0        M000034966        여성  PD0777  남성런닝/트레이닝화       스포츠패션       남성스포츠화
# 1        M000034966        여성  PD0777  남성런닝/트레이닝화       스포츠패션       남성스포츠화
# 2        M000136117        여성  PD0777  남성런닝/트레이닝화       스포츠패션       남성스포츠화
# 3        M000261625        여성  PD0777  남성런닝/트레이닝화       스포츠패션       남성스포츠화
# 4        M000419293        여성  PD0777  남성런닝/트레이닝화       스포츠패션       남성스포츠화
# ...             ...       ...     ...         ...         ...          ...
# 4381738  M858719851        여성  PD0995      보이스레코더     영상/음향가전      소형디지털가전
# 4381739  M880029153        남성  PD0917        미니벨로     아웃도어/레저          자전거
# 4381740  M986268092        남성  PD0917        미니벨로     아웃도어/레저          자전거
# 4381741  M926014276        남성  PD1059          분양       원예/애완         동물병원
# 4381742  M962869931        여성  PD0442         절단기     문구/사무용품         사무기기
#
#            buy_am     de_dt  de_hr  buy_ct
# ...

# %%
cus_age = cus_merge.loc[:,["cust","ages","pd_c","pd_nm","clac_hlv_nm","clac_mcls_nm",'buy_am','de_dt','de_hr','buy_ct']]

# %%
cus_age1 = cus_merge1.loc[:,["cust","ages","pd_c","pd_nm","clac_hlv_nm","clac_mcls_nm",'buy_am','de_dt','de_hr','buy_ct']]

# %%
cus_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4381662 entries, 0 to 4381742
# Data columns (total 10 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   cust          int64
#  1   ages          int64
#  2   pd_c          int64
#  3   pd_nm         int64
#  4   clac_hlv_nm   int64
#  5   clac_mcls_nm  int64
#  6   buy_am        float64
#  7   de_dt         int64
#  8   de_hr         int64
#  9   buy_ct        int64
# dtypes: float64(1), int64(9)
# memory usage: 367.7 MB

# %%
cus_on_off = cus_merge.loc[:,["cust","chnl_dv","pd_c","pd_nm","clac_hlv_nm","clac_mcls_nm",'buy_am','de_dt','de_hr','buy_ct']]

# %%
cus_on_off1 = cus_merge1.loc[:,["cust","chnl_dv","pd_c","pd_nm","clac_hlv_nm","clac_mcls_nm",'buy_am','de_dt','de_hr','buy_ct']]

# %%
cus_time = cus_merge.loc[:,["cust","pd_c","pd_nm","clac_hlv_nm","clac_mcls_nm",'buy_am','de_dt','de_hr','buy_ct']]

# %%
cus_time1 = cus_merge1.loc[:,["cust","pd_c","pd_nm","clac_hlv_nm","clac_mcls_nm",'buy_am','de_dt','de_hr','buy_ct']]

# %%
lpay_join = pd.merge(demo_df,lpay_df, on="cust", how='inner')
lpay_join
# Out:
#               cust ma_fem_dv ages zon_hlv           rct_no cop_c  chnl_dv  \
# 0       M000136117        여성  30대     Z11  210926220176038   D01        2
# 1       M000136117        여성  30대     Z11  211120000687692   A06        2
# 2       M000136117        여성  30대     Z11  210104110684235   A06        2
# 3       M000136117        여성  30대     Z11  210109140124587   A01        1
# 4       M000419293        여성  40대     Z17  211103140120216   D01        2
# ...            ...       ...  ...     ...              ...   ...      ...
# 353179  M999962961        여성  50대     Z17  210724200025828   L00        2
# 353180  M999962961        여성  50대     Z17  210214170187495   A01        1
# 353181  M999962961        여성  50대     Z17  210214180290789   C02        1
# 353182  M999962961        여성  50대     Z17  210113180665862   A06        2
# 353183  M999962961        여성  50대     Z17  210117130146991   A01        1
#
#            de_dt  de_hr   buy_am
# 0       20210926     22    15100
# ...

# %%
lpay_join['ages'] = lpay_join['ages'].apply(lambda x : int(x.rstrip('대')))

# %%
lpay_join1 = lpay_join.copy()

# %%
encoder = LabelEncoder()
encoder.fit(lpay_join['cust'])
lpay_join['cust'] = encoder.transform(lpay_join['cust'])

# %%
encoder = LabelEncoder()
encoder.fit(lpay_join['ma_fem_dv'])
lpay_join['ma_fem_dv'] = encoder.transform(lpay_join['ma_fem_dv'])

# %%
encoder = LabelEncoder()
encoder.fit(lpay_join['zon_hlv'])
lpay_join['zon_hlv'] = encoder.transform(lpay_join['zon_hlv'])

# %%
encoder = LabelEncoder()
encoder.fit(lpay_join['cop_c'])
lpay_join['cop_c'] = encoder.transform(lpay_join['cop_c'])

# %% [markdown]
# ## elbow

# %%
def elbow(data, length):
    sse = [] # sum of squre error 오차제곱합
    for i in range(1, length):
        kmeans = KMeans(n_clusters=i)
        kmeans.fit(data)
        # SSE 값 저장
        sse.append(kmeans.inertia_)
    plt.plot(range(1, length), sse, 'bo-')
    plt.title("elbow method")
    plt.xlabel("number of clusters")
    plt.ylabel("SSE")
    plt.show()

# %%
elbow(cus_merge,10)
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ## 실루엣

# %%
def visualize_silhouette(cluster_lists, X_features): 

    from sklearn.datasets import make_blobs
    from sklearn.cluster import KMeans
    from sklearn.metrics import silhouette_samples, silhouette_score

    import matplotlib.pyplot as plt
    import matplotlib.cm as cm
    import math

    # 입력값으로 클러스터링 갯수들을 리스트로 받아서, 각 갯수별로 클러스터링을 적용하고 실루엣 개수를 구함
    n_cols = len(cluster_lists)

    # plt.subplots()으로 리스트에 기재된 클러스터링 수만큼의 sub figures를 가지는 axs 생성 
    fig, axs = plt.subplots(figsize=(4*n_cols, 4), nrows=1, ncols=n_cols)

    # 리스트에 기재된 클러스터링 갯수들을 차례로 iteration 수행하면서 실루엣 개수 시각화
    for ind, n_cluster in enumerate(cluster_lists):

        # KMeans 클러스터링 수행하고, 실루엣 스코어와 개별 데이터의 실루엣 값 계산. 
        clusterer = KMeans(n_clusters = n_cluster, max_iter=500, random_state=0)
        cluster_labels = clusterer.fit_predict(X_features)

        sil_avg = silhouette_score(X_features, cluster_labels)
        sil_values = silhouette_samples(X_features, cluster_labels)

        y_lower = 10
        axs[ind].set_title('Number of Cluster : '+ str(n_cluster)+'\n' \
                          'Silhouette Score :' + str(round(sil_avg,3)) )
        axs[ind].set_xlabel("The silhouette coefficient values")
        axs[ind].set_ylabel("Cluster label")
        axs[ind].set_xlim([-0.1, 1])
        axs[ind].set_ylim([0, len(X_features) + (n_cluster + 1) * 10])
        axs[ind].set_yticks([])  # Clear the yaxis labels / ticks
        axs[ind].set_xticks([0, 0.2, 0.4, 0.6, 0.8, 1])

        # 클러스터링 갯수별로 fill_betweenx( )형태의 막대 그래프 표현. 
        for i in range(n_cluster):
            ith_cluster_sil_values = sil_values[cluster_labels==i]
            ith_cluster_sil_values.sort()

            size_cluster_i = ith_cluster_sil_values.shape[0]
            y_upper = y_lower + size_cluster_i

            color = cm.nipy_spectral(float(i) / n_cluster)
            axs[ind].fill_betweenx(np.arange(y_lower, y_upper), 0, ith_cluster_sil_values, \
                                facecolor=color, edgecolor=color, alpha=0.7)
            axs[ind].text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
            y_lower = y_upper + 10

        axs[ind].axvline(x=sil_avg, color="red", linestyle="--")

# %%
a = list(range(2,20))
visualize_silhouette(a, cus_merge)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [61], in <cell line: 2>()
#       1 a = list(range(2,20))
# ----> 2 visualize_silhouette(a, cus_merge)
#
# Input In [60], in visualize_silhouette(cluster_lists, X_features)
#      21 clusterer = KMeans(n_clusters = n_cluster, max_iter=500, random_state=0)
#      22 cluster_labels = clusterer.fit_predict(X_features)
# ---> 24 sil_avg = silhouette_score(X_features, cluster_labels)
#      25 sil_values = silhouette_samples(X_features, cluster_labels)
#      27 y_lower = 10
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/metrics/cluster/_unsupervised.py:117, in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     115     else:
#     116         X, labels = X[indices], labels[indices]
# ...

# %% [markdown]
# ## Kmeans

# %% [markdown]
# ## 전체

# %%
kmeans = KMeans(n_clusters=3, random_state=1234)
kmeans.fit(cus_merge)
centers_s = kmeans.cluster_centers_ 
pred_s = kmeans.predict(cus_merge)

# %%
cus_merge['cluster'] = pred_s 
cus_merge
# Out:
#           cust  ma_fem_dv  ages  zon_hlv   rct_no  chnl_dv  cop_c  br_c  pd_c  \
# 0            0          1    40        6    16648        1      0    44   776
# 1            0          1    40        6    16648        1      0    44   776
# 2            1          1    30       10   294245        1      0    17   776
# 3            4          1    40       16   117091        1      0    16   776
# 4            6          1    40       16   543169        1      1    73   776
# ...        ...        ...   ...      ...      ...      ...    ...   ...   ...
# 4381738  23211          1    60       15  1165554        1      4  6386   994
# 4381739  23802          0    40       15  1257866        2      5  6755   916
# 4381740  26550          0    40        8  1255001        2      5  6755   916
# 4381741  25021          0    40        9   605562        1      1    88  1058
# 4381742  25970          1    20       15  1225757        2      5  6755   441
#
# ...

# %% [markdown]
# ### scaling

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import MinMaxScaler 
minmax_scaler = MinMaxScaler() 
scaled_df = pd.DataFrame(minmax_scaler.fit_transform(cus_merge), columns=cus_merge.columns)

# %%
kmeans.fit(scaled_df)
centers_s = kmeans.cluster_centers_ 
pred_s = kmeans.predict(scaled_df)

# %%
cus_merge['cluster_s'] = pred_s 
cus_merge
# Out:
#           cust  ma_fem_dv  ages  zon_hlv   rct_no  chnl_dv  cop_c  br_c  pd_c  \
# 0            0          1    40        6    16648        1      0    44   776
# 1            0          1    40        6    16648        1      0    44   776
# 2            1          1    30       10   294245        1      0    17   776
# 3            4          1    40       16   117091        1      0    16   776
# 4            6          1    40       16   543169        1      1    73   776
# ...        ...        ...   ...      ...      ...      ...    ...   ...   ...
# 4381738  23211          1    60       15  1165554        1      4  6386   994
# 4381739  23802          0    40       15  1257866        2      5  6755   916
# 4381740  26550          0    40        8  1255001        2      5  6755   916
# 4381741  25021          0    40        9   605562        1      1    88  1058
# 4381742  25970          1    20       15  1225757        2      5  6755   441
#
# ...

# %%
# cus_merge['cust'].apply(lambda x : encoder.inverse_transform([x]))

# %%
kmeans_cus = pd.merge(cus_merge, cus_merge1, on=['buy_am','de_dt','de_hr','buy_ct','ages']).drop(['cust_x','ma_fem_dv_x','zon_hlv_x','rct_no_x','cop_c_x','br_c_x','pd_c_x','pd_nm_x','clac_hlv_nm_x','clac_mcls_nm_x'],axis=1)
kmeans_cus
# Out:
#           ages  chnl_dv_x     de_dt  de_hr    buy_am  buy_ct  cluster  \
# 0           40          1  20210116     18   59000.0       1        0
# 1           40          1  20210116     18   19000.0       1        0
# 2           30          1  20210805     15  239000.0       1        0
# 3           40          1  20210403     13  179000.0       1        0
# 4           40          1  20210129     14    3000.0       3        0
# ...        ...        ...       ...    ...       ...     ...      ...
# 11731041    60          1  20210430     10  139000.0       1        1
# 11731042    40          2  20210712     21  199000.0       1        1
# 11731043    40          2  20210523      8  187050.0       1        1
# 11731044    40          1  20210828     17  800000.0       8        0
# 11731045    20          2  20210220     14   49500.0       1        1
#
#           cluster_s      cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  \
# ...

# %%
kmeans_cus[kmeans_cus['cluster'] == 0]
# Out:
#           ages  chnl_dv_x     de_dt  de_hr     buy_am  buy_ct  cluster  \
# 0           40          1  20210116     18    59000.0       1        0
# 1           40          1  20210116     18    19000.0       1        0
# 2           30          1  20210805     15   239000.0       1        0
# 3           40          1  20210403     13   179000.0       1        0
# 4           40          1  20210129     14     3000.0       3        0
# ...        ...        ...       ...    ...        ...     ...      ...
# 11731027    40          1  20210508     18    40000.0       1        0
# 11731029    40          1  20210911     16   279000.0       1        0
# 11731032    60          1  20210516     17  1650000.0       1        0
# 11731033    50          1  20210808     12    93000.0       1        0
# 11731044    40          1  20210828     17   800000.0       8        0
#
#           cluster_s      cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  \
# ...

# %%
kmeans_cus[kmeans_cus['cluster'] == 0].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 일반스낵         137114
# 기타파티/팬시용품    106584
# 기타남성의류세트      92829
# 바나나           80120
# 일반우유          69430
#               ...
# 임산부바디케어           1
# 자동차/레저렌탈          1
# 로드자전거             1
# 자전거수리부품           1
# 반건오징어             1
# Name: cust_y, Length: 1856, dtype: int64

# %%
kmeans_cus[kmeans_cus['cluster'] == 1]
# Out:
#           ages  chnl_dv_x     de_dt  de_hr    buy_am  buy_ct  cluster  \
# 10          40          1  20210220     22   50000.0       5        1
# 19          30          2  20210429     15   23000.0       1        1
# 39          40          1  20210724     13   20000.0       2        1
# 40          40          1  20210724     13    4000.0       4        1
# 110         30          2  20210207      0   48400.0       1        1
# ...        ...        ...       ...    ...       ...     ...      ...
# 11731040    50          1  20210320     12    7110.0       1        1
# 11731041    60          1  20210430     10  139000.0       1        1
# 11731042    40          2  20210712     21  199000.0       1        1
# 11731043    40          2  20210523      8  187050.0       1        1
# 11731045    20          2  20210220     14   49500.0       1        1
#
#           cluster_s      cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  \
# ...

# %%
kmeans_cus[kmeans_cus['cluster'] == 1].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 일반스낵            204637
# 감자스낵            148115
# 일반우유            119412
# 기타파티/팬시용품       114867
# 바나나             113810
#                  ...
# 유아동스포츠베스트            1
# 유아동스포츠전신/원피스         1
# 유아동스포츠점퍼/재킷          1
# 특판                   1
# 남성코스튬                1
# Name: cust_y, Length: 1886, dtype: int64

# %%
kmeans_cus[kmeans_cus['cluster'] == 2]
# Out:
#           ages  chnl_dv_x     de_dt  de_hr     buy_am  buy_ct  cluster  \
# 263604      40          2  20211123      6  3720000.0       1        2
# 1326732     30          1  20211230     16  2825000.0       1        2
# 4616330     30          1  20210806     14  5140000.0       1        2
# 4616338     30          1  20210525     18  2950000.0       1        2
# 4616354     50          1  20210724     16  5750000.0       1        2
# ...        ...        ...       ...    ...        ...     ...      ...
# 11730928    50          1  20210530     17  3450000.0       1        2
# 11730929    50          1  20210530     17  3450000.0       1        2
# 11730930    50          1  20210530     17  3450000.0       1        2
# 11730932    30          1  20210417     13  3750000.0       1        2
# 11731014    50          1  20210117     16  3605000.0       1        2
#
#           cluster_s      cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  \
# ...

# %%
kmeans_cus[kmeans_cus['cluster'] == 2].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 여성가방액세서리    375
# 기타패션잡화      305
# 남성시계        256
# 여성숄더백       256
# 여성토트백       246
#            ...
# 냉방가전소모품       1
# 장식스탠드         1
# 장식장/진열장       1
# 남성정장바지        1
# 휴대폰           1
# Name: cust_y, Length: 176, dtype: int64

# %%
kmeans_cus[kmeans_cus['cluster_s'] == 0]
# Out:
#           ages  chnl_dv_x     de_dt  de_hr    buy_am  buy_ct  cluster  \
# 0           40          1  20210116     18   59000.0       1        0
# 1           40          1  20210116     18   19000.0       1        0
# 2           30          1  20210805     15  239000.0       1        0
# 3           40          1  20210403     13  179000.0       1        0
# 4           40          1  20210129     14    3000.0       3        0
# ...        ...        ...       ...    ...       ...     ...      ...
# 11731024    40          1  20210508     18  300000.0       1        0
# 11731025    40          1  20210508     18  300000.0       1        0
# 11731026    40          1  20210508     18  300000.0       1        0
# 11731027    40          1  20210508     18   40000.0       1        0
# 11731033    50          1  20210808     12   93000.0       1        0
#
#           cluster_s      cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  \
# ...

# %%
kmeans_cus[kmeans_cus['cluster_s'] == 0].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 일반스낵         227941
# 기타파티/팬시용품    150856
# 바나나          123636
# 일반우유         110428
# 옥수수스낵        106404
#               ...
# 스키/보드고글           1
# 네일세트              1
# 이발기               1
# 벽걸이형에어컨           1
# 제본기               1
# Name: cust_y, Length: 1860, dtype: int64

# %%
kmeans_cus[kmeans_cus['cluster_s'] == 1]
# Out:
#           ages  chnl_dv_x     de_dt  de_hr     buy_am  buy_ct  cluster  \
# 7           50          1  20210321     15    87300.0       1        0
# 8           50          1  20210920     11   128600.0       1        0
# 9           30          1  20210306     15    69400.0       1        0
# 11          40          1  20210417     19   250000.0       1        0
# 12          40          1  20210716     19    65000.0       1        0
# ...        ...        ...       ...    ...        ...     ...      ...
# 11731014    50          1  20210117     16  3605000.0       1        2
# 11731029    40          1  20210911     16   279000.0       1        0
# 11731032    60          1  20210516     17  1650000.0       1        0
# 11731040    50          1  20210320     12     7110.0       1        1
# 11731044    40          1  20210828     17   800000.0       8        0
#
#           cluster_s      cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  \
# ...

# %%
kmeans_cus[kmeans_cus['cluster_s'] == 1].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 일반스낵         98476
# 기타파티/팬시용품    63176
# 바나나          49888
# 일반우유         48403
# 옥수수스낵        48201
#              ...
# 프로젝터             1
# 손싸개/발싸개          1
# 수입산소토시살          1
# 썰매류              1
# 힙색/사이드백          1
# Name: cust_y, Length: 1823, dtype: int64

# %%
kmeans_cus[kmeans_cus['cluster_s'] == 2]
# Out:
#           ages  chnl_dv_x     de_dt  de_hr    buy_am  buy_ct  cluster  \
# 19          30          2  20210429     15   23000.0       1        1
# 110         30          2  20210207      0   48400.0       1        1
# 111         50          2  20210414     10  231000.0       1        1
# 182         40          2  20210318     15   38000.0       1        1
# 183         40          2  20210318     15   38000.0       1        1
# ...        ...        ...       ...    ...       ...     ...      ...
# 11731039    40          2  20210131     19  229000.0       1        1
# 11731041    60          1  20210430     10  139000.0       1        1
# 11731042    40          2  20210712     21  199000.0       1        1
# 11731043    40          2  20210523      8  187050.0       1        1
# 11731045    20          2  20210220     14   49500.0       1        1
#
#           cluster_s      cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  \
# ...

# %%
kmeans_cus[kmeans_cus['cluster_s'] == 2].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 감자스낵             54263
# 영화/문화모바일상품권      37667
# 국물봉지라면           35065
# 여성패딩             34942
# 일반우유             30011
#                  ...
# 여성벨트                 1
# 여성스포츠베스트             1
# 여성피혁의류               1
# 여아스웨트셔츠/후드/집업        1
# 스포츠시계                1
# Name: cust_y, Length: 1801, dtype: int64

# %% [markdown]
# ## 성별

# %%
elbow(cus_sex.drop(['buy_am','de_dt','de_hr','buy_ct'],axis=1),10)
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %%
kmeans = KMeans(n_clusters=3, random_state=1234)
kmeans.fit(cus_sex.drop(['buy_am','de_dt','de_hr','buy_ct'],axis=1))
centers_s = kmeans.cluster_centers_ 
pred_s = kmeans.predict(cus_sex.drop(['buy_am','de_dt','de_hr','buy_ct'],axis=1))

# %%
cus_sex['cluster'] = pred_s 
cus_sex
# Out:
#           cust  ma_fem_dv  pd_c  pd_nm  clac_hlv_nm  clac_mcls_nm    buy_am  \
# 0            0          1   776    336           28            55   59000.0
# 1            0          1   776    336           28            55   19000.0
# 2            1          1   776    336           28            55  239000.0
# 3            4          1   776    336           28            55  179000.0
# 4            6          1   776    336           28            55    3000.0
# ...        ...        ...   ...    ...          ...           ...       ...
# 4381738  23211          1   994    736           35           150  139000.0
# 4381739  23802          0   916    652           31           273  199000.0
# 4381740  26550          0   916    652           31           273  187050.0
# 4381741  25021          0  1058    762           37            89  800000.0
# 4381742  25970          1   441   1504           19           129   49500.0
#
#             de_dt  de_hr  buy_ct  cluster
# ...

# %% [markdown]
# ### scaling

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import MinMaxScaler 
minmax_scaler = MinMaxScaler() 
scaled_df = pd.DataFrame(minmax_scaler.fit_transform(cus_sex.drop(['buy_am','de_dt','de_hr','buy_ct'],axis=1)), columns=cus_sex.drop(['buy_am','de_dt','de_hr','buy_ct'],axis=1).columns)

# %%
kmeans.fit(scaled_df)
centers_s = kmeans.cluster_centers_ 
pred_s = kmeans.predict(scaled_df)

# %%
cus_sex['cluster_s'] = pred_s 
cus_sex
# Out:
#           cust  ma_fem_dv  pd_c  pd_nm  clac_hlv_nm  clac_mcls_nm    buy_am  \
# 0            0          1   776    336           28            55   59000.0
# 1            0          1   776    336           28            55   19000.0
# 2            1          1   776    336           28            55  239000.0
# 3            4          1   776    336           28            55  179000.0
# 4            6          1   776    336           28            55    3000.0
# ...        ...        ...   ...    ...          ...           ...       ...
# 4381738  23211          1   994    736           35           150  139000.0
# 4381739  23802          0   916    652           31           273  199000.0
# 4381740  26550          0   916    652           31           273  187050.0
# 4381741  25021          0  1058    762           37            89  800000.0
# 4381742  25970          1   441   1504           19           129   49500.0
#
#             de_dt  de_hr  buy_ct  cluster  cluster_s
# ...

# %%
kmeans_sex = pd.merge(cus_sex, cus_sex1, on=['buy_am','de_dt','de_hr','buy_ct']).drop(['cust_x','ma_fem_dv_x','pd_c_x','pd_nm_x','clac_hlv_nm_x','clac_mcls_nm_x'],axis=1)
kmeans_sex
# Out:
#             buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 0          59000.0  20210116     18       1        2          0  M000034966
# 1          19000.0  20210116     18       1        2          0  M000034966
# 2          19000.0  20210116     18       1        2          0  M602016613
# 3          19000.0  20210116     18       1        2          0  M296951926
# 4          19000.0  20210116     18       1        1          2  M000034966
# ...            ...       ...    ...     ...      ...        ...         ...
# 26570151    7110.0  20210320     12       1        0          1  M854668364
# 26570152  139000.0  20210430     10       1        0          2  M858719851
# 26570153  199000.0  20210712     21       1        0          1  M880029153
# 26570154  187050.0  20210523      8       1        0          1  M986268092
# 26570155  800000.0  20210828     17       8        0          1  M926014276
#
# ...

# %%
kmeans_sex[kmeans_sex['cluster'] == 0]
# Out:
#             buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 16          3000.0  20210129     14       3        0          2  M000419293
# 17          3000.0  20210129     14       3        0          2  M690777930
# 18          3000.0  20210129     14       3        0          2  M064003542
# 19          3000.0  20210129     14       3        0          2  M453490534
# 30           500.0  20210129     14       5        0          2  M000419293
# ...            ...       ...    ...     ...      ...        ...         ...
# 26570151    7110.0  20210320     12       1        0          1  M854668364
# 26570152  139000.0  20210430     10       1        0          2  M858719851
# 26570153  199000.0  20210712     21       1        0          1  M880029153
# 26570154  187050.0  20210523      8       1        0          1  M986268092
# 26570155  800000.0  20210828     17       8        0          1  M926014276
#
# ...

# %%
kmeans_sex[kmeans_sex['cluster'] == 0].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성    2620056
# 여성    6220707
# Name: cust_y, dtype: int64

# %%
kmeans_sex[kmeans_sex['cluster']==0].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 일반스낵          269559
# 기타파티/팬시용품     216854
# 바나나           190541
# 일반우유          144337
# 감자스낵          141371
#                ...
# 로드자전거              1
# 유아공부상/디딤대          1
# 올인원                1
# 기타광학기기             1
# 복근/벨트마사지기구         1
# Name: cust_y, Length: 1889, dtype: int64

# %%
kmeans_sex[kmeans_sex['cluster']==0].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 영화/문화모바일상품권    1.528093e+09
# 기타남성의류세트       1.398780e+09
# 기타패션잡화         1.053891e+09
# 여성가방액세서리       1.019989e+09
# 여성숄더백          1.013145e+09
#                    ...
# 자석놀이           3.600000e+03
# 반짇고리/세트        3.000000e+03
# 분말죽            1.790000e+03
# 컴퓨터/노트북기프트     3.000000e+02
# 공병/공박스         2.000000e+02
# Name: buy_am, Length: 1889, dtype: float64

# %%
kmeans_sex[kmeans_sex['cluster'] == 1]
# Out:
#              buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 4           19000.0  20210116     18       1        1          2  M000034966
# 5           19000.0  20210116     18       1        1          2  M602016613
# 6           19000.0  20210116     18       1        1          2  M296951926
# 24           3000.0  20210129     14       3        1          1  M000419293
# 25           3000.0  20210129     14       3        1          1  M690777930
# ...             ...       ...    ...     ...      ...        ...         ...
# 26570118    25000.0  20210105      3       5        1          2  M504707751
# 26570120    11400.0  20210407     20       1        1          1  M530779190
# 26570122    95700.0  20211220     13       3        1          2  M557822429
# 26570124    45820.0  20210705     11       1        1          2  M570817832
# 26570126  3605000.0  20210117     16       1        1          1  M641790940
#
# ...

# %%
kmeans_sex[kmeans_sex['cluster'] == 1].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성    2588217
# 여성    6226385
# Name: cust_y, dtype: int64

# %%
kmeans_sex[kmeans_sex['cluster']==1].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 일반스낵              266291
# 기타파티/팬시용품         215285
# 바나나               189358
# 일반우유              143179
# 감자스낵              138148
#                    ...
# 기타탁구용품                 1
# 여성스포츠스커트               1
# 분말죽                    1
# 기타DVD/홈시어터액세서리         1
# 스포츠선글라스                1
# Name: cust_y, Length: 1892, dtype: int64

# %%
kmeans_sex[kmeans_sex['cluster']==1].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 여성패딩           2.843463e+09
# 영화/문화모바일상품권    1.700928e+09
# 여성스니커즈         1.425102e+09
# 기타패션잡화         1.307095e+09
# 기타남성의류세트       1.270550e+09
#                    ...
# 영유아패션트레이닝복     3.900000e+03
# 학습악기류          2.000000e+03
# 자석놀이           1.800000e+03
# 분말죽            1.790000e+03
# 공병/공박스         2.000000e+02
# Name: buy_am, Length: 1892, dtype: float64

# %%
kmeans_sex[kmeans_sex['cluster'] == 2]
# Out:
#             buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 0          59000.0  20210116     18       1        2          0  M000034966
# 1          19000.0  20210116     18       1        2          0  M000034966
# 2          19000.0  20210116     18       1        2          0  M602016613
# 3          19000.0  20210116     18       1        2          0  M296951926
# 7          19000.0  20210116     18       1        2          1  M000034966
# ...            ...       ...    ...     ...      ...        ...         ...
# 26570035     130.0  20210126     19       1        2          0  M296821100
# 26570036    1420.0  20210908     17       1        2          0  M299016876
# 26570037  180000.0  20210922     15       1        2          1  M305279155
# 26570040  151570.0  20210409     12       1        2          0  M320192165
# 26570041  151570.0  20210412     12       1        2          0  M320192165
#
# ...

# %%
kmeans_sex[kmeans_sex['cluster'] == 2].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성    2648510
# 여성    6266281
# Name: cust_y, dtype: int64

# %%
kmeans_sex[kmeans_sex['cluster']==2].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 일반스낵         268977
# 기타파티/팬시용품    226390
# 바나나          192654
# 감자스낵         146969
# 일반우유         146731
#               ...
# 분말죽               1
# 올인원               1
# 학습악기류             1
# 유아동시계             1
# 임산부스킨케어           1
# Name: cust_y, Length: 1900, dtype: int64

# %%
kmeans_sex[kmeans_sex['cluster']==2].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 영화/문화모바일상품권    1.945992e+09
# 기타패션잡화         1.567760e+09
# 기타남성의류세트       1.281849e+09
# 여성숄더백          1.191757e+09
# 남성시계           1.040587e+09
#                    ...
# 학습악기류          2.000000e+03
# 분말죽            1.420000e+03
# 공병/공박스         6.300000e+02
# 컴퓨터/노트북기프트     2.000000e+02
# 타이어            1.000000e+02
# Name: buy_am, Length: 1900, dtype: float64

# %%
kmeans_sex[kmeans_sex['cluster_s'] == 0]
# Out:
#             buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 0          59000.0  20210116     18       1        2          0  M000034966
# 1          19000.0  20210116     18       1        2          0  M000034966
# 2          19000.0  20210116     18       1        2          0  M602016613
# 3          19000.0  20210116     18       1        2          0  M296951926
# 10        239000.0  20210805     15       1        2          0  M000136117
# ...            ...       ...    ...     ...      ...        ...         ...
# 26570034     200.0  20210126     19       2        2          0  M296821100
# 26570035     130.0  20210126     19       1        2          0  M296821100
# 26570036    1420.0  20210908     17       1        2          0  M299016876
# 26570040  151570.0  20210409     12       1        2          0  M320192165
# 26570041  151570.0  20210412     12       1        2          0  M320192165
#
# ...

# %%
kmeans_sex[kmeans_sex['cluster_s'] == 0].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성    1422241
# 여성    4806421
# Name: cust_y, dtype: int64

# %%
kmeans_sex[kmeans_sex['cluster_s']==0].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 일반스낵         188829
# 기타파티/팬시용품    155813
# 바나나          139044
# 감자스낵         104874
# 일반우유         103470
#               ...
# 테니스라켓             1
# 기타보험              1
# 남성스포츠속옷           1
# 고양이건강용품           1
# 여성힙색              1
# Name: cust_y, Length: 1879, dtype: int64

# %%
kmeans_sex[kmeans_sex['cluster_s']==0].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 기타패션잡화        1.132552e+09
# 기타남성의류세트      8.936216e+08
# 여성가방액세서리      8.687004e+08
# 남성시계          6.810845e+08
# 여성티셔츠/탑       6.561870e+08
#                   ...
# 격투기의류/용품      1.900000e+03
# 분말죽           1.420000e+03
# 공병/공박스        6.300000e+02
# 컴퓨터/노트북기프트    2.000000e+02
# 타이어           1.000000e+02
# Name: buy_am, Length: 1879, dtype: float64

# %%
kmeans_sex[kmeans_sex['cluster_s'] == 1]
# Out:
#             buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 7          19000.0  20210116     18       1        2          1  M000034966
# 8          19000.0  20210116     18       1        2          1  M602016613
# 9          19000.0  20210116     18       1        2          1  M296951926
# 20          3000.0  20210129     14       3        2          1  M000419293
# 21          3000.0  20210129     14       3        2          1  M690777930
# ...            ...       ...    ...     ...      ...        ...         ...
# 26570150  229000.0  20210131     19       1        0          1  M802756595
# 26570151    7110.0  20210320     12       1        0          1  M854668364
# 26570153  199000.0  20210712     21       1        0          1  M880029153
# 26570154  187050.0  20210523      8       1        0          1  M986268092
# 26570155  800000.0  20210828     17       8        0          1  M926014276
#
# ...

# %%
kmeans_sex[kmeans_sex['cluster_s'] == 1].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성    3594332
# 여성    4262451
# Name: cust_y, dtype: int64

# %%
kmeans_sex[kmeans_sex['cluster_s']==1].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 일반스낵         236371
# 기타파티/팬시용품    196247
# 바나나          159640
# 일반우유         125752
# 감자스낵         121599
#               ...
# 여성쪼리              1
# 주방수납장             1
# 그림/인테리어렌탈         1
# 족욕기               1
# 라디오/튜너            1
# Name: cust_y, Length: 1897, dtype: int64

# %%
kmeans_sex[kmeans_sex['cluster_s']==1].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 영화/문화모바일상품권    3.413491e+09
# 여성패딩           2.841649e+09
# 남성시계           1.502445e+09
# 기타남성의류세트       1.355670e+09
# 여성스니커즈         1.341627e+09
#                    ...
# 자석놀이           3.600000e+03
# 니삭스/오버니삭스      2.700000e+03
# 분말죽            1.790000e+03
# 영유아패션트레이닝복     1.700000e+03
# 공병/공박스         2.000000e+02
# Name: buy_am, Length: 1897, dtype: float64

# %%
kmeans_sex[kmeans_sex['cluster_s'] == 2]
# Out:
#             buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 4          19000.0  20210116     18       1        1          2  M000034966
# 5          19000.0  20210116     18       1        1          2  M602016613
# 6          19000.0  20210116     18       1        1          2  M296951926
# 16          3000.0  20210129     14       3        0          2  M000419293
# 17          3000.0  20210129     14       3        0          2  M690777930
# ...            ...       ...    ...     ...      ...        ...         ...
# 26570144   93000.0  20210808     12       1        0          2  M949264778
# 26570146  208000.0  20210929     21       1        0          2  M970932333
# 26570147   28580.0  20210428     10       1        0          2  M762888764
# 26570148   19900.0  20210201     10       1        0          2  M780795389
# 26570152  139000.0  20210430     10       1        0          2  M858719851
#
# ...

# %%
kmeans_sex[kmeans_sex['cluster_s'] == 2].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성    2840210
# 여성    9644501
# Name: cust_y, dtype: int64

# %%
kmeans_sex[kmeans_sex['cluster_s']==2].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 일반스낵              379627
# 기타파티/팬시용품         306469
# 바나나               273869
# 일반우유              205025
# 감자스낵              200015
#                    ...
# 기타탁구용품                 1
# 기타광학기기                 1
# 기타DVD/홈시어터액세서리         1
# 행커치프                   1
# 침구청소기                  1
# Name: cust_y, Length: 1905, dtype: int64

# %%
kmeans_sex[kmeans_sex['cluster_s']==2].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 기타패션잡화      1.743122e+09
# 기타남성의류세트    1.701888e+09
# 여성가방액세서리    1.498849e+09
# 여성재킷        1.491485e+09
# 여성티셔츠/탑     1.455835e+09
#                 ...
# 자석놀이        5.400000e+03
# 반짇고리/세트     3.000000e+03
# 분말죽         1.790000e+03
# 타이어         4.000000e+02
# 공병/공박스      2.000000e+02
# Name: buy_am, Length: 1905, dtype: float64

# %% [markdown]
# ## 나이

# %%
elbow(cus_age.drop(['buy_am','de_dt','de_hr','buy_ct'],axis=1),10)
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %%
kmeans = KMeans(n_clusters=3, random_state=1234)
kmeans.fit(cus_age.drop(['buy_am','de_dt','de_hr','buy_ct'],axis=1))
centers_s = kmeans.cluster_centers_ 
pred_s = kmeans.predict(cus_age.drop(['buy_am','de_dt','de_hr','buy_ct'],axis=1))

# %%
cus_age['cluster'] = pred_s 
cus_age
# Out:
#           cust  ages  pd_c  pd_nm  clac_hlv_nm  clac_mcls_nm    buy_am  \
# 0            0    40   776    336           28            55   59000.0
# 1            0    40   776    336           28            55   19000.0
# 2            1    30   776    336           28            55  239000.0
# 3            4    40   776    336           28            55  179000.0
# 4            6    40   776    336           28            55    3000.0
# ...        ...   ...   ...    ...          ...           ...       ...
# 4381738  23211    60   994    736           35           150  139000.0
# 4381739  23802    40   916    652           31           273  199000.0
# 4381740  26550    40   916    652           31           273  187050.0
# 4381741  25021    40  1058    762           37            89  800000.0
# 4381742  25970    20   441   1504           19           129   49500.0
#
#             de_dt  de_hr  buy_ct  cluster
# 0        20210116     18       1        2
# ...

# %% [markdown]
# ### scaling

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import MinMaxScaler 
minmax_scaler = MinMaxScaler() 
scaled_df = pd.DataFrame(minmax_scaler.fit_transform(cus_age.drop(['buy_am','de_dt','de_hr','buy_ct'],axis=1)), columns=cus_age.drop(['buy_am','de_dt','de_hr','buy_ct'],axis=1).columns)

# %%
kmeans.fit(scaled_df)
centers_s = kmeans.cluster_centers_ 
pred_s = kmeans.predict(scaled_df)

# %%
cus_age['cluster_s'] = pred_s 
cus_age
# Out:
#           cust  ages  pd_c  pd_nm  clac_hlv_nm  clac_mcls_nm    buy_am  \
# 0            0    40   776    336           28            55   59000.0
# 1            0    40   776    336           28            55   19000.0
# 2            1    30   776    336           28            55  239000.0
# 3            4    40   776    336           28            55  179000.0
# 4            6    40   776    336           28            55    3000.0
# ...        ...   ...   ...    ...          ...           ...       ...
# 4381738  23211    60   994    736           35           150  139000.0
# 4381739  23802    40   916    652           31           273  199000.0
# 4381740  26550    40   916    652           31           273  187050.0
# 4381741  25021    40  1058    762           37            89  800000.0
# 4381742  25970    20   441   1504           19           129   49500.0
#
#             de_dt  de_hr  buy_ct  cluster  cluster_s
# 0        20210116     18       1        2          1
# ...

# %%
kmeans_age = pd.merge(cus_age, cus_age1, on=['buy_am','de_dt','de_hr','buy_ct']).drop(['cust_x','ages_x','pd_c_x','pd_nm_x','clac_hlv_nm_x','clac_mcls_nm_x'],axis=1)
kmeans_age
# Out:
#             buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 0          59000.0  20210116     18       1        2          1  M000034966
# 1          19000.0  20210116     18       1        2          1  M000034966
# 2          19000.0  20210116     18       1        2          1  M602016613
# 3          19000.0  20210116     18       1        2          1  M296951926
# 4          19000.0  20210116     18       1        1          1  M000034966
# ...            ...       ...    ...     ...      ...        ...         ...
# 26570151    7110.0  20210320     12       1        0          0  M854668364
# 26570152  139000.0  20210430     10       1        0          0  M858719851
# 26570153  199000.0  20210712     21       1        0          0  M880029153
# 26570154  187050.0  20210523      8       1        0          0  M986268092
# 26570155  800000.0  20210828     17       8        0          0  M926014276
#
# ...

# %%
kmeans_age[kmeans_age['cluster'] == 0]
# Out:
#             buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 16          3000.0  20210129     14       3        0          0  M000419293
# 17          3000.0  20210129     14       3        0          0  M690777930
# 18          3000.0  20210129     14       3        0          0  M064003542
# 19          3000.0  20210129     14       3        0          0  M453490534
# 30           500.0  20210129     14       5        0          0  M000419293
# ...            ...       ...    ...     ...      ...        ...         ...
# 26570151    7110.0  20210320     12       1        0          0  M854668364
# 26570152  139000.0  20210430     10       1        0          0  M858719851
# 26570153  199000.0  20210712     21       1        0          0  M880029153
# 26570154  187050.0  20210523      8       1        0          0  M986268092
# 26570155  800000.0  20210828     17       8        0          0  M926014276
#
# ...

# %%
kmeans_age[kmeans_age['cluster'] == 0].groupby('ages_y')['cust_y'].count() / len(kmeans_age[kmeans_age['cluster'] == 0])
# Out:
# ages_y
# 20    0.056483
# 30    0.234095
# 40    0.424357
# 50    0.205745
# 60    0.059722
# 70    0.019598
# Name: cust_y, dtype: float64

# %%
kmeans_age[kmeans_age['cluster']==0].groupby(['ages_y','pd_nm_y'])['cust_y'].count().sort_values(ascending=False)
# Out:
# ages_y  pd_nm_y
# 40      일반스낵         127602
#         기타파티/팬시용품     79674
#         바나나           73992
#         감자스낵          70689
# 30      일반스낵          65233
#                       ...
# 60      남성샌들              1
# 50      물걸레청소기            1
# 70      빨래건조대             1
# 20      유모차               1
#         이불/옷커버류           1
# Name: cust_y, Length: 9658, dtype: int64

# %%
kmeans_age[kmeans_age['cluster']==0].groupby(['ages_y','pd_nm_y'])["buy_am"].sum().sort_values(ascending=False).head(1000)
# Out:
# ages_y  pd_nm_y
# 30      영화/문화모바일상품권    642138000.0
# 40      기타남성의류세트       638329750.0
#         영화/문화모바일상품권    596356600.0
# 30      여성가방액세서리       505967400.0
# 20      남성스니커즈         436532500.0
#                           ...
# 40      스테이크            15187179.0
# 60      고추              15178250.0
# 40      여성팬티            15161360.0
#         곶감              15158990.0
# 20      남성사파리           15155200.0
# Name: buy_am, Length: 1000, dtype: float64

# %%
kmeans_age[kmeans_age['cluster'] == 1]
# Out:
#              buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 4           19000.0  20210116     18       1        1          1  M000034966
# 5           19000.0  20210116     18       1        1          1  M602016613
# 6           19000.0  20210116     18       1        1          1  M296951926
# 24           3000.0  20210129     14       3        1          1  M000419293
# 25           3000.0  20210129     14       3        1          1  M690777930
# ...             ...       ...    ...     ...      ...        ...         ...
# 26570118    25000.0  20210105      3       5        1          1  M504707751
# 26570120    11400.0  20210407     20       1        1          1  M530779190
# 26570122    95700.0  20211220     13       3        1          1  M557822429
# 26570124    45820.0  20210705     11       1        1          2  M570817832
# 26570126  3605000.0  20210117     16       1        1          1  M641790940
#
# ...

# %%
kmeans_age[kmeans_age['cluster'] == 1].groupby('ages_y')['cust_y'].count() / len(kmeans_age[kmeans_age['cluster'] == 1])
# Out:
# ages_y
# 20    0.054757
# 30    0.235969
# 40    0.424063
# 50    0.207646
# 60    0.058268
# 70    0.019297
# Name: cust_y, dtype: float64

# %%
kmeans_age[kmeans_age['cluster']==1].groupby(['ages_y','pd_nm_y'])['cust_y'].count().sort_values(ascending=False)
# Out:
# ages_y  pd_nm_y
# 40      일반스낵         126141
#         기타파티/팬시용품     79398
#         바나나           73406
#         감자스낵          68513
# 30      일반스낵          64297
#                       ...
#         여성골프스커트           1
#         여성골프베스트           1
#         여성골프남방셔츠          1
#         여권/통장지갑           1
# 70      히터                1
# Name: cust_y, Length: 9668, dtype: int64

# %%
kmeans_age[kmeans_age['cluster']==1].groupby(['ages_y','pd_nm_y'])["buy_am"].sum().sort_values(ascending=False).head(1000)
# Out:
# ages_y  pd_nm_y
# 30      여성패딩           2.764603e+09
#         여성스니커즈         1.294340e+09
#         영화/문화모바일상품권    7.188532e+08
# 40      남성시계           7.116783e+08
#         영화/문화모바일상품권    6.570684e+08
#                            ...
# 20      남성정장재킷         1.545210e+07
# 50      남성숄더/크로스백      1.544622e+07
# 30      양상추            1.544107e+07
# 50      태블릿PC          1.543470e+07
# 40      립스틱/립라이너       1.542795e+07
# Name: buy_am, Length: 1000, dtype: float64

# %%
kmeans_age[kmeans_age['cluster'] == 2]
# Out:
#             buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 0          59000.0  20210116     18       1        2          1  M000034966
# 1          19000.0  20210116     18       1        2          1  M000034966
# 2          19000.0  20210116     18       1        2          1  M602016613
# 3          19000.0  20210116     18       1        2          1  M296951926
# 7          19000.0  20210116     18       1        2          2  M000034966
# ...            ...       ...    ...     ...      ...        ...         ...
# 26570035     130.0  20210126     19       1        2          1  M296821100
# 26570036    1420.0  20210908     17       1        2          1  M299016876
# 26570037  180000.0  20210922     15       1        2          1  M305279155
# 26570040  151570.0  20210409     12       1        2          1  M320192165
# 26570041  151570.0  20210412     12       1        2          1  M320192165
#
# ...

# %%
kmeans_age[kmeans_age['cluster'] == 2].groupby('ages_y')['cust_y'].count() / len(kmeans_age[kmeans_age['cluster'] == 2])
# Out:
# ages_y
# 20    0.055195
# 30    0.235214
# 40    0.424754
# 50    0.207077
# 60    0.058887
# 70    0.018873
# Name: cust_y, dtype: float64

# %%
kmeans_age[kmeans_age['cluster']==2].groupby(['ages_y','pd_nm_y'])['cust_y'].count().sort_values(ascending=False)
# Out:
# ages_y  pd_nm_y
# 40      일반스낵         127631
#         기타파티/팬시용품     83346
#         바나나           74856
#         감자스낵          71361
# 30      일반스낵          64936
#                       ...
# 60      시가/기타특수담배         1
#         스피커               1
#         스포츠시계             1
# 20      온풍기               1
# 70      안전상비의약품           1
# Name: cust_y, Length: 9707, dtype: int64

# %%
kmeans_age[kmeans_age['cluster']==2].groupby(['ages_y','pd_nm_y'])["buy_am"].sum().sort_values(ascending=False).head(1000)
# Out:
# ages_y  pd_nm_y
# 30      영화/문화모바일상품권    823597200.0
# 40      영화/문화모바일상품권    755595100.0
#         기타패션잡화         705966860.0
# 30      여성숄더백          608944360.0
#         기타패션잡화         608160970.0
#                           ...
# 20      국물봉지라면          15690716.0
# 40      스틱원두커피          15671790.0
# 50      여성남방셔츠          15606500.0
# 40      접시              15590250.0
# 30      양상추             15585470.0
# Name: buy_am, Length: 1000, dtype: float64

# %%
kmeans_age[kmeans_age['cluster_s'] == 0]
# Out:
#             buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 16          3000.0  20210129     14       3        0          0  M000419293
# 17          3000.0  20210129     14       3        0          0  M690777930
# 18          3000.0  20210129     14       3        0          0  M064003542
# 19          3000.0  20210129     14       3        0          0  M453490534
# 30           500.0  20210129     14       5        0          0  M000419293
# ...            ...       ...    ...     ...      ...        ...         ...
# 26570151    7110.0  20210320     12       1        0          0  M854668364
# 26570152  139000.0  20210430     10       1        0          0  M858719851
# 26570153  199000.0  20210712     21       1        0          0  M880029153
# 26570154  187050.0  20210523      8       1        0          0  M986268092
# 26570155  800000.0  20210828     17       8        0          0  M926014276
#
# ...

# %%
kmeans_age[kmeans_age['cluster_s'] == 0].groupby('ages_y')['cust_y'].count() / len(kmeans_age[kmeans_age['cluster_s'] == 0])
# Out:
# ages_y
# 20    0.056481
# 30    0.234084
# 40    0.424332
# 50    0.205768
# 60    0.059735
# 70    0.019600
# Name: cust_y, dtype: float64

# %%
kmeans_age[kmeans_age['cluster_s']==0].groupby(['ages_y','pd_nm_y'])['cust_y'].count().sort_values(ascending=False)
# Out:
# ages_y  pd_nm_y
# 40      일반스낵          127643
#         기타파티/팬시용품      79732
#         바나나            74003
#         감자스낵           70705
# 30      일반스낵           65261
#                        ...
# 60      남성샌들               1
# 70      냉장/냉동가전소모품         1
#         냉동홍시               1
# 40      젤네일/케어류            1
# 30      글루코사민              1
# Name: cust_y, Length: 9659, dtype: int64

# %%
kmeans_age[kmeans_age['cluster_s']==0].groupby(['ages_y','pd_nm_y'])["buy_am"].sum().sort_values(ascending=False).head(1000)
# Out:
# ages_y  pd_nm_y
# 30      영화/문화모바일상품권    642138000.0
# 40      기타남성의류세트       638563050.0
#         영화/문화모바일상품권    596356600.0
# 30      여성가방액세서리       505967400.0
# 20      남성스니커즈         436532500.0
#                           ...
# 40      등산화             15290680.0
#         식기세척기           15279900.0
# 20      소시지             15256506.0
# 40      기타과일선물세트        15252540.0
#         스테이크            15187179.0
# Name: buy_am, Length: 1000, dtype: float64

# %%
kmeans_age[kmeans_age['cluster_s'] == 1]
# Out:
#              buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 0           59000.0  20210116     18       1        2          1  M000034966
# 1           19000.0  20210116     18       1        2          1  M000034966
# 2           19000.0  20210116     18       1        2          1  M602016613
# 3           19000.0  20210116     18       1        2          1  M296951926
# 4           19000.0  20210116     18       1        1          1  M000034966
# ...             ...       ...    ...     ...      ...        ...         ...
# 26570116    13900.0  20210405     21       1        1          1  M490677749
# 26570118    25000.0  20210105      3       5        1          1  M504707751
# 26570120    11400.0  20210407     20       1        1          1  M530779190
# 26570122    95700.0  20211220     13       3        1          1  M557822429
# 26570126  3605000.0  20210117     16       1        1          1  M641790940
#
# ...

# %%
kmeans_age[kmeans_age['cluster_s'] == 1].groupby('ages_y')['cust_y'].count() / len(kmeans_age[kmeans_age['cluster_s'] == 1])
# Out:
# ages_y
# 20    0.054631
# 30    0.232231
# 40    0.430696
# 50    0.207273
# 60    0.056707
# 70    0.018462
# Name: cust_y, dtype: float64

# %%
kmeans_age[kmeans_age['cluster_s']==1].groupby(['ages_y','pd_nm_y'])['cust_y'].count().sort_values(ascending=False)
# Out:
# ages_y  pd_nm_y
# 40      일반스낵             167838
#         감자스낵              97433
#         기타파티/팬시용품         90624
# 30      일반스낵              85293
# 40      바나나               85198
#                           ...
#         안마의자/헬스/이미용렌탈         1
# 70      아이케어                  1
# 40      애견이동장                 1
# 70      안경테                   1
# 60      기타피트니스기구              1
# Name: cust_y, Length: 9346, dtype: int64

# %%
kmeans_age[kmeans_age['cluster_s']==1].groupby(['ages_y','pd_nm_y'])["buy_am"].sum().sort_values(ascending=False).head(1000)
# Out:
# ages_y  pd_nm_y
# 30      영화/문화모바일상품권    1.535843e+09
# 40      영화/문화모바일상품권    1.405905e+09
#         기타남성의류세트       7.934396e+08
# 30      기타남성의류세트       5.690914e+08
# 40      남성티셔츠          5.196344e+08
#                            ...
# 60      냉장면            1.335225e+07
#         수입포도           1.334804e+07
# 30      건강마스크          1.334323e+07
# 40      성인침구매트         1.332700e+07
# 70      기타국산과일류        1.331253e+07
# Name: buy_am, Length: 1000, dtype: float64

# %%
kmeans_age[kmeans_age['cluster_s'] == 2]
# Out:
#             buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 7          19000.0  20210116     18       1        2          2  M000034966
# 8          19000.0  20210116     18       1        2          2  M602016613
# 9          19000.0  20210116     18       1        2          2  M296951926
# 66         29000.0  20210808     19       1        2          2  M001694463
# 67         29000.0  20210808     19       1        2          2  M704962495
# ...            ...       ...    ...     ...      ...        ...         ...
# 26570111    5850.0  20210106      9       1        1          2  M533330698
# 26570112   12500.0  20211228     18       1        1          2  M481734389
# 26570113   10500.0  20211228     18       1        1          2  M481734389
# 26570117  119200.0  20210605     19       1        1          2  M500789827
# 26570124   45820.0  20210705     11       1        1          2  M570817832
#
# ...

# %%
kmeans_age[kmeans_age['cluster_s'] == 2].groupby('ages_y')['cust_y'].count() / len(kmeans_age[kmeans_age['cluster_s'] == 2])
# Out:
# ages_y
# 20    0.055344
# 30    0.239156
# 40    0.417784
# 50    0.207430
# 60    0.060546
# 70    0.019740
# Name: cust_y, dtype: float64

# %%
kmeans_age[kmeans_age['cluster_s']==2].groupby(['ages_y','pd_nm_y'])['cust_y'].count().sort_values(ascending=False).head(50)
# Out:
# ages_y  pd_nm_y
# 40      일반스낵         85893
#         일반우유         84302
#         기타파티/팬시용품    72062
#         종량제봉투        70573
#         바나나          63053
#         두부류          58898
#         일반계란         50767
#         일반요구르트       49811
# 30      기타파티/팬시용품    48931
#         종량제봉투        46536
# 40      수입맥주         46078
#         떠먹는요구르트      44454
# 30      일반스낵         43912
#         일반우유         43370
# 40      감자스낵         42425
# 50      기타파티/팬시용품    40814
#         일반우유         40267
# 40      옥수수스낵        39269
#         가공우유         39153
# 50      바나나          39094
# 40      마시는요구르트      37837
#         샐러드류         37240
#         커피음료         37200
# 50      두부류          37185
# 30      수입맥주         37037
# 50      일반스낵         35263
# 30      여성패딩         34961
#         바나나          34475
# 50      종량제봉투        34092
# 40      고추           33311
#         과일음료         32015
#         쿠키           31062
#         젤리           30375
# ...

# %%
kmeans_age[kmeans_age['cluster_s']==2].groupby(['ages_y','pd_nm_y'])["buy_am"].sum().sort_values(ascending=False).head(50)
# Out:
# ages_y  pd_nm_y
# 30      여성패딩         2.819516e+09
#         여성스니커즈       1.309421e+09
# 40      기타패션잡화       1.248980e+09
#         남성시계         1.132580e+09
# 30      여성가방액세서리     1.018228e+09
#         기타패션잡화       9.850808e+08
#         여성숄더백        8.934425e+08
# 40      여성가방액세서리     8.246095e+08
#         여성티셔츠/탑      6.400033e+08
#         기타여성의류아우터    5.881545e+08
# 30      여성토트백        5.862668e+08
# 40      여성숄더백        5.830696e+08
#         여성토트백        5.706597e+08
#         기타여성의류세트     5.542262e+08
# 50      여성재킷         4.929681e+08
# 30      남성시계         4.778766e+08
# 40      기타보석류        4.513314e+08
#         여성재킷         4.505426e+08
# 50      기타여성의류아우터    4.500242e+08
# 40      여성원피스        4.252111e+08
# 50      남성시계         4.196222e+08
# 40      반지           4.189560e+08
# 50      여성토트백        3.766644e+08
#         여성티셔츠/탑      3.563964e+08
# 40      일반계란         3.434342e+08
#         여성코트         3.384329e+08
#         일반우유         3.216136e+08
# ...

# %% [markdown]
# ## 온라인/오프라인

# %%
elbow(cus_on_off.drop(['buy_am','de_dt','de_hr','buy_ct'],axis=1),10)
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %%
kmeans = KMeans(n_clusters=3, random_state=1234)
kmeans.fit(cus_on_off.drop(['buy_am','de_dt','de_hr','buy_ct'],axis=1))
centers_s = kmeans.cluster_centers_ 
pred_s = kmeans.predict(cus_on_off.drop(['buy_am','de_dt','de_hr','buy_ct'],axis=1))

# %%
cus_on_off['cluster'] = pred_s 
cus_on_off
# Out:
#           cust  chnl_dv  pd_c  pd_nm  clac_hlv_nm  clac_mcls_nm    buy_am  \
# 0            0        1   776    336           28            55   59000.0
# 1            0        1   776    336           28            55   19000.0
# 2            1        1   776    336           28            55  239000.0
# 3            4        1   776    336           28            55  179000.0
# 4            6        1   776    336           28            55    3000.0
# ...        ...      ...   ...    ...          ...           ...       ...
# 4381738  23211        1   994    736           35           150  139000.0
# 4381739  23802        2   916    652           31           273  199000.0
# 4381740  26550        2   916    652           31           273  187050.0
# 4381741  25021        1  1058    762           37            89  800000.0
# 4381742  25970        2   441   1504           19           129   49500.0
#
#             de_dt  de_hr  buy_ct  cluster
# ...

# %% [markdown]
# ### scaling

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import MinMaxScaler 
minmax_scaler = MinMaxScaler() 
scaled_df = pd.DataFrame(minmax_scaler.fit_transform(cus_on_off.drop(['buy_am','de_dt','de_hr','buy_ct'],axis=1)), columns=cus_on_off.drop(['buy_am','de_dt','de_hr','buy_ct'],axis=1).columns)

# %%
kmeans.fit(scaled_df)
centers_s = kmeans.cluster_centers_ 
pred_s = kmeans.predict(scaled_df)

# %%
cus_on_off['cluster_s'] = pred_s 
cus_on_off
# Out:
#           cust  chnl_dv  pd_c  pd_nm  clac_hlv_nm  clac_mcls_nm    buy_am  \
# 0            0        1   776    336           28            55   59000.0
# 1            0        1   776    336           28            55   19000.0
# 2            1        1   776    336           28            55  239000.0
# 3            4        1   776    336           28            55  179000.0
# 4            6        1   776    336           28            55    3000.0
# ...        ...      ...   ...    ...          ...           ...       ...
# 4381738  23211        1   994    736           35           150  139000.0
# 4381739  23802        2   916    652           31           273  199000.0
# 4381740  26550        2   916    652           31           273  187050.0
# 4381741  25021        1  1058    762           37            89  800000.0
# 4381742  25970        2   441   1504           19           129   49500.0
#
#             de_dt  de_hr  buy_ct  cluster  cluster_s
# ...

# %%
kmeans_onoff = pd.merge(cus_on_off, cus_on_off1, on=['buy_am','de_dt','de_hr','buy_ct']).drop(['cust_x','chnl_dv_x','pd_c_x','pd_nm_x','clac_hlv_nm_x','clac_mcls_nm_x'],axis=1)
kmeans_onoff
# Out:
#             buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 0          59000.0  20210116     18       1        2          0  M000034966
# 1          19000.0  20210116     18       1        2          0  M000034966
# 2          19000.0  20210116     18       1        2          0  M602016613
# 3          19000.0  20210116     18       1        2          0  M296951926
# 4          19000.0  20210116     18       1        1          0  M000034966
# ...            ...       ...    ...     ...      ...        ...         ...
# 26570151    7110.0  20210320     12       1        0          1  M854668364
# 26570152  139000.0  20210430     10       1        0          1  M858719851
# 26570153  199000.0  20210712     21       1        0          1  M880029153
# 26570154  187050.0  20210523      8       1        0          1  M986268092
# 26570155  800000.0  20210828     17       8        0          1  M926014276
#
# ...

# %%
kmeans_onoff[kmeans_onoff['cluster'] == 0]
# Out:
#             buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 16          3000.0  20210129     14       3        0          1  M000419293
# 17          3000.0  20210129     14       3        0          1  M690777930
# 18          3000.0  20210129     14       3        0          1  M064003542
# 19          3000.0  20210129     14       3        0          1  M453490534
# 30           500.0  20210129     14       5        0          1  M000419293
# ...            ...       ...    ...     ...      ...        ...         ...
# 26570151    7110.0  20210320     12       1        0          1  M854668364
# 26570152  139000.0  20210430     10       1        0          1  M858719851
# 26570153  199000.0  20210712     21       1        0          1  M880029153
# 26570154  187050.0  20210523      8       1        0          1  M986268092
# 26570155  800000.0  20210828     17       8        0          1  M926014276
#
# ...

# %%
kmeans_onoff[kmeans_onoff['cluster'] == 0].groupby('chnl_dv_y')['cust_y'].count()
# Out:
# chnl_dv_y
# 1    8021475
# 2     819288
# Name: cust_y, dtype: int64

# %%
kmeans_onoff[kmeans_onoff['cluster']==0].groupby(['chnl_dv_y','pd_nm_y'])['cust_y'].count().sort_values(ascending=False)
# Out:
# chnl_dv_y  pd_nm_y
# 1          일반스낵         268106
#            기타파티/팬시용품    216854
#            바나나          175032
#            옥수수스낵        129991
#            일반우유         120483
#                          ...
# 2          유아공부상/디딤대         1
#            파충류용품             1
#            배드민턴화             1
#            버섯선물세트            1
# 1          배드민턴복             1
# Name: cust_y, Length: 3132, dtype: int64

# %%
kmeans_onoff[kmeans_onoff['cluster']==0].groupby(['chnl_dv_y','pd_nm_y'])["buy_am"].sum().sort_values(ascending=False).head(1000)
# Out:
# chnl_dv_y  pd_nm_y
# 2          영화/문화모바일상품권    1.528093e+09
# 1          기타남성의류세트       1.398780e+09
#            기타패션잡화         1.053831e+09
#            여성가방액세서리       1.019299e+09
#            여성숄더백          1.009112e+09
#                               ...
# 2          데스크탑/올인원PC     8.091880e+06
# 1          분유             8.053719e+06
#            국산돼지등심         8.052511e+06
#            국산돼지뒷다리        8.043971e+06
# 2          방울토마토          8.018064e+06
# Name: buy_am, Length: 1000, dtype: float64

# %%
kmeans_onoff[kmeans_onoff['cluster'] == 1]
# Out:
#              buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 4           19000.0  20210116     18       1        1          0  M000034966
# 5           19000.0  20210116     18       1        1          0  M602016613
# 6           19000.0  20210116     18       1        1          0  M296951926
# 24           3000.0  20210129     14       3        1          0  M000419293
# 25           3000.0  20210129     14       3        1          0  M690777930
# ...             ...       ...    ...     ...      ...        ...         ...
# 26570118    25000.0  20210105      3       5        1          0  M504707751
# 26570120    11400.0  20210407     20       1        1          0  M530779190
# 26570122    95700.0  20211220     13       3        1          0  M557822429
# 26570124    45820.0  20210705     11       1        1          2  M570817832
# 26570126  3605000.0  20210117     16       1        1          0  M641790940
#
# ...

# %%
kmeans_onoff[kmeans_onoff['cluster'] == 1].groupby('chnl_dv_y')['cust_y'].count()
# Out:
# chnl_dv_y
# 1    7948861
# 2     865741
# Name: cust_y, dtype: int64

# %%
kmeans_onoff[kmeans_onoff['cluster']==1].groupby(['chnl_dv_y','pd_nm_y'])['cust_y'].count().sort_values(ascending=False)
# Out:
# chnl_dv_y  pd_nm_y
# 1          일반스낵         264977
#            기타파티/팬시용품    215285
#            바나나          174158
#            옥수수스낵        126862
#            일반우유         119016
#                          ...
# 2          침실가구세트            1
#            카드                1
#            썰매류               1
#            기타자전거             1
#            남성방한화             1
# Name: cust_y, Length: 3148, dtype: int64

# %%
kmeans_onoff[kmeans_onoff['cluster']==1].groupby(['chnl_dv_y','pd_nm_y'])["buy_am"].sum().sort_values(ascending=False).head(1000)
# Out:
# chnl_dv_y  pd_nm_y
# 2          여성패딩           2.765952e+09
#            영화/문화모바일상품권    1.700928e+09
#            여성스니커즈         1.341199e+09
# 1          기타패션잡화         1.306802e+09
#            기타남성의류세트       1.270550e+09
#                               ...
# 2          콩나물            8.070090e+06
# 1          유아동캐쥬얼스포츠양말    8.047830e+06
#            시계             8.032940e+06
#            벙거지            8.021400e+06
# 2          페이셜클렌저         8.013380e+06
# Name: buy_am, Length: 1000, dtype: float64

# %%
kmeans_onoff[kmeans_onoff['cluster'] == 2]
# Out:
#             buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 0          59000.0  20210116     18       1        2          0  M000034966
# 1          19000.0  20210116     18       1        2          0  M000034966
# 2          19000.0  20210116     18       1        2          0  M602016613
# 3          19000.0  20210116     18       1        2          0  M296951926
# 7          19000.0  20210116     18       1        2          2  M000034966
# ...            ...       ...    ...     ...      ...        ...         ...
# 26570035     130.0  20210126     19       1        2          0  M296821100
# 26570036    1420.0  20210908     17       1        2          0  M299016876
# 26570037  180000.0  20210922     15       1        2          0  M305279155
# 26570040  151570.0  20210409     12       1        2          0  M320192165
# 26570041  151570.0  20210412     12       1        2          0  M320192165
#
# ...

# %%
kmeans_onoff[kmeans_onoff['cluster'] == 2].groupby('chnl_dv_y')['cust_y'].count()
# Out:
# chnl_dv_y
# 1    8100516
# 2     814275
# Name: cust_y, dtype: int64

# %%
kmeans_onoff[kmeans_onoff['cluster']==2].groupby(['chnl_dv_y','pd_nm_y'])['cust_y'].count().sort_values(ascending=False)
# Out:
# chnl_dv_y  pd_nm_y
# 1          일반스낵         267485
#            기타파티/팬시용품    226390
#            바나나          176981
#            옥수수스낵        130090
#            일반우유         122447
#                          ...
#            기타스키/보드용품         1
#            기타보험              1
# 2          기타축구용품            1
#            기타자동차정비용품         1
#            기타패션잡화            1
# Name: cust_y, Length: 3164, dtype: int64

# %%
kmeans_onoff[kmeans_onoff['cluster']==2].groupby(['chnl_dv_y','pd_nm_y'])["buy_am"].sum().sort_values(ascending=False).head(1000)
# Out:
# chnl_dv_y  pd_nm_y
# 2          영화/문화모바일상품권    1.945992e+09
# 1          기타패션잡화         1.566998e+09
#            기타남성의류세트       1.281849e+09
#            여성숄더백          1.184283e+09
#            남성시계           1.039620e+09
#                               ...
# 2          치약             8.112120e+06
#            남성청바지          8.106780e+06
# 1          즉석누룽지          8.103386e+06
#            여성수영복          8.102490e+06
#            헤어에센스          8.049090e+06
# Name: buy_am, Length: 1000, dtype: float64

# %%
kmeans_onoff[kmeans_onoff['cluster_s'] == 0]
# Out:
#              buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 0           59000.0  20210116     18       1        2          0  M000034966
# 1           19000.0  20210116     18       1        2          0  M000034966
# 2           19000.0  20210116     18       1        2          0  M602016613
# 3           19000.0  20210116     18       1        2          0  M296951926
# 4           19000.0  20210116     18       1        1          0  M000034966
# ...             ...       ...    ...     ...      ...        ...         ...
# 26570116    13900.0  20210405     21       1        1          0  M490677749
# 26570118    25000.0  20210105      3       5        1          0  M504707751
# 26570120    11400.0  20210407     20       1        1          0  M530779190
# 26570122    95700.0  20211220     13       3        1          0  M557822429
# 26570126  3605000.0  20210117     16       1        1          0  M641790940
#
# ...

# %%
kmeans_onoff[kmeans_onoff['cluster_s'] == 0].groupby('chnl_dv_y')['cust_y'].count()
# Out:
# chnl_dv_y
# 1    8211769
# 2     901398
# Name: cust_y, dtype: int64

# %%
kmeans_onoff[kmeans_onoff['cluster_s']==0].groupby(['chnl_dv_y','pd_nm_y'])['cust_y'].count().sort_values(ascending=False)
# Out:
# chnl_dv_y  pd_nm_y
# 1          일반스낵                  350026
#            기타파티/팬시용품             246008
#            바나나                   202159
#            옥수수스낵                 173036
#            감자스낵                  131583
#                                   ...
# 2          기타테니스용품                    1
#            비디오게임액세서리                  1
#            인라인/스케이트보드/킥보드안전용품         1
#            파쇄기                        1
#            매실                         1
# Name: cust_y, Length: 3042, dtype: int64

# %%
kmeans_onoff[kmeans_onoff['cluster_s']==0].groupby(['chnl_dv_y','pd_nm_y'])["buy_am"].sum().sort_values(ascending=False).head(1000)
# Out:
# chnl_dv_y  pd_nm_y
# 2          영화/문화모바일상품권    3.630343e+09
# 1          기타남성의류세트       2.089573e+09
#            임대매출           1.174322e+09
#            남성티셔츠          1.170921e+09
#            침대             9.545243e+08
#                               ...
# 2          삼계탕용닭          6.201920e+06
# 1          캐쥬얼백팩          6.182900e+06
#            일반매트           6.160400e+06
# 2          망고             6.145240e+06
#            남성등산바지         6.125300e+06
# Name: buy_am, Length: 1000, dtype: float64

# %%
kmeans_onoff[kmeans_onoff['cluster_s'] == 1]
# Out:
#             buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 16          3000.0  20210129     14       3        0          1  M000419293
# 17          3000.0  20210129     14       3        0          1  M690777930
# 18          3000.0  20210129     14       3        0          1  M064003542
# 19          3000.0  20210129     14       3        0          1  M453490534
# 30           500.0  20210129     14       5        0          1  M000419293
# ...            ...       ...    ...     ...      ...        ...         ...
# 26570151    7110.0  20210320     12       1        0          1  M854668364
# 26570152  139000.0  20210430     10       1        0          1  M858719851
# 26570153  199000.0  20210712     21       1        0          1  M880029153
# 26570154  187050.0  20210523      8       1        0          1  M986268092
# 26570155  800000.0  20210828     17       8        0          1  M926014276
#
# ...

# %%
kmeans_onoff[kmeans_onoff['cluster_s'] == 1].groupby('chnl_dv_y')['cust_y'].count()
# Out:
# chnl_dv_y
# 1    8027824
# 2     819611
# Name: cust_y, dtype: int64

# %%
kmeans_onoff[kmeans_onoff['cluster_s']==1].groupby(['chnl_dv_y','pd_nm_y'])['cust_y'].count().sort_values(ascending=False)
# Out:
# chnl_dv_y  pd_nm_y
# 1          일반스낵         268199
#            기타파티/팬시용품    216995
#            바나나          175064
#            옥수수스낵        130026
#            일반우유         120536
#                          ...
#            여성골프패딩            1
#            스포츠선글라스           1
#            체온계               1
# 2          기타난방가전            1
# 1          배드민턴복             1
# Name: cust_y, Length: 3133, dtype: int64

# %%
kmeans_onoff[kmeans_onoff['cluster_s']==1].groupby(['chnl_dv_y','pd_nm_y'])["buy_am"].sum().sort_values(ascending=False).head(1000)
# Out:
# chnl_dv_y  pd_nm_y
# 2          영화/문화모바일상품권      1.528093e+09
# 1          기타남성의류세트         1.399899e+09
#            기타패션잡화           1.054490e+09
#            여성가방액세서리         1.019299e+09
#            여성숄더백            1.009137e+09
#                                 ...
# 2          남성스웨트셔츠/후드/집업    8.120060e+06
#            볶음반찬             8.110820e+06
# 1          이유식용품            8.094640e+06
# 2          데스크탑/올인원PC       8.091880e+06
# 1          분유               8.062619e+06
# Name: buy_am, Length: 1000, dtype: float64

# %%
kmeans_onoff[kmeans_onoff['cluster_s'] == 2]
# Out:
#             buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 7          19000.0  20210116     18       1        2          2  M000034966
# 8          19000.0  20210116     18       1        2          2  M602016613
# 9          19000.0  20210116     18       1        2          2  M296951926
# 66         29000.0  20210808     19       1        2          2  M001694463
# 67         29000.0  20210808     19       1        2          2  M704962495
# ...            ...       ...    ...     ...      ...        ...         ...
# 26570111    5850.0  20210106      9       1        1          2  M533330698
# 26570112   12500.0  20211228     18       1        1          2  M481734389
# 26570113   10500.0  20211228     18       1        1          2  M481734389
# 26570117  119200.0  20210605     19       1        1          2  M500789827
# 26570124   45820.0  20210705     11       1        1          2  M570817832
#
# ...

# %%
kmeans_onoff[kmeans_onoff['cluster_s'] == 2].groupby('chnl_dv_y')['cust_y'].count()
# Out:
# chnl_dv_y
# 1    7831259
# 2     778295
# Name: cust_y, dtype: int64

# %%
kmeans_onoff[kmeans_onoff['cluster_s']==2].groupby(['chnl_dv_y','pd_nm_y'])['cust_y'].count().sort_values(ascending=False)
# Out:
# chnl_dv_y  pd_nm_y
# 1          기타파티/팬시용품     195526
#            일반스낵          182343
#            종량제봉투         175983
#            일반우유          160704
#            바나나           148948
#                           ...
# 2          남성골프베스트            1
#            남성골프니트/가디건         1
#            꽃게                 1
# 1          광택제                1
# 2          기타탁구용품             1
# Name: cust_y, Length: 3041, dtype: int64

# %%
kmeans_onoff[kmeans_onoff['cluster_s']==2].groupby(['chnl_dv_y','pd_nm_y'])["buy_am"].sum().sort_values(ascending=False).head(1000)
# Out:
# chnl_dv_y  pd_nm_y
# 1          기타패션잡화      2.784430e+09
# 2          여성패딩        2.778646e+09
# 1          여성가방액세서리    2.241931e+09
#            남성시계        2.158998e+09
#            여성숄더백       1.995394e+09
#                            ...
# 2          아이케어        7.633000e+06
# 1          락스          7.610270e+06
# 2          레고          7.594300e+06
# 1          새우          7.553650e+06
# 2          메이크업세트      7.536700e+06
# Name: buy_am, Length: 1000, dtype: float64

# %% [markdown]
# ## 시간대

# %%
elbow(cus_time.drop(['buy_am','de_dt','buy_ct'],axis=1),10)
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %%
kmeans = KMeans(n_clusters=3, random_state=1234)
kmeans.fit(cus_time.drop(['buy_am','de_dt','buy_ct'],axis=1))
centers_s = kmeans.cluster_centers_ 
pred_s = kmeans.predict(cus_time.drop(['buy_am','de_dt','buy_ct'],axis=1))

# %%
cus_time['cluster'] = pred_s 
cus_time
# Out:
#           cust  pd_c  pd_nm  clac_hlv_nm  clac_mcls_nm    buy_am     de_dt  \
# 0            0   776    336           28            55   59000.0  20210116
# 1            0   776    336           28            55   19000.0  20210116
# 2            1   776    336           28            55  239000.0  20210805
# 3            4   776    336           28            55  179000.0  20210403
# 4            6   776    336           28            55    3000.0  20210129
# ...        ...   ...    ...          ...           ...       ...       ...
# 4381738  23211   994    736           35           150  139000.0  20210430
# 4381739  23802   916    652           31           273  199000.0  20210712
# 4381740  26550   916    652           31           273  187050.0  20210523
# 4381741  25021  1058    762           37            89  800000.0  20210828
# 4381742  25970   441   1504           19           129   49500.0  20210220
#
#          de_hr  buy_ct  cluster
# 0           18       1        2
# ...

# %% [markdown]
# ### scaling

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import MinMaxScaler 
minmax_scaler = MinMaxScaler() 
scaled_df = pd.DataFrame(minmax_scaler.fit_transform(cus_time.drop(['buy_am','de_dt','de_hr','buy_ct'],axis=1)), columns=cus_time.drop(['buy_am','de_dt','de_hr','buy_ct'],axis=1).columns)

# %%
kmeans.fit(scaled_df)
centers_s = kmeans.cluster_centers_ 
pred_s = kmeans.predict(scaled_df)

# %%
cus_time['cluster_s'] = pred_s 
cus_time
# Out:
#           cust  pd_c  pd_nm  clac_hlv_nm  clac_mcls_nm    buy_am     de_dt  \
# 0            0   776    336           28            55   59000.0  20210116
# 1            0   776    336           28            55   19000.0  20210116
# 2            1   776    336           28            55  239000.0  20210805
# 3            4   776    336           28            55  179000.0  20210403
# 4            6   776    336           28            55    3000.0  20210129
# ...        ...   ...    ...          ...           ...       ...       ...
# 4381738  23211   994    736           35           150  139000.0  20210430
# 4381739  23802   916    652           31           273  199000.0  20210712
# 4381740  26550   916    652           31           273  187050.0  20210523
# 4381741  25021  1058    762           37            89  800000.0  20210828
# 4381742  25970   441   1504           19           129   49500.0  20210220
#
#          de_hr  buy_ct  cluster  cluster_s
# ...

# %%
kmeans_time = pd.merge(cus_time, cus_time1, on=['buy_am','de_dt','de_hr','buy_ct']).drop(['cust_x','pd_c_x','pd_nm_x','clac_hlv_nm_x','clac_mcls_nm_x'],axis=1)
kmeans_time
# Out:
#             buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 0          59000.0  20210116     18       1        2          1  M000034966
# 1          19000.0  20210116     18       1        2          1  M000034966
# 2          19000.0  20210116     18       1        2          1  M602016613
# 3          19000.0  20210116     18       1        2          1  M296951926
# 4          19000.0  20210116     18       1        1          1  M000034966
# ...            ...       ...    ...     ...      ...        ...         ...
# 26570151    7110.0  20210320     12       1        0          0  M854668364
# 26570152  139000.0  20210430     10       1        0          0  M858719851
# 26570153  199000.0  20210712     21       1        0          0  M880029153
# 26570154  187050.0  20210523      8       1        0          0  M986268092
# 26570155  800000.0  20210828     17       8        0          0  M926014276
#
# ...

# %%
kmeans_time[kmeans_time['cluster'] == 0]
# Out:
#             buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 16          3000.0  20210129     14       3        0          0  M000419293
# 17          3000.0  20210129     14       3        0          0  M690777930
# 18          3000.0  20210129     14       3        0          0  M064003542
# 19          3000.0  20210129     14       3        0          0  M453490534
# 30           500.0  20210129     14       5        0          0  M000419293
# ...            ...       ...    ...     ...      ...        ...         ...
# 26570151    7110.0  20210320     12       1        0          0  M854668364
# 26570152  139000.0  20210430     10       1        0          0  M858719851
# 26570153  199000.0  20210712     21       1        0          0  M880029153
# 26570154  187050.0  20210523      8       1        0          0  M986268092
# 26570155  800000.0  20210828     17       8        0          0  M926014276
#
# ...

# %%
kmeans_time[kmeans_time['cluster'] == 0].groupby('de_hr')['cust_y'].count() / len(kmeans_time[kmeans_time['cluster'] == 0])
# Out:
# de_hr
# 0     0.002296
# 1     0.000825
# 2     0.000346
# 3     0.000196
# 4     0.000123
# 5     0.000194
# 6     0.000447
# 7     0.001294
# 8     0.002706
# 9     0.004806
# 10    0.022298
# 11    0.051118
# 12    0.064743
# 13    0.063264
# 14    0.076499
# 15    0.100056
# 16    0.118585
# 17    0.131617
# 18    0.124251
# 19    0.094595
# 20    0.077341
# 21    0.044848
# 22    0.014380
# 23    0.003173
# Name: cust_y, dtype: float64

# %%
kmeans_time[kmeans_time['cluster']==0].groupby(['de_hr','pd_nm_y'])['cust_y'].count().sort_values(ascending=False)
# Out:
# de_hr  pd_nm_y
# 18     일반스낵                 38624
# 17     일반스낵                 37245
# 16     일반스낵                 31515
# 19     일반스낵                 29952
# 17     기타파티/팬시용품            28663
#                             ...
# 3      유아동스포츠스웨트셔츠/후드/집업        1
# 19     유아동슬립온                   1
# 3      유아동스니커즈                  1
# 9      축구복                      1
# 17     시계부속품                    1
# Name: cust_y, Length: 26578, dtype: int64

# %%
kmeans_time[kmeans_time['cluster']==0].groupby(['de_hr','pd_nm_y'])["buy_am"].sum().sort_values(ascending=False).head(1000)
# Out:
# de_hr  pd_nm_y
# 10     영화/문화모바일상품권    421493500.0
# 16     여성코트           380837080.0
# 13     남성백팩           364035300.0
# 12     남성스니커즈         354654740.0
#        영화/문화모바일상품권    350931500.0
#                          ...
# 16     복숭아             15286980.0
# 14     수입맥주            15278220.0
# 16     물리치료/의료기용품      15256000.0
# 12     골프필드용품          15240000.0
# 16     멀티형에어컨          15221000.0
# Name: buy_am, Length: 1000, dtype: float64

# %%
kmeans_time[kmeans_time['cluster'] == 1]
# Out:
#              buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 4           19000.0  20210116     18       1        1          1  M000034966
# 5           19000.0  20210116     18       1        1          1  M602016613
# 6           19000.0  20210116     18       1        1          1  M296951926
# 24           3000.0  20210129     14       3        1          1  M000419293
# 25           3000.0  20210129     14       3        1          1  M690777930
# ...             ...       ...    ...     ...      ...        ...         ...
# 26570118    25000.0  20210105      3       5        1          1  M504707751
# 26570120    11400.0  20210407     20       1        1          1  M530779190
# 26570122    95700.0  20211220     13       3        1          1  M557822429
# 26570124    45820.0  20210705     11       1        1          2  M570817832
# 26570126  3605000.0  20210117     16       1        1          1  M641790940
#
# ...

# %%
kmeans_time[kmeans_time['cluster'] == 1].groupby('de_hr')['cust_y'].count() / len(kmeans_time[kmeans_time['cluster'] == 0])
# Out:
# de_hr
# 0     0.001837
# 1     0.000811
# 2     0.000393
# 3     0.000275
# 4     0.000176
# 5     0.000243
# 6     0.000438
# 7     0.001320
# 8     0.002665
# 9     0.004626
# 10    0.020837
# 11    0.049244
# 12    0.064387
# 13    0.064962
# 14    0.076537
# 15    0.103654
# 16    0.122230
# 17    0.131711
# 18    0.120898
# 19    0.091924
# 20    0.076207
# 21    0.044007
# 22    0.014202
# 23    0.003456
# Name: cust_y, dtype: float64

# %%
kmeans_time[kmeans_time['cluster']==1].groupby(['de_hr','pd_nm_y'])['cust_y'].count().sort_values(ascending=False)

# %%
kmeans_time[kmeans_time['cluster']==1].groupby(['de_hr','pd_nm_y'])["buy_am"].sum().sort_values(ascending=False).head(1000)
# Out:
# de_hr  pd_nm_y
# 15     여성패딩           1.653635e+09
# 16     여성패딩           6.621639e+08
# 10     영화/문화모바일상품권    5.222045e+08
# 13     여성패딩           4.199006e+08
# 12     여성스니커즈         4.187318e+08
#                           ...
#        샴푸             1.538089e+07
# 18     여성시계           1.537740e+07
# 11     떠먹는요구르트        1.537642e+07
# 19     일반시리얼          1.537242e+07
# 17     태블릿PC          1.537090e+07
# Name: buy_am, Length: 1000, dtype: float64

# %%
kmeans_time[kmeans_time['cluster'] == 2]
# Out:
#             buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 0          59000.0  20210116     18       1        2          1  M000034966
# 1          19000.0  20210116     18       1        2          1  M000034966
# 2          19000.0  20210116     18       1        2          1  M602016613
# 3          19000.0  20210116     18       1        2          1  M296951926
# 7          19000.0  20210116     18       1        2          2  M000034966
# ...            ...       ...    ...     ...      ...        ...         ...
# 26570035     130.0  20210126     19       1        2          1  M296821100
# 26570036    1420.0  20210908     17       1        2          1  M299016876
# 26570037  180000.0  20210922     15       1        2          1  M305279155
# 26570040  151570.0  20210409     12       1        2          1  M320192165
# 26570041  151570.0  20210412     12       1        2          1  M320192165
#
# ...

# %%
kmeans_time[kmeans_time['cluster'] == 2].groupby('de_hr')['cust_y'].count() / len(kmeans_time[kmeans_time['cluster'] == 0])
# Out:
# de_hr
# 0     0.001949
# 1     0.001080
# 2     0.000451
# 3     0.000253
# 4     0.000156
# 5     0.000200
# 6     0.000627
# 7     0.001538
# 8     0.002676
# 9     0.004931
# 10    0.021546
# 11    0.051150
# 12    0.066954
# 13    0.063038
# 14    0.077788
# 15    0.100078
# 16    0.120190
# 17    0.130312
# 18    0.123484
# 19    0.096216
# 20    0.079972
# 21    0.046441
# 22    0.014006
# 23    0.003338
# Name: cust_y, dtype: float64

# %%
kmeans_time[kmeans_time['cluster']==2].groupby(['de_hr','pd_nm_y'])['cust_y'].count().sort_values(ascending=False)
# Out:
# de_hr  pd_nm_y
# 18     일반스낵         37155
# 17     일반스낵         36791
# 16     일반스낵         31959
#        기타파티/팬시용품    30649
# 19     일반스낵         30285
#                     ...
# 8      낚시용품             1
#        낙지               1
#        꽃게               1
#        깨                1
# 23     힙색/사이드백          1
# Name: cust_y, Length: 26869, dtype: int64

# %%
kmeans_time[kmeans_time['cluster']==2].groupby(['de_hr','pd_nm_y'])["buy_am"].sum().sort_values(ascending=False).head(1000)
# Out:
# de_hr  pd_nm_y
# 10     영화/문화모바일상품권    534541500.0
# 12     영화/문화모바일상품권    417689000.0
#        여성숄더백          351309800.0
# 9      영화/문화모바일상품권    290374400.0
# 11     영화/문화모바일상품권    278607200.0
#                          ...
# 19     기능성우유           15537934.0
# 11     마시는요구르트         15532845.0
# 16     남성캐주얼바지         15517980.0
# 14     스탠드형에어컨         15496600.0
# 13     어묵              15480790.0
# Name: buy_am, Length: 1000, dtype: float64

# %%
kmeans_time[kmeans_time['cluster_s'] == 0]
# Out:
#             buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 16          3000.0  20210129     14       3        0          0  M000419293
# 17          3000.0  20210129     14       3        0          0  M690777930
# 18          3000.0  20210129     14       3        0          0  M064003542
# 19          3000.0  20210129     14       3        0          0  M453490534
# 30           500.0  20210129     14       5        0          0  M000419293
# ...            ...       ...    ...     ...      ...        ...         ...
# 26570151    7110.0  20210320     12       1        0          0  M854668364
# 26570152  139000.0  20210430     10       1        0          0  M858719851
# 26570153  199000.0  20210712     21       1        0          0  M880029153
# 26570154  187050.0  20210523      8       1        0          0  M986268092
# 26570155  800000.0  20210828     17       8        0          0  M926014276
#
# ...

# %%
kmeans_time[kmeans_time['cluster_s'] == 0].groupby('de_hr')['cust_y'].count() / len(kmeans_time[kmeans_time['cluster_s'] == 0])
# Out:
# de_hr
# 0     0.002295
# 1     0.000825
# 2     0.000346
# 3     0.000196
# 4     0.000123
# 5     0.000194
# 6     0.000448
# 7     0.001293
# 8     0.002705
# 9     0.004803
# 10    0.022292
# 11    0.051118
# 12    0.064748
# 13    0.063282
# 14    0.076530
# 15    0.100080
# 16    0.118590
# 17    0.131612
# 18    0.124242
# 19    0.094583
# 20    0.077311
# 21    0.044834
# 22    0.014380
# 23    0.003172
# Name: cust_y, dtype: float64

# %%
kmeans_time[kmeans_time['cluster_s']==0].groupby(['de_hr','pd_nm_y'])['cust_y'].count().sort_values(ascending=False)
# Out:
# de_hr  pd_nm_y
# 18     일반스낵         38649
# 17     일반스낵         37258
# 16     일반스낵         31529
# 19     일반스낵         29953
# 17     기타파티/팬시용품    28698
#                     ...
# 7      기타아로마용품          1
#        기타분말류            1
# 20     자전거수리부품          1
#        잣                1
# 8      물엿/시럽            1
# Name: cust_y, Length: 26599, dtype: int64

# %%
kmeans_time[kmeans_time['cluster_s']==0].groupby(['de_hr','pd_nm_y'])["buy_am"].sum().sort_values(ascending=False).head(1000)
# Out:
# de_hr  pd_nm_y
# 10     영화/문화모바일상품권    421493500.0
# 16     여성코트           380837080.0
# 13     남성백팩           364035300.0
# 12     남성스니커즈         354934540.0
#        영화/문화모바일상품권    350931500.0
#                          ...
# 8      냄비              15400000.0
# 14     안마의자            15380000.0
# 11     남성골프티셔츠         15337110.0
# 15     커피/음료           15333400.0
# 14     수입맥주            15318720.0
# Name: buy_am, Length: 1000, dtype: float64

# %%
kmeans_time[kmeans_time['cluster_s'] == 1]
# Out:
#              buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 0           59000.0  20210116     18       1        2          1  M000034966
# 1           19000.0  20210116     18       1        2          1  M000034966
# 2           19000.0  20210116     18       1        2          1  M602016613
# 3           19000.0  20210116     18       1        2          1  M296951926
# 4           19000.0  20210116     18       1        1          1  M000034966
# ...             ...       ...    ...     ...      ...        ...         ...
# 26570116    13900.0  20210405     21       1        1          1  M490677749
# 26570118    25000.0  20210105      3       5        1          1  M504707751
# 26570120    11400.0  20210407     20       1        1          1  M530779190
# 26570122    95700.0  20211220     13       3        1          1  M557822429
# 26570126  3605000.0  20210117     16       1        1          1  M641790940
#
# ...

# %%
kmeans_time[kmeans_time['cluster_s'] == 1].groupby('de_hr')['cust_y'].count() / len(kmeans_time[kmeans_time['cluster_s'] == 0])
# Out:
# de_hr
# 0     0.002309
# 1     0.001126
# 2     0.000441
# 3     0.000292
# 4     0.000193
# 5     0.000245
# 6     0.000591
# 7     0.001541
# 8     0.002921
# 9     0.005652
# 10    0.022724
# 11    0.049812
# 12    0.065408
# 13    0.063366
# 14    0.077384
# 15    0.102395
# 16    0.122782
# 17    0.133572
# 18    0.124235
# 19    0.097810
# 20    0.085722
# 21    0.049758
# 22    0.015995
# 23    0.003773
# Name: cust_y, dtype: float64

# %%
kmeans_time[kmeans_time['cluster_s']==1].groupby(['de_hr','pd_nm_y'])['cust_y'].count().sort_values(ascending=False)
# Out:
# de_hr  pd_nm_y
# 17     일반스낵         48300
# 18     일반스낵         47056
# 16     일반스낵         41231
# 19     일반스낵         39325
# 20     일반스낵         35424
#                     ...
# 5      칼/가위             1
#        철물공구             1
#        채소즙              1
#        채소병통조림           1
# 13     남성스포츠화부속품        1
# Name: cust_y, Length: 24669, dtype: int64

# %%
kmeans_time[kmeans_time['cluster_s']==1].groupby(['de_hr','pd_nm_y'])["buy_am"].sum().sort_values(ascending=False).head(1000)
# Out:
# de_hr  pd_nm_y
# 10     영화/문화모바일상품권    1.056560e+09
# 12     영화/문화모바일상품권    7.930565e+08
# 9      영화/문화모바일상품권    5.220788e+08
# 11     영화/문화모바일상품권    4.919988e+08
# 15     기타남성의류세트       2.898802e+08
#                           ...
#        공기청정기          1.540011e+07
# 14     기타모바일기기        1.537266e+07
# 15     레드와인           1.534574e+07
# 17     볶음반찬           1.531508e+07
# 11     기타냉장간편식        1.528792e+07
# Name: buy_am, Length: 1000, dtype: float64

# %%
kmeans_time[kmeans_time['cluster_s'] == 2]
# Out:
#             buy_am     de_dt  de_hr  buy_ct  cluster  cluster_s      cust_y  \
# 7          19000.0  20210116     18       1        2          2  M000034966
# 8          19000.0  20210116     18       1        2          2  M602016613
# 9          19000.0  20210116     18       1        2          2  M296951926
# 66         29000.0  20210808     19       1        2          2  M001694463
# 67         29000.0  20210808     19       1        2          2  M704962495
# ...            ...       ...    ...     ...      ...        ...         ...
# 26570111    5850.0  20210106      9       1        1          2  M533330698
# 26570112   12500.0  20211228     18       1        1          2  M481734389
# 26570113   10500.0  20211228     18       1        1          2  M481734389
# 26570117  119200.0  20210605     19       1        1          2  M500789827
# 26570124   45820.0  20210705     11       1        1          2  M570817832
#
# ...

# %%
kmeans_time[kmeans_time['cluster_s'] == 2].groupby('de_hr')['cust_y'].count() / len(kmeans_time[kmeans_time['cluster_s'] == 0])
# Out:
# de_hr
# 0     0.001473
# 1     0.000764
# 2     0.000403
# 3     0.000235
# 4     0.000138
# 5     0.000197
# 6     0.000472
# 7     0.001315
# 8     0.002416
# 9     0.003897
# 10    0.019617
# 11    0.050471
# 12    0.065785
# 13    0.064476
# 14    0.076742
# 15    0.101091
# 16    0.119369
# 17    0.128168
# 18    0.119887
# 19    0.090136
# 20    0.070317
# 21    0.040605
# 22    0.012181
# 23    0.003014
# Name: cust_y, dtype: float64

# %%
kmeans_time[kmeans_time['cluster_s']==2].groupby(['de_hr','pd_nm_y'])['cust_y'].count().sort_values(ascending=False)
# Out:
# de_hr  pd_nm_y
# 18     일반스낵              26498
# 16     기타파티/팬시용품         26142
# 18     종량제봉투             26029
# 17     일반스낵              25892
#        기타파티/팬시용품         25671
#                          ...
# 11     기타DVD/홈시어터액세서리        1
# 4      놀이동산이용권               1
#        노트북                   1
#        냉동피자                  1
# 17     미술공예품                 1
# Name: cust_y, Length: 25540, dtype: int64

# %%
kmeans_time[kmeans_time['cluster_s']==2].groupby(['de_hr','pd_nm_y'])["buy_am"].sum().sort_values(ascending=False).head(1000)
# Out:
# de_hr  pd_nm_y
# 15     여성패딩       1.677316e+09
# 16     여성패딩       6.718625e+08
# 13     남성시계       4.486452e+08
#        여성패딩       4.427868e+08
# 12     여성숄더백      4.356064e+08
#                       ...
# 16     햄          1.464114e+07
# 20     콜라         1.464038e+07
# 12     소품가방       1.461520e+07
# 19     일반미        1.459959e+07
#        국산돼지삼겹살    1.459186e+07
# Name: buy_am, Length: 1000, dtype: float64

# %% [markdown]
# ## lpay

# %%
kmeans = KMeans(n_clusters=4, random_state=1234)
kmeans.fit(lpay_join)
centers_s = kmeans.cluster_centers_ 
pred_s = kmeans.predict(lpay_join)

# %%
lpay_join['cluster'] = pred_s 
lpay_join

# %%
lpay_join[lpay_join['cluster'] == 0]

# %%
lpay_join[lpay_join['cluster'] == 1]

# %%
lpay_join[lpay_join['cluster'] == 2]

# %%
lpay_join[lpay_join['cluster'] == 3]

# %% [markdown]
# ## 2030 나이대

# %%
cus_2030 = cus_merge.loc[(cus_merge['ages'] == 20) | (cus_merge['ages'] == 30), : ]

# %%
elbow(cus_2030,10)

# %%
kmeans = KMeans(n_clusters=4, random_state=1234)
kmeans.fit(cus_2030)
centers_s = kmeans.cluster_centers_ 
pred_s = kmeans.predict(cus_2030)

# %%
cus_2030['cluster'] = pred_s
cus_2030
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#           cust  ma_fem_dv  ages  zon_hlv   rct_no  chnl_dv  cop_c  br_c  pd_c  \
# 2            1          1    30       10   294245        1      0    17   776
# 9           11          0    30       10    78866        1      0    23   776
# 17          47          1    30        3  1248384        2      5  6755   776
# 18          50          1    30       15   392954        1      0    21   776
# 19          50          1    30       15   392954        1      0    21   776
# ...        ...        ...   ...      ...      ...      ...    ...   ...   ...
# ...

# %% [markdown]
# ### scaling

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import MinMaxScaler 
minmax_scaler = MinMaxScaler() 
scaled_df = pd.DataFrame(minmax_scaler.fit_transform(cus_2030), columns=cus_2030.columns)

# %%
kmeans.fit(scaled_df)
centers_s = kmeans.cluster_centers_ 
pred_s = kmeans.predict(scaled_df)

# %%
cus_2030['cluster_s'] = pred_s
cus_2030
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#           cust  ma_fem_dv  ages  zon_hlv   rct_no  chnl_dv  cop_c  br_c  pd_c  \
# 2            1          1    30       10   294245        1      0    17   776
# 9           11          0    30       10    78866        1      0    23   776
# 17          47          1    30        3  1248384        2      5  6755   776
# 18          50          1    30       15   392954        1      0    21   776
# 19          50          1    30       15   392954        1      0    21   776
# ...        ...        ...   ...      ...      ...      ...    ...   ...   ...
# ...

# %%
kmeans_2030 = pd.merge(cus_2030, cus_merge1, on=['buy_am','de_dt','de_hr','ages'], how = 'inner').drop(['cust_x','ma_fem_dv_x','zon_hlv_x','rct_no_x','chnl_dv_x','cop_c_x','br_c_x','pd_c_x','pd_nm_x','clac_hlv_nm_x','clac_mcls_nm_x'], axis=1)
kmeans_2030
# Out:
#          ages     de_dt  de_hr    buy_am  buy_ct_x  cluster  cluster_s  \
# 0          30  20210805     15  239000.0         1        1          0
# 1          30  20210306     15   69400.0         1        1          3
# 2          30  20210429     15   23000.0         1        0          2
# 3          30  20211016     17   31500.0         1        1          0
# 4          30  20211016     17   34300.0         1        1          0
# ...       ...       ...    ...       ...       ...      ...        ...
# 3227944    30  20210317     22  239000.0         1        0          2
# 3227945    30  20210929     21  208000.0         1        0          2
# 3227946    30  20210428     10   28580.0         1        0          2
# 3227947    30  20210201     10   19900.0         1        0          2
# 3227948    20  20210220     14   49500.0         1        0          2
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_2030.groupby(['cust_y','cluster'])['ages'].count()
# Out:
# cust_y      cluster
# M000136117  0           25
#             1           99
#             2            1
#             3           55
# M000494848  0          241
#                       ...
# M999770689  1           51
#             3          365
# M999849895  0            8
#             1           27
#             3           68
# Name: ages, Length: 26638, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster']==0]
# Out:
#          ages     de_dt  de_hr    buy_am  buy_ct_x  cluster  cluster_s  \
# 2          30  20210429     15   23000.0         1        0          2
# 30         30  20210207      0   48400.0         1        0          2
# 44         30  20210506     13   23000.0         1        0          2
# 45         30  20210520      5   23000.0         1        0          2
# 46         30  20210520      5   23000.0         1        0          2
# ...       ...       ...    ...       ...       ...      ...        ...
# 3227944    30  20210317     22  239000.0         1        0          2
# 3227945    30  20210929     21  208000.0         1        0          2
# 3227946    30  20210428     10   28580.0         1        0          2
# 3227947    30  20210201     10   19900.0         1        0          2
# 3227948    20  20210220     14   49500.0         1        0          2
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_2030[kmeans_2030['cluster']==0].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성    431233
# 여성    689001
# Name: cust_y, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster']==0].groupby('cop_c_y')['cust_y'].count()
# Out:
# cop_c_y
# A01     70299
# A02    319454
# A03    358423
# A04    241268
# A05      3664
# A06    127126
# Name: cust_y, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster']==0].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 여성패딩            34793
# 감자스낵            26394
# 일반스낵            25863
# 백화점/마트모바일상품권    20588
# 영화/문화모바일상품권     20295
#                 ...
# 순금/순은/장식품           1
# 솥                   1
# 족욕기                 1
# 성인요/요커버             1
# 힙색/사이드백             1
# Name: cust_y, Length: 1741, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster']==0].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 여성패딩            2.756652e+09
# 여성스니커즈          1.281720e+09
# 영화/문화모바일상품권     9.920294e+08
# 백화점/마트모바일상품권    6.781094e+08
# 남성스니커즈          4.634537e+08
#                     ...
# 젤네일/케어류         2.500000e+03
# 얼음/빙수용품         1.900000e+03
# 기타여아특수목적의류      1.200000e+03
# 미용거울            4.000000e+02
# 공병/공박스          1.000000e+02
# Name: buy_am, Length: 1741, dtype: float64

# %%
kmeans_2030[kmeans_2030['cluster']==1]
# Out:
#          ages     de_dt  de_hr    buy_am  buy_ct_x  cluster  cluster_s  \
# 0          30  20210805     15  239000.0         1        1          0
# 1          30  20210306     15   69400.0         1        1          3
# 3          30  20211016     17   31500.0         1        1          0
# 4          30  20211016     17   34300.0         1        1          0
# 5          20  20210601     14   14000.0         1        1          0
# ...       ...       ...    ...       ...       ...      ...        ...
# 3227925    30  20211022     14  619000.0         1        1          0
# 3227927    30  20210221     14  589000.0         1        1          0
# 3227936    30  20210215     16   49000.0         1        1          3
# 3227941    30  20210306     15   47000.0         1        1          0
# 3227943    30  20210605     19  119200.0         1        1          0
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_2030[kmeans_2030['cluster']==1].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성     99697
# 여성    279702
# Name: cust_y, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster']==1].groupby('cop_c_y')['cust_y'].count()
# Out:
# cop_c_y
# A01    294642
# A02     59457
# A03     11250
# A04     12244
# A05       229
# A06      1577
# Name: cust_y, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster']==1].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 기타남성의류세트      26168
# 임대매출          17434
# 디저트           11094
# 푸드코트한식         7523
# 일반스낵           7440
#               ...
# 파충류               1
# 남성점프수트/오버롤        1
# 수입돼지목심            1
# 남성양말선물세트          1
# 힙색/사이드백           1
# Name: cust_y, Length: 1661, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster']==1].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 기타패션잡화        742237930.0
# 기타남성의류세트      736730180.0
# 여성토트백         639373030.0
# 여성코트          600797390.0
# 여성가방액세서리      596906650.0
#                  ...
# 여아한복                800.0
# 공병/공박스              530.0
# 배선물세트               400.0
# 육가공품선물세트            250.0
# 컴퓨터/노트북기프트          100.0
# Name: buy_am, Length: 1661, dtype: float64

# %%
kmeans_2030[kmeans_2030['cluster']==2]
# Out:
#          ages     de_dt  de_hr     buy_am  buy_ct_x  cluster  cluster_s  \
# 2344       30  20211205     12  2580000.0        20        2          3
# 338156     30  20211230     16  2825000.0         1        2          0
# 1089344    30  20210806     14  5140000.0         1        2          0
# 1089348    30  20210525     18  2950000.0         1        2          0
# 1089364    30  20210828     15  2550000.0         1        2          0
# ...       ...       ...    ...        ...       ...      ...        ...
# 3227672    30  20210409     13  5842100.0         1        2          3
# 3227704    30  20211002     14  3000000.0         1        2          3
# 3227825    30  20210619     20  5879000.0         1        2          3
# 3227826    30  20210703     11  5954000.0         1        2          3
# 3227917    30  20210417     13  3750000.0         1        2          3
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_2030[kmeans_2030['cluster']==2].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성     499
# 여성    1086
# Name: cust_y, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster']==2].groupby('cop_c_y')['cust_y'].count()
# Out:
# cop_c_y
# A01    1525
# A02       1
# A05      56
# A06       3
# Name: cust_y, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster']==2].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 여성가방액세서리    209
# 여성숄더백       131
# 기타패션잡화      125
# 여성토트백       106
# 양문형냉장고       93
#            ...
# 선물류           1
# 식탁의자          1
# 골프필드용품        1
# 여성점퍼          1
# 화장대           1
# Name: cust_y, Length: 94, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster']==2].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 여성가방액세서리      1.149167e+09
# 여성숄더백         7.689410e+08
# 기타패션잡화        6.428805e+08
# 남성시계          6.248975e+08
# 양문형냉장고        4.846714e+08
#                   ...
# 식탁의자          2.700000e+06
# 노트북           2.660000e+06
# 여성티셔츠/탑       2.650000e+06
# 남성골프티셔츠       2.633000e+06
# 남성런닝/트레이닝화    2.580000e+06
# Name: buy_am, Length: 94, dtype: float64

# %%
kmeans_2030[kmeans_2030['cluster']==3]
# Out:
#          ages     de_dt  de_hr   buy_am  buy_ct_x  cluster  cluster_s  \
# 41         30  20211228     15  71200.0         1        3          0
# 53         20  20210101     20   6600.0         2        3          3
# 54         20  20210101     20   6600.0         2        3          3
# 55         20  20210101     20   6600.0         2        3          3
# 56         20  20210101     20   6600.0         2        3          3
# ...       ...       ...    ...      ...       ...      ...        ...
# 3227909    30  20210717     22  17500.0         1        3          3
# 3227910    30  20211204     15  29000.0         1        3          0
# 3227934    30  20211209     13   5600.0         2        3          0
# 3227939    30  20211228     18  12500.0         1        3          3
# 3227940    30  20211228     18  10500.0         1        3          3
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_2030[kmeans_2030['cluster']==3].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성     513004
# 여성    1213727
# Name: cust_y, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster']==3].groupby('cop_c_y')['cust_y'].count()
# Out:
# cop_c_y
# A01      87429
# A02    1432423
# A03     149582
# A04      53469
# A05        365
# A06       3463
# Name: cust_y, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster']==3].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 기타파티/팬시용품    58304
# 일반스낵         54160
# 종량제봉투        30961
# 수입맥주         29811
# 바나나          28226
#              ...
# 펀치류              1
# 전화기              1
# 기타연체류            1
# 자전거수리부품          1
# 남성코트             1
# Name: cust_y, Length: 1644, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster']==3].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 기타파티/팬시용품    162588120.0
# 수입맥주         126932080.0
# 일반스낵         118526022.0
# 딸기           111900488.0
# 일반계란         104106120.0
#                 ...
# 자석놀이              3600.0
# 손난로/핫팩            1960.0
# 어린이홍삼             1300.0
# 여성스포츠속옷           1000.0
# 인덕션/가스레인지          200.0
# Name: buy_am, Length: 1644, dtype: float64

# %%
kmeans_2030[kmeans_2030['cluster_s']==0]
# Out:
#          ages     de_dt  de_hr    buy_am  buy_ct_x  cluster  cluster_s  \
# 0          30  20210805     15  239000.0         1        1          0
# 3          30  20211016     17   31500.0         1        1          0
# 4          30  20211016     17   34300.0         1        1          0
# 5          20  20210601     14   14000.0         1        1          0
# 6          20  20210601     14   14000.0         1        1          0
# ...       ...       ...    ...       ...       ...      ...        ...
# 3227925    30  20211022     14  619000.0         1        1          0
# 3227927    30  20210221     14  589000.0         1        1          0
# 3227934    30  20211209     13    5600.0         2        3          0
# 3227941    30  20210306     15   47000.0         1        1          0
# 3227943    30  20210605     19  119200.0         1        1          0
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_2030[kmeans_2030['cluster_s']==0].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성     216545
# 여성    1288110
# Name: cust_y, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster_s']==0].groupby('cop_c_y')['cust_y'].count()
# Out:
# cop_c_y
# A01     286311
# A02    1053443
# A03     114052
# A04      46788
# A05        441
# A06       3620
# Name: cust_y, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster_s']==0].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 기타파티/팬시용품     47292
# 일반스낵          44771
# 수입맥주          22637
# 기타남성의류세트      22375
# 종량제봉투         22091
#               ...
# 컴퓨터/노트북기프트        1
# 커피크리머             1
# 보드복               1
# 지구의/지도            1
# 제본기               1
# Name: cust_y, Length: 1757, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster_s']==0].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)

# %%
kmeans_2030[kmeans_2030['cluster_s']==1]
# Out:
#          ages     de_dt  de_hr   buy_am  buy_ct_x  cluster  cluster_s  \
# 77         20  20210331     20   1000.0         1        0          1
# 78         20  20210331     20   1000.0         1        0          1
# 692        30  20210716     13   4000.0         2        0          1
# 693        30  20210716     13   4000.0         2        0          1
# 694        30  20210716     13   4000.0         2        0          1
# ...       ...       ...    ...      ...       ...      ...        ...
# 3227921    30  20210514      9    100.0         1        0          1
# 3227930    20  20210319     12  19413.0         1        0          1
# 3227931    20  20211017     15  29500.0         1        0          1
# 3227932    20  20210715     22  19900.0         1        0          1
# 3227933    20  20211103      0  19900.0         1        0          1
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_2030[kmeans_2030['cluster_s']==1].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성    254371
# 여성    446671
# Name: cust_y, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster_s']==1].groupby('cop_c_y')['cust_y'].count()
# Out:
# cop_c_y
# A01     22820
# A02    130699
# A03    306863
# A04    236044
# A05      3127
# A06      1489
# Name: cust_y, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster_s']==1].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 일반스낵           22743
# 종량제봉투          18531
# 옥수수스낵          16291
# 기타파티/팬시용품      14498
# 국산담배           14494
#                ...
# 전기그릴               1
# 기타요가/필라테스소품        1
# 잣                  1
# 기타여행용가방            1
# 모기장                1
# Name: cust_y, Length: 1448, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster_s']==1].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 스탠드형에어컨      119713500.0
# 휴대폰          119287264.0
# UHD          115587400.0
# 노트북           79855400.0
# 국산담배          78862600.0
#                 ...
# 소품가방               400.0
# 공병/공박스             100.0
# 남성스포츠패딩            100.0
# 등산화                100.0
# 남성등산점퍼/재킷          100.0
# Name: buy_am, Length: 1448, dtype: float64

# %%
kmeans_2030[kmeans_2030['cluster_s']==2]
# Out:
#          ages     de_dt  de_hr    buy_am  buy_ct_x  cluster  cluster_s  \
# 2          30  20210429     15   23000.0         1        0          2
# 30         30  20210207      0   48400.0         1        0          2
# 44         30  20210506     13   23000.0         1        0          2
# 45         30  20210520      5   23000.0         1        0          2
# 46         30  20210520      5   23000.0         1        0          2
# ...       ...       ...    ...       ...       ...      ...        ...
# 3227944    30  20210317     22  239000.0         1        0          2
# 3227945    30  20210929     21  208000.0         1        0          2
# 3227946    30  20210428     10   28580.0         1        0          2
# 3227947    30  20210201     10   19900.0         1        0          2
# 3227948    20  20210220     14   49500.0         1        0          2
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_2030[kmeans_2030['cluster_s']==2].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성    176884
# 여성    242369
# Name: cust_y, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster_s']==2].groupby('cop_c_y')['cust_y'].count()
# Out:
# cop_c_y
# A01     47481
# A02    188755
# A03     51560
# A04      5224
# A05       593
# A06    125640
# Name: cust_y, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster_s']==2].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 여성패딩            34791
# 백화점/마트모바일상품권    20473
# 영화/문화모바일상품권     20284
# 여성스니커즈          16100
# 감자스낵            12413
#                 ...
# 남성머니클립              1
# 식탁세트                1
# 족욕기                 1
# 남성등산/아웃도어세트         1
# 힙색/사이드백             1
# Name: cust_y, Length: 1623, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster_s']==2].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 여성패딩            2.756648e+09
# 여성스니커즈          1.281688e+09
# 영화/문화모바일상품권     9.919344e+08
# 백화점/마트모바일상품권    6.774082e+08
# 남성스니커즈          4.632464e+08
#                     ...
# 우비              1.000000e+03
# 곤약              9.900000e+02
# 봉투보증금           9.000000e+02
# 기타여아특수목적의류      5.000000e+02
# 미용거울            4.000000e+02
# Name: buy_am, Length: 1623, dtype: float64

# %%
kmeans_2030[kmeans_2030['cluster_s']==3]
# Out:
#          ages     de_dt  de_hr     buy_am  buy_ct_x  cluster  cluster_s  \
# 1          30  20210306     15    69400.0         1        1          3
# 12         20  20210503     15   119200.0         1        1          3
# 13         20  20210806     12   159000.0         1        1          3
# 14         20  20210806     12    55000.0         1        1          3
# 32         30  20210904     16    39000.0         1        1          3
# ...       ...       ...    ...        ...       ...      ...        ...
# 3227914    20  20210111     20    15000.0         1        1          3
# 3227917    30  20210417     13  3750000.0         1        2          3
# 3227936    30  20210215     16    49000.0         1        1          3
# 3227939    30  20211228     18    12500.0         1        3          3
# 3227940    30  20211228     18    10500.0         1        3          3
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_2030[kmeans_2030['cluster_s']==3].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성    396633
# 여성    206366
# Name: cust_y, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster_s']==3].groupby('cop_c_y')['cust_y'].count()
# Out:
# cop_c_y
# A01     97283
# A02    438438
# A03     46780
# A04     18925
# A05       153
# A06      1420
# Name: cust_y, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster_s']==3].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 기타파티/팬시용품    18159
# 일반스낵         16829
# 햄            11349
# 수입맥주         11029
# 기타남성의류세트     10396
#              ...
# 비데               1
# 튜브/보트            1
# 블라인드/버티컬         1
# 특수용세탁세제          1
# 힙색/사이드백          1
# Name: cust_y, Length: 1686, dtype: int64

# %%
kmeans_2030[kmeans_2030['cluster_s']==3].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 여성숄더백         613490460.0
# 여성가방액세서리      546095600.0
# 기타남성의류세트      327799700.0
# 여성토트백         319435240.0
# 기타남성의류아우터     312303740.0
#                  ...
# 네일케어도구             2500.0
# 마                  2430.0
# 기타테니스용품            1900.0
# 영유아패션트레이닝복          900.0
# 배선물세트               200.0
# Name: buy_am, Length: 1686, dtype: float64

# %% [markdown]
# ## 젤 많은 40대

# %%
cus_40 = cus_merge[cus_merge['ages'] == 40]

# %%
elbow(cus_40,10)
# Out:
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['NanumGothic'] not found. Falling back to DejaVu Sans.

# %%
kmeans = KMeans(n_clusters=4, random_state=1234)
kmeans.fit(cus_40)
centers_s = kmeans.cluster_centers_ 
pred_s = kmeans.predict(cus_40)

# %%
cus_40['cluster'] = pred_s
cus_40
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#           cust  ma_fem_dv  ages  zon_hlv   rct_no  chnl_dv  cop_c  br_c  pd_c  \
# 0            0          1    40        6    16648        1      0    44   776
# 1            0          1    40        6    16648        1      0    44   776
# 3            4          1    40       16   117091        1      0    16   776
# 4            6          1    40       16   543169        1      1    73   776
# 5            6          1    40       16   543169        1      1    73   776
# ...        ...        ...   ...      ...      ...      ...    ...   ...   ...
# ...

# %% [markdown]
# ### scaling

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import MinMaxScaler 
minmax_scaler = MinMaxScaler() 
scaled_df = pd.DataFrame(minmax_scaler.fit_transform(cus_40), columns=cus_40.columns)

# %%
kmeans.fit(scaled_df)
centers_s = kmeans.cluster_centers_ 
pred_s = kmeans.predict(scaled_df)

# %%
cus_40['cluster_s'] = pred_s
cus_40
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#           cust  ma_fem_dv  ages  zon_hlv   rct_no  chnl_dv  cop_c  br_c  pd_c  \
# 0            0          1    40        6    16648        1      0    44   776
# 1            0          1    40        6    16648        1      0    44   776
# 3            4          1    40       16   117091        1      0    16   776
# 4            6          1    40       16   543169        1      1    73   776
# 5            6          1    40       16   543169        1      1    73   776
# ...        ...        ...   ...      ...      ...      ...    ...   ...   ...
# ...

# %%
kmeans_40 = pd.merge(cus_40, cus_merge1, on=['buy_am','de_dt','de_hr','ages'], how = 'inner').drop(['cust_x','ma_fem_dv_x','zon_hlv_x','rct_no_x','chnl_dv_x','cop_c_x','br_c_x','pd_c_x','pd_nm_x','clac_hlv_nm_x','clac_mcls_nm_x'], axis=1)
kmeans_40
# Out:
#          ages     de_dt  de_hr    buy_am  buy_ct_x  cluster  cluster_s  \
# 0          40  20210116     18   59000.0         1        2          3
# 1          40  20210116     18   19000.0         1        2          3
# 2          40  20210403     13  179000.0         1        2          3
# 3          40  20210129     14    3000.0         3        1          3
# 4          40  20210129     14    3000.0         3        1          3
# ...       ...       ...    ...       ...       ...      ...        ...
# 7084708    40  20210307     10  908000.0         1        0          2
# 7084709    40  20210131     19  229000.0         1        0          2
# 7084710    40  20210712     21  199000.0         1        0          2
# 7084711    40  20210523      8  187050.0         1        0          2
# 7084712    40  20210828     17  800000.0         8        1          1
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_40[kmeans_40['cluster']==0]
# Out:
#          ages     de_dt  de_hr    buy_am  buy_ct_x  cluster  cluster_s  \
# 11         40  20210129     14    3000.0         1        0          0
# 12         40  20210129     14    3000.0         1        0          0
# 13         40  20210129     14    3000.0         1        0          0
# 14         40  20210129     14    3000.0         1        0          0
# 15         40  20210129     14    3000.0         1        0          0
# ...       ...       ...    ...       ...       ...      ...        ...
# 7084707    40  20210218      8   59000.0         1        0          2
# 7084708    40  20210307     10  908000.0         1        0          2
# 7084709    40  20210131     19  229000.0         1        0          2
# 7084710    40  20210712     21  199000.0         1        0          2
# 7084711    40  20210523      8  187050.0         1        0          2
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_40[kmeans_40['cluster']==0].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성     702859
# 여성    1654660
# Name: cust_y, dtype: int64

# %%
kmeans_40[kmeans_40['cluster']==0].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 일반스낵           74288
# 감자스낵           64929
# 일반우유           42910
# 기타파티/팬시용품      41426
# 국물봉지라면         39593
#                ...
# 하이패스               1
# 기타카메라              1
# 학생용가방              1
# 유아동시계              1
# 영유아점프수트/오버롤        1
# Name: cust_y, Length: 1806, dtype: int64

# %%
kmeans_40[kmeans_40['cluster']==1]
# Out:
#          ages     de_dt  de_hr    buy_am  buy_ct_x  cluster  cluster_s  \
# 3          40  20210129     14    3000.0         3        1          3
# 4          40  20210129     14    3000.0         3        1          3
# 5          40  20210129     14    3000.0         3        1          3
# 6          40  20210129     14    3000.0         3        1          3
# 7          40  20210129     14    3000.0         1        1          1
# ...       ...       ...    ...       ...       ...      ...        ...
# 7084647    40  20210103     13   12900.0         1        1          3
# 7084673    40  20210216     19    2800.0         1        1          0
# 7084674    40  20211119     20    2800.0         1        1          1
# 7084685    40  20210429     17   12500.0         1        1          0
# 7084712    40  20210828     17  800000.0         8        1          1
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_40[kmeans_40['cluster']==1].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성    1238237
# 여성    2853368
# Name: cust_y, dtype: int64

# %%
kmeans_40[kmeans_40['cluster']==1].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 일반스낵           147334
# 기타파티/팬시용품      115300
# 바나나             78243
# 옥수수스낵           70768
# 감자스낵            69160
#                 ...
# 택배                  1
# 핸디형청소기              1
# 목욕가운                1
# 프린터/복합기/스캐너         1
# 수삼선물세트              1
# Name: cust_y, Length: 1700, dtype: int64

# %%
kmeans_40[kmeans_40['cluster']==2]
# Out:
#          ages     de_dt  de_hr    buy_am  buy_ct_x  cluster  cluster_s  \
# 0          40  20210116     18   59000.0         1        2          3
# 1          40  20210116     18   19000.0         1        2          3
# 2          40  20210403     13  179000.0         1        2          3
# 21         40  20210417     19  250000.0         1        2          1
# 22         40  20210716     19   65000.0         1        2          1
# ...       ...       ...    ...       ...       ...      ...        ...
# 7084701    40  20210508     18  300000.0         1        2          3
# 7084702    40  20210508     18  300000.0         1        2          3
# 7084703    40  20210508     18  300000.0         1        2          3
# 7084704    40  20210508     18   40000.0         1        2          3
# 7084706    40  20210911     16  279000.0         1        2          1
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_40[kmeans_40['cluster']==2].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성    173394
# 여성    460554
# Name: cust_y, dtype: int64

# %%
kmeans_40[kmeans_40['cluster']==2].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 기타남성의류세트     30785
# 임대매출         18500
# 기타파티/팬시용품    14522
# 디저트          14007
# 일반스낵         12497
#              ...
# 아기띠/캐리어          1
# 남성스포츠속옷          1
# 청소기/광택기          1
# 썰매류              1
# 힙색/사이드백          1
# Name: cust_y, Length: 1728, dtype: int64

# %%
kmeans_40[kmeans_40['cluster']==3]
# Out:
#          ages     de_dt  de_hr      buy_am  buy_ct_x  cluster  cluster_s  \
# 207696     40  20211123      6   3720000.0         1        3          2
# 3580071    40  20211023     15   3890000.0         1        3          0
# 3580090    40  20211130     12   8490000.0         1        3          0
# 3580091    40  20211130     17   8490000.0         1        3          0
# 3580092    40  20211221     15   5264000.0         1        3          0
# ...       ...       ...    ...         ...       ...      ...        ...
# 7084132    40  20210903     14   5662800.0         1        3          3
# 7084133    40  20211106     15   5700000.0         1        3          1
# 7084139    40  20211119     12   3980000.0         1        3          0
# 7084539    40  20210320     13   3630000.0         1        3          1
# 7084650    40  20210503     17  20000000.0         1        3          3
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_40[kmeans_40['cluster']==3].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성     618
# 여성    1023
# Name: cust_y, dtype: int64

# %%
kmeans_40[kmeans_40['cluster']==3].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 여성가방액세서리    127
# 기타패션잡화      120
# 남성시계        112
# 침대           86
# 여성토트백        72
#            ...
# 골프연습장비        1
# 여성점퍼          1
# 여성코스튬         1
# 골프공           1
# 휴대폰           1
# Name: cust_y, Length: 122, dtype: int64

# %%
kmeans_40[kmeans_40['cluster_s']==0]
# Out:
#          ages     de_dt  de_hr   buy_am  buy_ct_x  cluster  cluster_s  \
# 11         40  20210129     14   3000.0         1        0          0
# 12         40  20210129     14   3000.0         1        0          0
# 13         40  20210129     14   3000.0         1        0          0
# 14         40  20210129     14   3000.0         1        0          0
# 15         40  20210129     14   3000.0         1        0          0
# ...       ...       ...    ...      ...       ...      ...        ...
# 7084678    40  20211017     15  49000.0         1        2          0
# 7084679    40  20211017     15  49000.0         1        2          0
# 7084680    40  20211024     14  39900.0         1        2          0
# 7084682    40  20210324     13  79000.0         1        2          0
# 7084685    40  20210429     17  12500.0         1        1          0
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_40[kmeans_40['cluster_s']==0].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성     401728
# 여성    1651696
# Name: cust_y, dtype: int64

# %%
kmeans_40[kmeans_40['cluster_s']==0].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 종량제봉투        50377
# 기타파티/팬시용품    47459
# 일반우유         44720
# 일반스낵         43169
# 두부류          35518
#              ...
# 햄통조림세트           1
# 킹크랩              1
# 탁구공              1
# 핸디형청소기           1
# 힙색/사이드백          1
# Name: cust_y, Length: 1733, dtype: int64

# %%
kmeans_40[kmeans_40['cluster_s']==1]
# Out:
#          ages     de_dt  de_hr    buy_am  buy_ct_x  cluster  cluster_s  \
# 7          40  20210129     14    3000.0         1        1          1
# 8          40  20210129     14    3000.0         1        1          1
# 9          40  20210129     14    3000.0         1        1          1
# 10         40  20210129     14    3000.0         1        1          1
# 21         40  20210417     19  250000.0         1        2          1
# ...       ...       ...    ...       ...       ...      ...        ...
# 7084666    40  20210228     15  589000.0         1        2          1
# 7084672    40  20210803     11   19900.0         1        0          1
# 7084674    40  20211119     20    2800.0         1        1          1
# 7084706    40  20210911     16  279000.0         1        2          1
# 7084712    40  20210828     17  800000.0         8        1          1
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_40[kmeans_40['cluster_s']==1].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성    1037143
# 여성     890651
# Name: cust_y, dtype: int64

# %%
kmeans_40[kmeans_40['cluster_s']==1].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 일반스낵             67913
# 기타파티/팬시용품        50525
# 옥수수스낵            32624
# 감자스낵             31181
# 일반우유             30190
#                  ...
# 캠코더                  1
# 캐노피                  1
# 스키복                  1
# 카메라액세서리              1
# 안마의자/헬스/이미용렌탈        1
# Name: cust_y, Length: 1765, dtype: int64

# %%
kmeans_40[kmeans_40['cluster_s']==2]
# Out:
#          ages     de_dt  de_hr    buy_am  buy_ct_x  cluster  cluster_s  \
# 154        40  20210318     15   38000.0         1        0          2
# 155        40  20210318     15   38000.0         1        0          2
# 156        40  20210318     15   38000.0         1        0          2
# 157        40  20210318     15   38000.0         1        0          2
# 193        40  20210228     14   49000.0         1        0          2
# ...       ...       ...    ...       ...       ...      ...        ...
# 7084707    40  20210218      8   59000.0         1        0          2
# 7084708    40  20210307     10  908000.0         1        0          2
# 7084709    40  20210131     19  229000.0         1        0          2
# 7084710    40  20210712     21  199000.0         1        0          2
# 7084711    40  20210523      8  187050.0         1        0          2
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_40[kmeans_40['cluster_s']==2].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성    212982
# 여성    639048
# Name: cust_y, dtype: int64

# %%
kmeans_40[kmeans_40['cluster_s']==2].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 감자스낵           34436
# 국물봉지라면         24786
# 일반우유           19346
# 즉석덮밥류          18515
# 영화/문화모바일상품권    16652
#                ...
# 캐쥬얼시계              1
# 성인침구매트             1
# 성인요/요커버            1
# 서식지                1
# 2단우산               1
# Name: cust_y, Length: 1743, dtype: int64

# %%
kmeans_40[kmeans_40['cluster_s']==3]
# Out:
#          ages     de_dt  de_hr    buy_am  buy_ct_x  cluster  cluster_s  \
# 0          40  20210116     18   59000.0         1        2          3
# 1          40  20210116     18   19000.0         1        2          3
# 2          40  20210403     13  179000.0         1        2          3
# 3          40  20210129     14    3000.0         3        1          3
# 4          40  20210129     14    3000.0         3        1          3
# ...       ...       ...    ...       ...       ...      ...        ...
# 7084700    40  20210508     18  300000.0         1        2          3
# 7084701    40  20210508     18  300000.0         1        2          3
# 7084702    40  20210508     18  300000.0         1        2          3
# 7084703    40  20210508     18  300000.0         1        2          3
# 7084704    40  20210508     18   40000.0         1        2          3
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_40[kmeans_40['cluster_s']==3].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성     463255
# 여성    1788210
# Name: cust_y, dtype: int64

# %%
kmeans_40[kmeans_40['cluster_s']==3].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 일반스낵          110273
# 기타파티/팬시용품      65924
# 옥수수스낵          52143
# 감자스낵           49640
# 바나나            43355
#                ...
# 스포츠목걸이/팔찌          1
# 현악기                1
# 헤어펌/코팅제            1
# 영유아패션트레이닝복         1
# 테니스화               1
# Name: cust_y, Length: 1735, dtype: int64

# %% [markdown]
# ## 5060 나이대

# %%
cus_5060 = cus_merge.loc[(cus_merge['ages'] == 50) | (cus_merge['ages'] == 60), : ]

# %%
elbow(cus_5060,10)

# %%
kmeans = KMeans(n_clusters=5, random_state=1234)
kmeans.fit(cus_5060)
centers_s = kmeans.cluster_centers_ 
pred_s = kmeans.predict(cus_5060)

# %%
cus_5060['cluster'] = pred_s
cus_5060
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#           cust  ma_fem_dv  ages  zon_hlv   rct_no  chnl_dv  cop_c  br_c  pd_c  \
# 6            9          1    50       16   416926        1      0    31   776
# 7           10          0    50        9   100227        1      0    38   776
# 8           10          0    50        9   355373        1      0    38   776
# 42          98          1    50       16    26238        1      0     1   776
# 48         144          1    50       15   372980        1      0    13   776
# ...        ...        ...   ...      ...      ...      ...    ...   ...   ...
# ...

# %% [markdown]
# ### scaling

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import MinMaxScaler 
minmax_scaler = MinMaxScaler() 
scaled_df = pd.DataFrame(minmax_scaler.fit_transform(cus_5060), columns=cus_5060.columns)

# %%
kmeans.fit(scaled_df)
centers_s = kmeans.cluster_centers_ 
pred_s = kmeans.predict(scaled_df)

# %%
cus_5060['cluster_s'] = pred_s
cus_5060
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#           cust  ma_fem_dv  ages  zon_hlv   rct_no  chnl_dv  cop_c  br_c  pd_c  \
# 6            9          1    50       16   416926        1      0    31   776
# 7           10          0    50        9   100227        1      0    38   776
# 8           10          0    50        9   355373        1      0    38   776
# 42          98          1    50       16    26238        1      0     1   776
# 48         144          1    50       15   372980        1      0    13   776
# ...        ...        ...   ...      ...      ...      ...    ...   ...   ...
# ...

# %%
kmeans_5060 = pd.merge(cus_5060, cus_merge1, on=['buy_am','de_dt','de_hr','ages'], how = 'inner').drop(['cust_x','ma_fem_dv_x','zon_hlv_x','rct_no_x','chnl_dv_x','cop_c_x','br_c_x','pd_c_x','pd_nm_x','clac_hlv_nm_x','clac_mcls_nm_x'], axis=1)
kmeans_5060
# Out:
#          ages     de_dt  de_hr     buy_am  buy_ct_x  cluster  cluster_s  \
# 0          50  20211031     18    49000.0         1        1          1
# 1          50  20210321     15    87300.0         1        1          2
# 2          50  20210920     11   128600.0         1        1          2
# 3          50  20210125     16    29900.0         1        1          1
# 4          50  20211003     13   129000.0         1        1          1
# ...       ...       ...    ...        ...       ...      ...        ...
# 2731365    50  20210324     22    49500.0         1        2          3
# 2731366    60  20210516     17  1650000.0         1        4          4
# 2731367    50  20210808     12    93000.0         1        1          1
# 2731368    50  20210320     12     7110.0         1        2          2
# 2731369    60  20210430     10   139000.0         1        2          4
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_5060[kmeans_5060['cluster']==0]
# Out:
#          ages     de_dt  de_hr   buy_am  buy_ct_x  cluster  cluster_s  \
# 47         50  20210212     15   2000.0         2        0          1
# 48         50  20210212     15   2000.0         2        0          1
# 49         50  20210212     15   2000.0         2        0          1
# 50         50  20210212     15   2000.0         2        0          1
# 55         50  20210212     15   2000.0         2        0          0
# ...       ...       ...    ...      ...       ...      ...        ...
# 2731337    60  20210319     18  59900.0         1        0          4
# 2731338    50  20210102     14  75900.0         1        0          2
# 2731339    50  20210827     11  49900.0         1        0          0
# 2731341    50  20210729     10   7000.0         1        0          1
# 2731361    50  20211220     13  95700.0         3        0          1
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_5060[kmeans_5060['cluster']==0].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성     395639
# 여성    1046546
# Name: cust_y, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==0].groupby('cop_c_y')['cust_y'].count()
# Out:
# cop_c_y
# A01      89294
# A02    1243120
# A03      91124
# A04      16407
# A05        165
# A06       2075
# Name: cust_y, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==0].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 기타파티/팬시용품    42152
# 바나나          31780
# 일반스낵         31500
# 일반우유         23402
# 두부류          23230
#              ...
# 시계부속품            1
# 실내DIY용품          1
# 아동수영복            1
# 알타리무             1
# 힙색/사이드백          1
# Name: cust_y, Length: 1624, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==0].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 일반계란         156780120.0
# 기타남성의류세트     138549680.0
# 기타파티/팬시용품    120503000.0
# 바나나          114978160.0
# 일반우유          94379530.0
#                 ...
# 기타농구용품            3900.0
# 알타리무              2490.0
# 서적세트              2200.0
# 명함정리용품            1000.0
# 의류스타일러             100.0
# Name: buy_am, Length: 1624, dtype: float64

# %%
kmeans_5060[kmeans_5060['cluster']==1]
# Out:
#          ages     de_dt  de_hr     buy_am  buy_ct_x  cluster  cluster_s  \
# 0          50  20211031     18    49000.0         1        1          1
# 1          50  20210321     15    87300.0         1        1          2
# 2          50  20210920     11   128600.0         1        1          2
# 3          50  20210125     16    29900.0         1        1          1
# 4          50  20211003     13   129000.0         1        1          1
# ...       ...       ...    ...        ...       ...      ...        ...
# 2731335    50  20210906     17    72000.0         1        1          0
# 2731343    50  20210405     17  1000000.0         1        1          1
# 2731358    50  20210313     18     8000.0         1        1          0
# 2731362    60  20210912     12   600000.0         1        1          4
# 2731367    50  20210808     12    93000.0         1        1          1
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_5060[kmeans_5060['cluster']==1].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성     71211
# 여성    235079
# Name: cust_y, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==1].groupby('cop_c_y')['cust_y'].count()
# Out:
# cop_c_y
# A01    240073
# A02     50033
# A03     11037
# A04      4269
# A05       178
# A06       700
# Name: cust_y, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==1].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 기타남성의류세트    16616
# 여성티셔츠/탑      6520
# 임대매출         6271
# 일반스낵         5876
# 푸드코트한식       5742
#             ...
# 보드장비            1
# 일반기능미           1
# 기타고기            1
# 분유              1
# 힙색/사이드백         1
# Name: cust_y, Length: 1631, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==1].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 여성재킷         725317430.0
# 기타여성의류아우터    494888230.0
# 여성티셔츠/탑      491936170.0
# 기타여성의류세트     476872390.0
# 기타남성의류세트     435807830.0
#                 ...
# 싸인물/자석/압핀         2000.0
# 포장용품              1500.0
# 색종이               1500.0
# 모종/씨앗             1000.0
# 얼음/빙수용품           1000.0
# Name: buy_am, Length: 1631, dtype: float64

# %%
kmeans_5060[kmeans_5060['cluster']==2]
# Out:
#          ages     de_dt  de_hr    buy_am  buy_ct_x  cluster  cluster_s  \
# 41         50  20210414     10  231000.0         1        2          3
# 51         50  20210212     15    2000.0         1        2          2
# 52         50  20210212     15    2000.0         1        2          2
# 53         50  20210212     15    2000.0         1        2          2
# 54         50  20210212     15    2000.0         1        2          2
# ...       ...       ...    ...       ...       ...      ...        ...
# 2731360    50  20210513     17   12700.0         1        2          3
# 2731364    50  20210119     21  124000.0         1        2          3
# 2731365    50  20210324     22   49500.0         1        2          3
# 2731368    50  20210320     12    7110.0         1        2          2
# 2731369    60  20210430     10  139000.0         1        2          4
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_5060[kmeans_5060['cluster']==2].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성    284026
# 여성    696755
# Name: cust_y, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==2].groupby('cop_c_y')['cust_y'].count()
# Out:
# cop_c_y
# A01     26880
# A02    340457
# A03    499835
# A04     89134
# A05      2291
# A06     22184
# Name: cust_y, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==2].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 일반스낵           24789
# 두부류            20732
# 일반우유           19460
# 감자스낵           18970
# 바나나            17980
#                ...
# 기타자동차가전기기          1
# 스팀청소기              1
# 스텝퍼/트위스트           1
# 기타전자/비디오게임         1
# 사무용/학생용가구세트        1
# Name: cust_y, Length: 1676, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==2].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 수입산소갈비          192354040.0
# 백화점/마트모바일상품권    120188200.0
# 일반계란             96077455.0
# 일반우유             73257598.0
# 휴대폰              62719940.0
#                    ...
# 여아스커트                2700.0
# 영유아남방셔츠              2200.0
# 영유아패션트레이닝복            900.0
# 기타전자/비디오게임            100.0
# 타이어                   100.0
# Name: buy_am, Length: 1676, dtype: float64

# %%
kmeans_5060[kmeans_5060['cluster']==3]
# Out:
#          ages     de_dt  de_hr      buy_am  buy_ct_x  cluster  cluster_s  \
# 893349     60  20210716     13  13500000.0         1        3          4
# 893350     60  20210810     12  13500000.0         1        3          4
# 893462     50  20211023     19  21140000.0         1        3          2
# 893809     50  20211029     15   9690000.0         1        3          0
# 893810     50  20211029     15   9690000.0         1        3          0
# ...       ...       ...    ...         ...       ...      ...        ...
# 2727931    60  20210516     17   8564000.0         1        3          4
# 2728116    50  20210226     13  10330000.0         1        3          1
# 2728118    50  20211110     14  10480000.0         1        3          1
# 2728119    50  20210915     11   9766000.0         1        3          1
# 2728275    50  20210814     19  11620000.0         1        3          1
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_5060[kmeans_5060['cluster']==3].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성    47
# 여성    66
# Name: cust_y, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==3].groupby('cop_c_y')['cust_y'].count()
# Out:
# cop_c_y
# A01    111
# A02      2
# Name: cust_y, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==3].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 남성시계          36
# 반지             9
# 여성토트백          7
# UHD            7
# 기타여성의류아우터      6
# 여성시계           5
# 기타보석류          4
# 기타패션잡화         4
# 여성기타모피의류       3
# 안마의자           3
# 팔찌             2
# 여성코트           2
# 여성가방액세서리       2
# 양문형냉장고         2
# 스탠드형김치냉장고      2
# 수입소고기선물세트      2
# 소파             2
# 바디케어세트         2
# 목걸이            2
# 남성정장세트         2
# 기타TV           2
# 한우선물세트         2
# 골프채            1
# 멀티형에어컨         1
# 냉장/냉동가전소모품     1
# 골프패션잡화         1
# 침대             1
# Name: cust_y, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==3].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 남성시계          611763300.0
# 반지            134345900.0
# 여성토트백          86900000.0
# 기타패션잡화         72940000.0
# UHD            72033000.0
# 기타보석류          66100000.0
# 기타여성의류아우터      66087000.0
# 여성시계           64900000.0
# 목걸이            40000000.0
# 여성기타모피의류       31690000.0
# 안마의자           30576000.0
# 팔찌             28772000.0
# 남성정장세트         26320000.0
# 여성코트           24000000.0
# 양문형냉장고         23528000.0
# 스탠드형김치냉장고      20705000.0
# 한우선물세트         20000000.0
# 소파             19968400.0
# 기타TV           18174000.0
# 바디케어세트         18000000.0
# 수입소고기선물세트      17980000.0
# 여성가방액세서리       17600000.0
# 냉장/냉동가전소모품     11620000.0
# 침대             11111120.0
# 멀티형에어컨         10000000.0
# 골프패션잡화         10000000.0
# 골프채             9640000.0
# Name: buy_am, dtype: float64

# %%
kmeans_5060[kmeans_5060['cluster']==4]
# Out:
#          ages     de_dt  de_hr     buy_am  buy_ct_x  cluster  cluster_s  \
# 46001      50  20210910     11  2142000.0         1        4          0
# 229251     60  20210124     11  2000000.0         1        4          4
# 893157     50  20211027     16  1640000.0         1        4          0
# 893158     50  20211027     16  1990000.0         1        4          0
# 893159     50  20210724     16  5750000.0         1        4          0
# ...       ...       ...    ...        ...       ...      ...        ...
# 2731345    50  20210530     17  3450000.0         1        4          1
# 2731346    50  20210530     17  3450000.0         1        4          1
# 2731347    50  20210530     17  3450000.0         1        4          1
# 2731363    50  20210117     16  3605000.0         1        4          2
# 2731366    60  20210516     17  1650000.0         1        4          4
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_5060[kmeans_5060['cluster']==4].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성     610
# 여성    1391
# Name: cust_y, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==4].groupby('cop_c_y')['cust_y'].count()
# Out:
# cop_c_y
# A01    1907
# A02      19
# A05      66
# A06       9
# Name: cust_y, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==4].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 여성토트백        100
# 침대            99
# 여성숄더백         95
# 여성재킷          90
# 양문형냉장고        86
#             ...
# 에멀젼/로션         1
# 선크림류           1
# 압력솥            1
# 그림/인테리어렌탈      1
# 성인침구속통/솜       1
# Name: cust_y, Length: 176, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==4].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 침대           351047100.0
# 여성토트백        302691000.0
# 양문형냉장고       283522100.0
# 여성숄더백        276115000.0
# UHD          264072000.0
#                 ...
# 에어워셔           1650000.0
# 남성서류가방         1631000.0
# 여성바지           1624000.0
# 성인침구속통/솜       1600000.0
# 기타남아의류아우터      1549000.0
# Name: buy_am, Length: 176, dtype: float64

# %%
kmeans_5060[kmeans_5060['cluster_s']==0]
# Out:
#          ages     de_dt  de_hr    buy_am  buy_ct_x  cluster  cluster_s  \
# 7          50  20211003     13  129000.0         1        1          0
# 8          50  20211003     13  129000.0         1        1          0
# 9          50  20211003     13  129000.0         1        1          0
# 21         50  20210418     15   29000.0         1        1          0
# 22         50  20210418     15   29000.0         1        1          0
# ...       ...       ...    ...       ...       ...      ...        ...
# 2731334    50  20210915     17  260000.0         2        1          0
# 2731335    50  20210906     17   72000.0         1        1          0
# 2731336    50  20211129     16   72000.0         1        0          0
# 2731339    50  20210827     11   49900.0         1        0          0
# 2731358    50  20210313     18    8000.0         1        1          0
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_5060[kmeans_5060['cluster_s']==0].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성    107200
# 여성    685265
# Name: cust_y, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster_s']==0].groupby('cop_c_y')['cust_y'].count()
# Out:
# cop_c_y
# A01    115765
# A02    467061
# A03    184589
# A04     23352
# A05       408
# A06      1290
# Name: cust_y, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster_s']==0].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 두부류           18834
# 일반우유          18538
# 종량제봉투         18415
# 기타파티/팬시용품     14979
# 일반계란          14174
#               ...
# 낚시장비              1
# 기타남성특수목적의류        1
# 핸디형청소기            1
# 꿀세트               1
# 한치오징어             1
# Name: cust_y, Length: 1598, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster_s']==0].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 여성재킷         588018480.0
# 여성티셔츠/탑      381062060.0
# 기타패션잡화       368894310.0
# 기타여성의류아우터    362263170.0
# 여성토트백        331423930.0
#                 ...
# 명함정리용품            1000.0
# 손난로/핫팩            1000.0
# 아동비치웨어             500.0
# 의류스타일러             200.0
# 타이어                100.0
# Name: buy_am, Length: 1598, dtype: float64

# %%
kmeans_5060[kmeans_5060['cluster_s']==1]
# Out:
#          ages     de_dt  de_hr    buy_am  buy_ct_x  cluster  cluster_s  \
# 0          50  20211031     18   49000.0         1        1          1
# 3          50  20210125     16   29900.0         1        1          1
# 4          50  20211003     13  129000.0         1        1          1
# 5          50  20211003     13  129000.0         1        1          1
# 6          50  20211003     13  129000.0         1        1          1
# ...       ...       ...    ...       ...       ...      ...        ...
# 2731354    50  20210313      3   19900.0         1        2          1
# 2731355    50  20210527     23   19900.0         1        2          1
# 2731356    50  20210721     23   33000.0         1        2          1
# 2731361    50  20211220     13   95700.0         3        0          1
# 2731367    50  20210808     12   93000.0         1        1          1
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_5060[kmeans_5060['cluster_s']==1].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성    104158
# 여성    628064
# Name: cust_y, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster_s']==1].groupby('cop_c_y')['cust_y'].count()
# Out:
# cop_c_y
# A01     95997
# A02    455457
# A03    154550
# A04     24650
# A05       397
# A06      1171
# Name: cust_y, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==1].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 기타남성의류세트    16616
# 여성티셔츠/탑      6520
# 임대매출         6271
# 일반스낵         5876
# 푸드코트한식       5742
#             ...
# 보드장비            1
# 일반기능미           1
# 기타고기            1
# 분유              1
# 힙색/사이드백         1
# Name: cust_y, Length: 1631, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==1].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 여성재킷         725317430.0
# 기타여성의류아우터    494888230.0
# 여성티셔츠/탑      491936170.0
# 기타여성의류세트     476872390.0
# 기타남성의류세트     435807830.0
#                 ...
# 싸인물/자석/압핀         2000.0
# 포장용품              1500.0
# 색종이               1500.0
# 모종/씨앗             1000.0
# 얼음/빙수용품           1000.0
# Name: buy_am, Length: 1631, dtype: float64

# %%
kmeans_5060[kmeans_5060['cluster_s']==2]
# Out:
#          ages     de_dt  de_hr     buy_am  buy_ct_x  cluster  cluster_s  \
# 1          50  20210321     15    87300.0         1        1          2
# 2          50  20210920     11   128600.0         1        1          2
# 10         50  20211003     13   129000.0         1        1          2
# 11         50  20211003     13   129000.0         1        1          2
# 12         50  20211003     13   129000.0         1        1          2
# ...       ...       ...    ...        ...       ...      ...        ...
# 2731328    50  20210606     12   179000.0         1        0          2
# 2731338    50  20210102     14    75900.0         1        0          2
# 2731342    50  20211212     17  4000000.0         1        4          2
# 2731363    50  20210117     16  3605000.0         1        4          2
# 2731368    50  20210320     12     7110.0         1        2          2
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_5060[kmeans_5060['cluster_s']==2].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성    385211
# 여성    212050
# Name: cust_y, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster_s']==2].groupby('cop_c_y')['cust_y'].count()
# Out:
# cop_c_y
# A01     68610
# A02    363698
# A03    111978
# A04     51343
# A05       733
# A06       899
# Name: cust_y, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==2].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 일반스낵           24789
# 두부류            20732
# 일반우유           19460
# 감자스낵           18970
# 바나나            17980
#                ...
# 기타자동차가전기기          1
# 스팀청소기              1
# 스텝퍼/트위스트           1
# 기타전자/비디오게임         1
# 사무용/학생용가구세트        1
# Name: cust_y, Length: 1676, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==2].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 수입산소갈비          192354040.0
# 백화점/마트모바일상품권    120188200.0
# 일반계란             96077455.0
# 일반우유             73257598.0
# 휴대폰              62719940.0
#                    ...
# 여아스커트                2700.0
# 영유아남방셔츠              2200.0
# 영유아패션트레이닝복            900.0
# 기타전자/비디오게임            100.0
# 타이어                   100.0
# Name: buy_am, Length: 1676, dtype: float64

# %%
kmeans_5060[kmeans_5060['cluster_s']==3]
# Out:
#          ages     de_dt  de_hr    buy_am  buy_ct_x  cluster  cluster_s  \
# 41         50  20210414     10  231000.0         1        2          3
# 555        50  20210123     14    3000.0         1        2          3
# 556        50  20210123     14    3000.0         1        2          3
# 557        50  20210123     14    3000.0         1        2          3
# 558        50  20210123     14    3000.0         1        2          3
# ...       ...       ...    ...       ...       ...      ...        ...
# 2731357    50  20210410     20   98000.0         1        2          3
# 2731359    60  20211207     11   13900.0         1        2          3
# 2731360    50  20210513     17   12700.0         1        2          3
# 2731364    50  20210119     21  124000.0         1        2          3
# 2731365    50  20210324     22   49500.0         1        2          3
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_5060[kmeans_5060['cluster_s']==3].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성     51047
# 여성    139275
# Name: cust_y, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster_s']==3].groupby('cop_c_y')['cust_y'].count()
# Out:
# cop_c_y
# A01      4664
# A02    105295
# A03     56943
# A04      1361
# A05       624
# A06     21435
# Name: cust_y, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==3].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 남성시계          36
# 반지             9
# 여성토트백          7
# UHD            7
# 기타여성의류아우터      6
# 여성시계           5
# 기타보석류          4
# 기타패션잡화         4
# 여성기타모피의류       3
# 안마의자           3
# 팔찌             2
# 여성코트           2
# 여성가방액세서리       2
# 양문형냉장고         2
# 스탠드형김치냉장고      2
# 수입소고기선물세트      2
# 소파             2
# 바디케어세트         2
# 목걸이            2
# 남성정장세트         2
# 기타TV           2
# 한우선물세트         2
# 골프채            1
# 멀티형에어컨         1
# 냉장/냉동가전소모품     1
# 골프패션잡화         1
# 침대             1
# Name: cust_y, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==3].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 남성시계          611763300.0
# 반지            134345900.0
# 여성토트백          86900000.0
# 기타패션잡화         72940000.0
# UHD            72033000.0
# 기타보석류          66100000.0
# 기타여성의류아우터      66087000.0
# 여성시계           64900000.0
# 목걸이            40000000.0
# 여성기타모피의류       31690000.0
# 안마의자           30576000.0
# 팔찌             28772000.0
# 남성정장세트         26320000.0
# 여성코트           24000000.0
# 양문형냉장고         23528000.0
# 스탠드형김치냉장고      20705000.0
# 한우선물세트         20000000.0
# 소파             19968400.0
# 기타TV           18174000.0
# 바디케어세트         18000000.0
# 수입소고기선물세트      17980000.0
# 여성가방액세서리       17600000.0
# 냉장/냉동가전소모품     11620000.0
# 침대             11111120.0
# 멀티형에어컨         10000000.0
# 골프패션잡화         10000000.0
# 골프채             9640000.0
# Name: buy_am, dtype: float64

# %%
kmeans_5060[kmeans_5060['cluster_s']==4]
# Out:
#          ages     de_dt  de_hr     buy_am  buy_ct_x  cluster  cluster_s  \
# 46         60  20210731     13    69300.0         1        1          4
# 73         60  20210123     18   179000.0         1        1          4
# 124        60  20211006     17    41300.0         1        1          4
# 125        60  20211014     17    45000.0         1        1          4
# 126        60  20211014     17    41300.0         1        1          4
# ...       ...       ...    ...        ...       ...      ...        ...
# 2731326    60  20210421     17  1440000.0         1        2          4
# 2731337    60  20210319     18    59900.0         1        0          4
# 2731362    60  20210912     12   600000.0         1        1          4
# 2731366    60  20210516     17  1650000.0         1        4          4
# 2731369    60  20210430     10   139000.0         1        2          4
#
#              cust_y ma_fem_dv_y zon_hlv_y      rct_no_y  chnl_dv_y cop_c_y  \
# ...

# %%
kmeans_5060[kmeans_5060['cluster_s']==4].groupby('ma_fem_dv_y')['cust_y'].count()
# Out:
# ma_fem_dv_y
# 남성    103917
# 여성    315183
# Name: cust_y, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster_s']==4].groupby('cop_c_y')['cust_y'].count()
# Out:
# cop_c_y
# A01     73229
# A02    242120
# A03     93936
# A04      9104
# A05       538
# A06       173
# Name: cust_y, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==4].groupby('pd_nm_y')['cust_y'].count().sort_values(ascending=False)
# Out:
# pd_nm_y
# 여성토트백        100
# 침대            99
# 여성숄더백         95
# 여성재킷          90
# 양문형냉장고        86
#             ...
# 에멀젼/로션         1
# 선크림류           1
# 압력솥            1
# 그림/인테리어렌탈      1
# 성인침구속통/솜       1
# Name: cust_y, Length: 176, dtype: int64

# %%
kmeans_5060[kmeans_5060['cluster']==4].groupby('pd_nm_y')["buy_am"].sum().sort_values(ascending=False)
# Out:
# pd_nm_y
# 침대           351047100.0
# 여성토트백        302691000.0
# 양문형냉장고       283522100.0
# 여성숄더백        276115000.0
# UHD          264072000.0
#                 ...
# 에어워셔           1650000.0
# 남성서류가방         1631000.0
# 여성바지           1624000.0
# 성인침구속통/솜       1600000.0
# 기타남아의류아우터      1549000.0
# Name: buy_am, Length: 176, dtype: float64

# %%
encoder = LabelEncoder()
encoder.fit(cus_merge['clac_mcls_nm'])
labels =encoder.inverse_transform(cus_merge['clac_mcls_nm'])
print('인코딩 변화값: ', labels)

# %%
print('인코딩 클래스: ', encoder.classes_)

# %%
print('디코딩 원본 값: ', encoder.inverse_transform([0, 1, 4, 5, 3, 3, 2, 2]))

# %% [markdown]
# ### scaling

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import MinMaxScaler 
minmax_scaler = MinMaxScaler() 
scaled_df = pd.DataFrame(minmax_scaler.fit_transform(cus_merge), columns=cus_merge.columns)

# %%
kmeans.fit(scaled_df)
centers_s = kmeans.cluster_centers_ 
pred_s = kmeans.predict(scaled_df)

# %% [markdown]
# # K-Medians

# %%
import pylab as pl

from sklearn.base import BaseEstimator
from sklearn.utils import check_random_state
from sklearn.cluster import MiniBatchKMeans
from sklearn.cluster import KMeans as KMeansGood
from sklearn.metrics.pairwise import euclidean_distances, manhattan_distances

# %%
class KMeans(BaseEstimator):

    def __init__(self, k, max_iter=100, random_state=0, tol=1e-4):
        self.k = k
        self.max_iter = max_iter
        self.random_state = random_state
        self.tol = tol

    def _e_step(self, X):
        self.labels_ = euclidean_distances(X, self.cluster_centers_,
                                     squared=True).argmin(axis=1)

    def _average(self, X):
        return X.mean(axis=0)

    def _m_step(self, X):
        X_center = None
        for center_id in range(self.k):
            center_mask = self.labels_ == center_id
            if not np.any(center_mask):
                # The centroid of empty clusters is set to the center of
                # everything
                if X_center is None:
                    X_center = self._average(X)
                self.cluster_centers_[center_id] = X_center
            else:
                self.cluster_centers_[center_id] = \
                    self._average(X[center_mask])

    def fit(self, X, y=None):
        n_samples = X.shape[0]
        vdata = np.mean(np.var(X, 0))

        random_state = check_random_state(self.random_state)
        self.labels_ = random_state.permutation(n_samples)[:self.k]
        self.cluster_centers_ = X[self.labels_]

        for i in xrange(self.max_iter):
            centers_old = self.cluster_centers_.copy()

            self._e_step(X)
            self._m_step(X)

            if np.sum((centers_old - self.cluster_centers_) ** 2) < self.tol * vdata:
                break

        return self

# %%
class KMedians(KMeans):

    def _e_step(self, X):
        self.labels_ = manhattan_distances(X, self.cluster_centers_).argmin(axis=1)

    def _average(self, X):
        return np.median(X, axis=0)

# %%
kmedians = KMedians(k=3, random_state=1234)
kmedians.fit(cus_merge)

# %%
kmeans = KMeans(n_clusters=3, random_state=1234)
kmeans.fit(cus_merge)
centers_s = kmedians.cluster_centers_ 
pred_s = kmedians.predict(cus_merge)

# %%
cus_merge.loc[[3695927, 3507452, 2648125],:]

# %%
cus_merge_drop = cus_merge.drop([3695927, 3507452, 2648125,3695920, 768479, 2648121],axis=0)
