# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from matplotlib import rc

rc('font', family='NanumGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Password:
# sudo: a password is required
# Password:
# sudo: a password is required
# rm: /Users/yeonji/.cache/matplotlib: No such file or directory
# rm: -rf: No such file or directory

# %%
demo_df = pd.read_csv("LPOINT_BIG_COMP_01_DEMO.csv")
pdde_df = pd.read_csv("LPOINT_BIG_COMP_02_PDDE.csv")
cop_df = pd.read_csv("LPOINT_BIG_COMP_03_COP_U.csv")
pd_df = pd.read_csv("LPOINT_BIG_COMP_04_PD_CLAC.csv")
br_df = pd.read_csv("LPOINT_BIG_COMP_05_BR.csv")
lpay_df = pd.read_csv("LPOINT_BIG_COMP_06_LPAY.csv")
# Out:
# /var/folders/z_/ns3pdgbs27x7bmf6wgkkg19r0000gn/T/ipykernel_5249/4235936177.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   pdde_df = pd.read_csv("LPOINT_BIG_COMP_02_PDDE.csv")

# %%
cus_join = pd.merge(demo_df,pdde_df, on="cust", how='inner')
cus_join
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 0        M000034966        여성  40대     Z07  A01016688590        1   A01
# 1        M000034966        여성  40대     Z07  A01016688590        1   A01
# 2        M000034966        여성  40대     Z07  A01016688590        1   A01
# 3        M000034966        여성  40대     Z07  A01016718167        1   A01
# 4        M000034966        여성  40대     Z07  A02357398521        1   A02
# ...             ...       ...  ...     ...           ...      ...   ...
# 4381738  M999962961        여성  50대     Z17  A05001012161        1   A05
# 4381739  M999962961        여성  50대     Z17  E06002810292        2   A06
# 4381740  M999962961        여성  50대     Z17  E06004609359        2   A06
# 4381741  M999962961        여성  50대     Z17  E06025413888        2   A06
# 4381742  M999962961        여성  50대     Z17  E06035713248        2   A06
#
#             br_c    pd_c     de_dt  de_hr    buy_am  buy_ct
# ...

# %%
cus_merge = pd.merge(cus_join,pd_df, on ='pd_c', how='inner' )
cus_merge
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 0        M000034966        여성  40대     Z07  A01016688590        1   A01
# 1        M000034966        여성  40대     Z07  A01016688590        1   A01
# 2        M000136117        여성  30대     Z11  A01294575336        1   A01
# 3        M000261625        여성  40대     Z17  A01117216600        1   A01
# 4        M000419293        여성  40대     Z17  A02041463489        1   A02
# ...             ...       ...  ...     ...           ...      ...   ...
# 4381738  M858719851        여성  60대     Z16  A05001516873        1   A05
# 4381739  M880029153        남성  40대     Z16  E06043468594        2   A06
# 4381740  M986268092        남성  40대     Z09  E06040602652        2   A06
# 4381741  M926014276        남성  40대     Z10  A02105319111        1   A02
# 4381742  M962869931        여성  20대     Z16  E06011348557        2   A06
#
#             br_c    pd_c     de_dt  de_hr    buy_am  buy_ct       pd_nm  \
# ...

# %%
cus_merge = pd.merge(cus_join,pd_df, on ='pd_c', how='inner' )
cus_merge
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 0        M000034966        여성  40대     Z07  A01016688590        1   A01
# 1        M000034966        여성  40대     Z07  A01016688590        1   A01
# 2        M000136117        여성  30대     Z11  A01294575336        1   A01
# 3        M000261625        여성  40대     Z17  A01117216600        1   A01
# 4        M000419293        여성  40대     Z17  A02041463489        1   A02
# ...             ...       ...  ...     ...           ...      ...   ...
# 4381738  M858719851        여성  60대     Z16  A05001516873        1   A05
# 4381739  M880029153        남성  40대     Z16  E06043468594        2   A06
# 4381740  M986268092        남성  40대     Z09  E06040602652        2   A06
# 4381741  M926014276        남성  40대     Z10  A02105319111        1   A02
# 4381742  M962869931        여성  20대     Z16  E06011348557        2   A06
#
#             br_c    pd_c     de_dt  de_hr    buy_am  buy_ct       pd_nm  \
# ...

# %%
index1 = cus_merge.loc[(cus_merge['clac_hlv_nm'] == '냉장식품') | (cus_merge['clac_hlv_nm'] == '유제품') | (cus_merge['clac_hlv_nm'] == '테넌트/음식점'), : ].index
cus_merge.drop(index1, axis=0, inplace = True)

# %%
index2 = cus_merge.loc[(cus_merge['clac_hlv_nm'] == '건해산물') & ((cus_merge['pd_nm'] != '김선물세트') | (cus_merge['pd_nm'] != '멸치선물세트') | (cus_merge['pd_nm'] != '굴비선물세트') | (cus_merge['pd_nm'] != '기타건해산물선물세트')) , : ].index
index3 = cus_merge.loc[(cus_merge['clac_hlv_nm'] == '채소') & ((cus_merge['pd_nm'] != '혼합채소선물세트') | (cus_merge['pd_nm'] != '버섯선물세트') | (cus_merge['pd_nm'] != '기타한방약재') | (cus_merge['pd_nm'] != '수삼선물세트') | (cus_merge['pd_nm'] != '약용버섯류') | (cus_merge['pd_nm'] != '인삼류')) , : ].index
index4 = cus_merge.loc[(cus_merge['clac_hlv_nm'] == '조미료') & ((cus_merge['pd_nm'] != '조미료세트') | (cus_merge['pd_nm'] != '조미혼합세트') | (cus_merge['pd_nm'] != '식용유세트')) , : ].index
index5 = cus_merge.loc[(cus_merge['clac_hlv_nm'] == '양곡') & (cus_merge['pd_nm'] != '곡물선물세트') , : ].index
index6 = cus_merge.loc[(cus_merge['clac_hlv_nm'] == '병통조림') & ((cus_merge['pd_nm'] != '통조림혼합세트') | (cus_merge['pd_nm'] != '참치통조림세트') ) , : ].index
index7 = cus_merge.loc[(cus_merge['clac_hlv_nm'] == '조리식품') & ((cus_merge['pd_nm'] != '케이크') | (cus_merge['pd_nm'] != '롤') | (cus_merge['pd_nm'] != '선물류') | (cus_merge['pd_nm'] != '일반떡') | (cus_merge['pd_nm'] != '치킨류') | (cus_merge['pd_nm'] != '도넛')| (cus_merge['pd_nm'] != '피자')) , : ].index
index8 = cus_merge.loc[(cus_merge['clac_hlv_nm'] == '수산물') & ((cus_merge['pd_nm'] != '생선선물세트') | (cus_merge['pd_nm'] != '해물선물세트') | (cus_merge['pd_nm'] != '혼합수산선물세트') ) , : ].index

# %%
cus_merge.drop(index2, axis=0, inplace=True)
cus_merge.drop(index3, axis=0, inplace=True)
cus_merge.drop(index4, axis=0, inplace=True)
cus_merge.drop(index5, axis=0, inplace=True)
cus_merge.drop(index6, axis=0, inplace=True)
cus_merge.drop(index7, axis=0, inplace=True)
cus_merge.drop(index8, axis=0, inplace=True)

# %%
cus_304050 = cus_merge.loc[((cus_merge['ages'] == '30대') | (cus_merge['ages'] == '40대')| (cus_merge['ages'] == '50대')) & ((cus_merge['cop_c'] == 'A01') |  (cus_merge['cop_c'] == 'A06')) , : ]
cus_304050
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 0        M000034966        여성  40대     Z07  A01016688590        1   A01
# 1        M000034966        여성  40대     Z07  A01016688590        1   A01
# 2        M000136117        여성  30대     Z11  A01294575336        1   A01
# 3        M000261625        여성  40대     Z17  A01117216600        1   A01
# 6        M000508243        여성  50대     Z17  A01417352264        1   A01
# ...             ...       ...  ...     ...           ...      ...   ...
# 4381733  M762888764        여성  30대     Z11  E06033428238        2   A06
# 4381735  M897387507        남성  40대     Z07  E06015295559        2   A06
# 4381736  M802756595        남성  40대     Z17  E06006556124        2   A06
# 4381739  M880029153        남성  40대     Z16  E06043468594        2   A06
# 4381740  M986268092        남성  40대     Z09  E06040602652        2   A06
#
#             br_c    pd_c     de_dt  de_hr    buy_am  buy_ct       pd_nm  \
# ...

# %%
from datetime import datetime, date
cus_304050['de_dt'] = pd.to_datetime(cus_304050['de_dt'],format='%Y%m%d')
# Out:
# /var/folders/z_/ns3pdgbs27x7bmf6wgkkg19r0000gn/T/ipykernel_1177/16302932.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cus_304050['de_dt'] = pd.to_datetime(cus_304050['de_dt'],format='%Y%m%d')

# %%
cus_304050['de_dt']
# Out:
# 0         2021-01-16
# 1         2021-01-16
# 2         2021-08-05
# 3         2021-04-03
# 6         2021-10-31
#              ...
# 4381733   2021-04-28
# 4381735   2021-03-07
# 4381736   2021-01-31
# 4381739   2021-07-12
# 4381740   2021-05-23
# Name: de_dt, Length: 479262, dtype: datetime64[ns]

# %%
cus_304050[cus_304050['de_dt'].dt.dayofweek == 5]
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 0        M000034966        여성  40대     Z07  A01016688590        1   A01
# 1        M000034966        여성  40대     Z07  A01016688590        1   A01
# 3        M000261625        여성  40대     Z17  A01117216600        1   A01
# 9        M000557840        남성  30대     Z11  A01078954018        1   A01
# 11       M001694463        남성  40대     Z14  A01139531032        1   A01
# ...             ...       ...  ...     ...           ...      ...   ...
# 4381721  M740326708        여성  40대     Z17  A01171190884        1   A01
# 4381722  M740326708        여성  40대     Z17  A01171192292        1   A01
# 4381723  M740326708        여성  40대     Z17  A01171195251        1   A01
# 4381724  M740326708        여성  40대     Z17  A01171199385        1   A01
# 4381726  M747738564        남성  40대     Z11  A01341536210        1   A01
#
#             br_c    pd_c      de_dt  de_hr    buy_am  buy_ct       pd_nm  \
# ...

# %% [markdown]
# ## 직장동료

# %%
a = cus_304050.loc[((cus_304050['chnl_dv'] == 1) &( (cus_304050['de_hr'] >= 9) & (cus_304050['de_hr'] <= 12)) | ((cus_304050['de_hr'] >= 13) & (cus_304050['de_hr'] <= 18))) \
                   &((cus_304050['de_dt'].dt.dayofweek != 5) | (cus_304050['de_dt'].dt.dayofweek != 6)|(cus_304050['de_dt'] != '2021-01-01')|(cus_304050['de_dt'] != '2021-02-11')|(cus_304050['de_dt'] != '2021-02-12') \
                   |(cus_304050['de_dt'] != '2021-03-01')|(cus_304050['de_dt'] != '2021-05-05')|(cus_304050['de_dt'] != '2021-05-19')|(cus_304050['de_dt'] != '2021-09-20')|(cus_304050['de_dt'] != '2021-09-21')|(cus_304050['de_dt'] != '2021-09-22')), :]
a = cus_304050.groupby(['de_dt','cust']).agg({'buy_ct': 'count'})
b = []
for i in range(len(a)):
    if a['buy_ct'][i] > 20: # 연차 수
           b.append(a.index[i])

# %%
a
# Out:
#                        buy_ct
# de_dt      cust
# 2021-01-01 M023350361       3
#            M029031283       3
#            M030477840       3
#            M031090387       1
#            M032724385       1
# ...                       ...
# 2021-12-31 M991819890       6
#            M992159582       5
#            M992460429       2
#            M999180761       1
#            M999227380       1
#
# [209291 rows x 1 columns]

# %%
b
# Out:
# [(Timestamp('2021-01-04 00:00:00'), 'M770295038'),
#  (Timestamp('2021-01-06 00:00:00'), 'M934079434'),
#  (Timestamp('2021-01-09 00:00:00'), 'M020145678'),
#  (Timestamp('2021-01-13 00:00:00'), 'M308751833'),
#  (Timestamp('2021-01-14 00:00:00'), 'M721646184'),
#  (Timestamp('2021-01-18 00:00:00'), 'M145994881'),
#  (Timestamp('2021-01-23 00:00:00'), 'M393430073'),
#  (Timestamp('2021-01-25 00:00:00'), 'M951454133'),
#  (Timestamp('2021-01-27 00:00:00'), 'M072055624'),
#  (Timestamp('2021-01-31 00:00:00'), 'M332788295'),
#  (Timestamp('2021-01-31 00:00:00'), 'M832140011'),
#  (Timestamp('2021-02-01 00:00:00'), 'M175885324'),
#  (Timestamp('2021-02-08 00:00:00'), 'M124503444'),
#  (Timestamp('2021-02-08 00:00:00'), 'M169084943'),
#  (Timestamp('2021-02-11 00:00:00'), 'M231537676'),
#  (Timestamp('2021-02-14 00:00:00'), 'M098691956'),
#  (Timestamp('2021-02-14 00:00:00'), 'M218238453'),
#  (Timestamp('2021-02-20 00:00:00'), 'M498697163'),
# ...

# %%
worker = cus_304050[~cus_304050['cust'].isin(b)]
worker
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 0        M000034966        여성  40대     Z07  A01016688590        1   A01
# 1        M000034966        여성  40대     Z07  A01016688590        1   A01
# 7        M000555652        남성  50대     Z10  A01100339077        1   A01
# 8        M000555652        남성  50대     Z10  A01355760494        1   A01
# 9        M000557840        남성  30대     Z11  A01078954018        1   A01
# ...             ...       ...  ...     ...           ...      ...   ...
# 4381730  M949264778        여성  50대     Z12  A01298342312        1   A01
# 4381732  M970932333        여성  30대     Z04  E06046994706        2   A06
# 4381733  M762888764        여성  30대     Z11  E06033428238        2   A06
# 4381735  M897387507        남성  40대     Z07  E06015295559        2   A06
# 4381736  M802756595        남성  40대     Z17  E06006556124        2   A06
#
#             br_c    pd_c      de_dt  de_hr    buy_am  buy_ct       pd_nm  \
# ...

# %%
len(worker['cust'].unique())
# Out:
# 10399

# %%
10399/len(cus_merge['cust'].unique())
# Out:
# 0.3893881524750992

# %%
for i in worker['clac_hlv_nm'].unique():
   print(worker[worker['clac_hlv_nm'] == i ].groupby('pd_nm')['buy_am'].sum().sort_values(ascending = False).head(10))
   print('-'*10)
# Out:
# pd_nm
# 남성런닝/트레이닝화     184921710.0
# 남성트레이닝복        139339210.0
# 남성스포츠티셔츠        83897670.0
# 여성런닝/트레이닝화      53628920.0
# 남성골프티셔츠         52579950.0
# 남성등산티셔츠         52176850.0
# 남성등산/아웃도어세트     43970620.0
# 남성등산점퍼/재킷       36753390.0
# 남성일반스포츠바지       29397580.0
# 여성골프티셔츠/탑       28192110.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 기타여성속옷    17370800.0
# 유아동내의      9066280.0
# 브래지어       9046250.0
# 여성속옷세트     7273910.0
# 남성팬티       3924610.0
# 남성일반양말     3096600.0
# 홈웨어세트      1331240.0
# 스타킹        1277730.0
# 여성팬티       1267690.0
# 여아실내복      1161300.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 여성티셔츠/탑      181810810.0
# 기타여성의류세트     144253590.0
# 기타여성의류아우터    121132630.0
# 여성재킷         114614930.0
# 여성원피스         77419150.0
# 여성코트          73148250.0
# 여성블라우스        62829680.0
# 여성패딩          52544960.0
# 여성정장세트        36268800.0
# 여성점퍼          29133760.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 냉동만두       2436270.0
# 기타냉동간편식    1413570.0
# ...

# %%
for i in worker['clac_hlv_nm'].unique():
   print(worker[worker['clac_hlv_nm'] == i ].groupby('pd_nm')['buy_ct'].count().sort_values(ascending = False).head(10))
   print('-'*10)
# Out:
# pd_nm
# 남성런닝/트레이닝화     2155
# 남성트레이닝복        1659
# 남성스포츠티셔츠        953
# 여성런닝/트레이닝화      695
# 남성등산티셔츠         452
# 남성등산/아웃도어세트     385
# 남성일반스포츠바지       375
# 여성트레이닝복         355
# 남성등산점퍼/재킷       311
# 남성골프티셔츠         265
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 기타여성속옷    264
# 유아동내의     225
# 브래지어      167
# 여성속옷세트    162
# 남성일반양말     93
# 남성팬티       78
# 스타킹        65
# 여성팬티       58
# 여성일반양말     47
# 홈웨어세트      38
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 여성티셔츠/탑      2509
# 기타여성의류세트     1060
# 기타여성의류아우터    1049
# 여성재킷          606
# 여성원피스         597
# 여성블라우스        557
# 여성정장세트        452
# 여성바지          376
# 여성코트          248
# 여성청바지         235
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 냉동만두       180
# 기타냉동간편식    148
# 콘아이스크림     125
# 냉동떡볶이       70
# 컵아이스크림      64
# 냉동디저트       61
# 바아이스크림      59
# 냉동피자        21
# 홈아이스크림      20
# 냉동핫도그       19
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 커피음료       851
# 과일음료       307
# ...

# %%
keywords = cus_304050['pd_nm'].unique()
matching = [x for x in keywords if "정장" in x] 
print(matching)
# Out:
# ['남성정장셔츠', '남성정장화', '여성정장세트', '남성정장세트', '남성정장재킷', '남성정장바지']

# %%
display(worker.loc[(worker['pd_nm'] == '남성정장셔츠') | (worker['pd_nm'] == '남성정장화') | (worker['pd_nm'] == '여성정장세트')| (worker['pd_nm'] == '남성정장세트')| (worker['pd_nm'] == '남성정장재킷')| (worker['pd_nm'] == '남성정장바지'),:])
cust_woker = worker.loc[(worker['pd_nm'] == '남성정장셔츠') | (worker['pd_nm'] == '남성정장화') | (worker['pd_nm'] == '여성정장세트')| (worker['pd_nm'] == '남성정장세트')| (worker['pd_nm'] == '남성정장재킷')| (worker['pd_nm'] == '남성정장바지'),:]['cust'].unique()
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 1942028  M005978086        남성  40대     Z17  A01012495480        1   A01
# 1942029  M006201429        여성  40대     Z10  A01373701734        1   A01
# 1942032  M007207067        남성  50대     Z12  A01415625133        1   A01
# 1942042  M009092500        여성  40대     Z09  A01187452498        1   A01
# 1942076  M020155133        여성  30대     Z17  A01116536389        1   A01
# ...             ...       ...  ...     ...           ...      ...   ...
# 4086585  M810526566        여성  30대     Z04  A01108189327        1   A01
# 4086589  M836287742        여성  30대     Z10  A01338066070        1   A01
# 4086590  M836287742        여성  30대     Z10  A01338066070        1   A01
# 4086592  M841223816        여성  40대     Z13  A01098632375        1   A01
# 4086607  M940071882        여성  30대     Z14  E06010487717        2   A06
#
#             br_c    pd_c      de_dt  de_hr    buy_am  buy_ct   pd_nm  \
# ...

# %%
len(cust_woker)
# Out:
# 1091

# %%
cus_304050.loc[(cus_304050['pd_nm'] == '남성정장셔츠') | (cus_304050['pd_nm'] == '남성정장화') | (cus_304050['pd_nm'] == '여성정장세트')| (cus_304050['pd_nm'] == '남성정장세트')| (cus_304050['pd_nm'] == '남성정장재킷')| (cus_304050['pd_nm'] == '남성정장바지'),:]
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 1942019  M000494848        여성  30대     Z10  A01235377234        1   A01
# 1942020  M000494848        여성  30대     Z10  A01440839579        1   A01
# 1942021  M000508243        여성  50대     Z17  A01108120047        1   A01
# 1942024  M004839058        남성  40대     Z13  A01187020373        1   A01
# 1942025  M005392126        남성  40대     Z17  A01149014106        1   A01
# ...             ...       ...  ...     ...           ...      ...   ...
# 4086605  M923285900        여성  30대     Z17  A01396321610        1   A01
# 4086606  M938201564        여성  40대     Z11  A01253572117        1   A01
# 4086607  M940071882        여성  30대     Z14  E06010487717        2   A06
# 4086608  M965981972        여성  30대     Z04  A01394422904        1   A01
# 4086609  M971914997        여성  30대     Z04  A01319395738        1   A01
#
#             br_c    pd_c      de_dt  de_hr    buy_am  buy_ct   pd_nm  \
# ...

# %%
worker_suit = cus_304050[cus_304050['cust'].isin(cust_woker)]
worker_suit
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 95       M009092500        여성  40대     Z09  A01151450863        1   A01
# 96       M009092500        여성  40대     Z09  A01399111029        1   A01
# 156      M012312404        남성  30대     Z16  A01064160517        1   A01
# 219      M013700307        여성  40대     Z10  A01129047374        1   A01
# 276      M018155432        여성  30대     Z09  A01093428642        1   A01
# ...             ...       ...  ...     ...           ...      ...   ...
# 4380977  M380432397        남성  50대     Z17  A01027872022        1   A01
# 4381208  M348833958        여성  40대     Z10  A01074362154        1   A01
# 4381228  M417573867        남성  40대     Z10  E06039377529        2   A06
# 4381545  M617975621        남성  40대     Z04  E06033399445        2   A06
# 4381680  M783432409        여성  40대     Z16  A01103639922        1   A01
#
#             br_c    pd_c      de_dt  de_hr    buy_am  buy_ct       pd_nm  \
# ...

# %%
for i in worker_suit['clac_hlv_nm'].unique():
   print(worker_suit[worker_suit['clac_hlv_nm'] == i ].groupby('pd_nm')['buy_am'].sum().sort_values(ascending = False).head(10))
   print('-'*10)
# Out:
# pd_nm
# 남성런닝/트레이닝화     25730540.0
# 남성트레이닝복        22670240.0
# 여성골프티셔츠/탑       9977900.0
# 남성스포츠티셔츠        9240600.0
# 남성골프티셔츠         7950500.0
# 남성골프의류세트        7713900.0
# 여성런닝/트레이닝화      7644100.0
# 남성등산티셔츠         5684850.0
# 남성등산/아웃도어세트     5534850.0
# 남성등산점퍼/재킷       4730300.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 기타여성속옷    3732900.0
# 브래지어      1436600.0
# 여성속옷세트    1126310.0
# 유아동내의      824300.0
# 남성팬티       706700.0
# 여아실내복      434700.0
# 남성일반양말     253000.0
# 여성팬티       235400.0
# 스타킹        217600.0
# 유아동팬티      172400.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 여성정장세트       36268800.0
# 여성티셔츠/탑      31895590.0
# 기타여성의류세트     23268870.0
# 여성재킷         22337390.0
# 기타여성의류아우터    18896050.0
# 여성원피스        16096720.0
# 여성코트         14140650.0
# 여성패딩         12210500.0
# 여성블라우스        8608440.0
# 여성기타모피의류      5644000.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 냉동떡볶이      227630.0
# 냉동만두       165170.0
# 기타냉동간편식     91560.0
# ...

# %%
for i in worker_suit['clac_hlv_nm'].unique():
   print(worker_suit[worker_suit['clac_hlv_nm'] == i ].groupby('pd_nm')['buy_ct'].count().sort_values(ascending = False).head(10))
   print('-'*10)
# Out:
# pd_nm
# 남성런닝/트레이닝화     304
# 남성트레이닝복        276
# 남성스포츠티셔츠       111
# 여성런닝/트레이닝화      89
# 여성골프티셔츠/탑       54
# 남성골프티셔츠         53
# 여성트레이닝복         50
# 남성등산티셔츠         49
# 남성등산/아웃도어세트     45
# 남성골프의류세트        40
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 기타여성속옷    57
# 브래지어      25
# 여성속옷세트    21
# 유아동내의     20
# 남성일반양말    12
# 남성팬티      10
# 스타킹        9
# 여성일반양말     8
# 여성팬티       8
# 여아실내복      5
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 여성정장세트       452
# 여성티셔츠/탑      425
# 기타여성의류아우터    185
# 기타여성의류세트     180
# 여성재킷         121
# 여성블라우스       105
# 여성원피스         94
# 여성코트          70
# 여성바지          55
# 여성남방셔츠        33
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 냉동만두       16
# 냉동떡볶이      13
# 콘아이스크림     12
# 기타냉동간편식    11
# 컵아이스크림      8
# 바아이스크림      4
# 냉동피자        3
# 냉동핫도그       3
# 냉동디저트       2
# 냉동튀김        2
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 커피음료       98
# 과일음료       42
# 혼합탄산       22
# 생수         18
# 기타기능성음료    17
# ...

# %% [markdown]
# ## 클라이언트

# %%
cus_304050.sort_values(by ='buy_ct', ascending=False).head(60)
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 2079732  M282697479        여성  40대     Z04  A01064770920        1   A01
# 2079734  M282697479        여성  40대     Z04  A01135093413        1   A01
# 2079738  M282697479        여성  40대     Z04  A01217558938        1   A01
# 2079745  M282697479        여성  40대     Z04  A01368542746        1   A01
# 2079742  M282697479        여성  40대     Z04  A01311491571        1   A01
# 928244   M927998831        남성  30대     Z10  E06047735952        2   A06
# 1706990  M552638745        남성  40대     Z16  A01260219259        1   A01
# 744654   M035470647        남성  30대     Z16  A01377355004        1   A01
# 744657   M035470647        남성  30대     Z16  A01489959059        1   A01
# 744658   M035470647        남성  30대     Z16  A01500249773        1   A01
# 3531975  M203489906        여성  40대     Z10  A01039612397        1   A01
# 4259761  M347773641        여성  30대     Z10  E06050987546        2   A06
# ...

# %%
cus_304050 = cus_304050[~cus_304050['cust'].isin(['M103897322'])]
cus_304050
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 0        M000034966        여성  40대     Z07  A01016688590        1   A01
# 1        M000034966        여성  40대     Z07  A01016688590        1   A01
# 2        M000136117        여성  30대     Z11  A01294575336        1   A01
# 3        M000261625        여성  40대     Z17  A01117216600        1   A01
# 6        M000508243        여성  50대     Z17  A01417352264        1   A01
# ...             ...       ...  ...     ...           ...      ...   ...
# 4381733  M762888764        여성  30대     Z11  E06033428238        2   A06
# 4381735  M897387507        남성  40대     Z07  E06015295559        2   A06
# 4381736  M802756595        남성  40대     Z17  E06006556124        2   A06
# 4381739  M880029153        남성  40대     Z16  E06043468594        2   A06
# 4381740  M986268092        남성  40대     Z09  E06040602652        2   A06
#
#             br_c    pd_c      de_dt  de_hr    buy_am  buy_ct       pd_nm  \
# ...

# %%
cus_304050[cus_304050['buy_ct']>30]['pd_nm'].unique()
# Out:
# array(['과일음료', '핸드로션/크림', '크림/밤/오일', '기타패션잡화', '남성티셔츠', '스킨/토너', '칫솔',
#        '생수', '크래커', '과채혼합음료', '판초콜릿', '스킨케어세트', '건강보조식품세트', '홍삼근', '와인세트',
#        '기타레토르트', '기타영양제', '커피음료', '냉동튀김', '건강마스크', '생활잡화균일가', '남성용스킨케어류',
#        '임대매출', '비디오게임소프트웨어', '티백/드립원두커피', '치약', '기타주방정리용품/소모품', '고양이간식',
#        '일반비타민', '이유식', '여성헤어액세서리', '필기도구소모품', '장갑류', '남성점퍼', '기능성캔디',
#        '안전상비의약품', '기타양주', '수입산소갈비', '책상정리용품', '팔찌', '남성슬리퍼', '수예도구',
#        '기타정리용품', '포장용품', '웨이트용품', '견출지/분류스티커'], dtype=object)

# %%
cus_55 = cus_304050[cus_304050['buy_ct']>55]
c = cus_55.loc[(cus_55['pd_nm'] == '남성런닝/트레이닝화')|(cus_55['pd_nm'] == '스포츠음료')|(cus_55['pd_nm'] == '과일음료')|(cus_55['pd_nm'] == '스킨케어세트')\
          |(cus_55['pd_nm'] == '홍삼근')|(cus_55['pd_nm'] == '여성티셔츠/탑')|(cus_55['pd_nm'] == '기타영양제')|(cus_55['pd_nm'] == '선물류')\
          |(cus_55['pd_nm'] == '커피음료')|(cus_55['pd_nm'] == '남성정장세트')|(cus_55['pd_nm'] == '믹스커피')|(cus_55['pd_nm'] == '기타여성화')\
          |(cus_55['pd_nm'] == '남성용스킨케어류')|(cus_55['pd_nm'] == '스툴/리빙의자')|(cus_55['pd_nm'] == '티백/드립원두커피')|(cus_55['pd_nm'] == '목걸이')\
          |(cus_55['pd_nm'] == '남성점퍼')|(cus_55['pd_nm'] == '햄통조림세트')|(cus_55['pd_nm'] == '수입소고기선물세트')|(cus_55['pd_nm'] == '남성양말선물세트')|(cus_55['pd_nm'] == '핸드워시/손세정제')\
          |(cus_55['pd_nm'] == '기타양주')|(cus_55['pd_nm'] == '통조림혼합세트')|(cus_55['pd_nm'] == '수입산소갈비')|(cus_55['pd_nm'] == '헤어케어선물세트')|(cus_55['pd_nm'] == '식용유세트'),:]['cust'].unique()

# %%
client = cus_304050[cus_304050['cust'].isin(c)]
client
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 2322     M203489906        여성  40대     Z10  A01207690970        1   A01
# 4913     M428731067        여성  30대     Z17  A01130136889        1   A01
# 4914     M428731067        여성  30대     Z17  A01130136889        1   A01
# 4915     M428731067        여성  30대     Z17  A01130136889        1   A01
# 4916     M428731067        여성  30대     Z17  A01130136889        1   A01
# ...             ...       ...  ...     ...           ...      ...   ...
# 4363838  M428731067        여성  30대     Z17  A01277482242        1   A01
# 4373685  M970615483        여성  30대     Z10  E06037503336        2   A06
# 4377767  M428731067        여성  30대     Z17  A01239112260        1   A01
# 4379988  M428731067        여성  30대     Z17  A01044002023        1   A01
# 4380546  M203489906        여성  40대     Z10  A01308847411        1   A01
#
#             br_c    pd_c      de_dt  de_hr    buy_am  buy_ct       pd_nm  \
# ...

# %%
for i in client['clac_hlv_nm'].unique():
   print(client[client['clac_hlv_nm'] == i ].groupby('pd_nm')['buy_am'].sum().sort_values(ascending = False).head(10))
   print('-'*10)
# Out:
# pd_nm
# 여성골프티셔츠/탑     11553400.0
# 남성런닝/트레이닝화     7432500.0
# 남성트레이닝복        2320800.0
# 남성골프티셔츠        1214000.0
# 여성골프바지          836000.0
# 남성스포츠티셔츠        709620.0
# 여성스포츠티셔츠/탑      705600.0
# 여성런닝/트레이닝화      448000.0
# 남성일반스포츠바지       440600.0
# 여성등산티셔츠/탑       417900.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 기타여성속옷      1710000.0
# 유아동내의       1324500.0
# 남성양말선물세트     799400.0
# 남성일반양말       400500.0
# 여성속옷세트       326440.0
# 여아잠옷         170000.0
# 스타킹           59200.0
# 남아실내복         54600.0
# 브래지어          45900.0
# 남성팬티          34800.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 여성티셔츠/탑      17399900.0
# 여성재킷         16229300.0
# 기타여성의류세트      8606590.0
# 여성블라우스        6843600.0
# 기타여성의류아우터     3419720.0
# 여성기타모피의류      2600000.0
# 여성원피스         1324120.0
# 여성패딩          1110000.0
# 여성트렌치코트        992000.0
# 여성코트           953200.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 냉동만두       581320.0
# 냉동튀김       278090.0
# 냉동디저트      216830.0
# ...

# %%
for i in client['clac_hlv_nm'].unique():
   print(client[client['clac_hlv_nm'] == i ].groupby('pd_nm')['buy_ct'].count().sort_values(ascending = False).head(10))
   print('-'*10)
# Out:
# pd_nm
# 남성런닝/트레이닝화          82
# 여성골프티셔츠/탑           41
# 남성트레이닝복             21
# 남성스포츠티셔츠            16
# 여성스포츠티셔츠/탑          14
# 여성런닝/트레이닝화           6
# 남성일반스포츠바지            4
# 남성스포츠스웨트셔츠/후드/집업     3
# 유아동런닝/트레이닝화          3
# 여성골프의류세트             3
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 유아동내의         21
# 기타여성속옷        12
# 여성캐쥬얼스포츠양말     9
# 남아실내복          5
# 기타유아동양말류       5
# 남성일반양말         5
# 브래지어           3
# 스타킹            3
# 남성팬티           3
# 남성캐쥬얼스포츠양말     3
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 여성티셔츠/탑      203
# 기타여성의류세트      32
# 여성블라우스        26
# 여성재킷          23
# 기타여성의류아우터     20
# 여성원피스          9
# 여성바지           6
# 여성스커트          5
# 여성정장세트         4
# 여성청바지          4
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 냉동만두       64
# 냉동튀김       33
# 바아이스크림     30
# 냉동디저트      25
# 기타냉동간편식    16
# 냉동떡볶이      13
# 냉동핫도그      13
# 냉동간편식세트    12
# 냉동피자       11
# 콘아이스크림      9
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# ...

# %%
for i in client['clac_hlv_nm'].unique():
   print(client[client['clac_hlv_nm'] == i ].groupby('pd_nm')['buy_ct'].sum().sort_values(ascending = False).head(10))
   print('-'*10)
# Out:
# pd_nm
# 남성런닝/트레이닝화          431
# 여성골프티셔츠/탑            41
# 여성스포츠티셔츠/탑           24
# 남성트레이닝복              21
# 남성스포츠티셔츠             16
# 여성런닝/트레이닝화            6
# 남성일반스포츠바지             5
# 스포츠두건/머플러/마스크         4
# 남성스포츠스웨트셔츠/후드/집업      3
# 유아동런닝/트레이닝화           3
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 남성양말선물세트      86
# 유아동내의         22
# 남성일반양말        20
# 기타여성속옷        14
# 브래지어          14
# 여성캐쥬얼스포츠양말    10
# 스타킹            7
# 여아잠옷           6
# 남아실내복          5
# 기타유아동양말류       5
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 여성티셔츠/탑      2036
# 여성블라우스         43
# 기타여성의류세트       33
# 여성재킷           23
# 기타여성의류아우터      20
# 여성바지           13
# 여성원피스           9
# 여성스커트           8
# 여성정장세트          4
# 여성청바지           4
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 냉동만두       68
# 냉동튀김       40
# 바아이스크림     36
# 냉동디저트      31
# 얼음         19
# 기타냉동간편식    19
# 냉동떡볶이      15
# 콘아이스크림     15
# 냉동간편식세트    14
# 냉동피자       14
# Name: buy_ct, dtype: int64
# ...

# %% [markdown]
# ## 은퇴하신분

# %%
re = cus_merge.loc[((cus_merge['ages'] == '70대') | (cus_merge['ages'] == '60대') ), :]
re
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 94       M009092385        여성  70대     Z11  A01467587862        1   A01
# 104      M009731870        여성  70대     Z17  A01000621072        1   A01
# 105      M009731870        여성  70대     Z17  A01000621072        1   A01
# 111      M010288392        여성  70대     Z10  A01455616801        1   A01
# 123      M011495510        남성  60대     Z03  A01287722938        1   A01
# ...             ...       ...  ...     ...           ...      ...   ...
# 4381568  M739187332        여성  60대     Z10  A02135272347        1   A02
# 4381684  M891879680        여성  60대     Z10  E06051292977        2   A06
# 4381714  M629301187        여성  60대     Z11  A01342755401        1   A01
# 4381729  M754959773        남성  60대     Z15  A01183130343        1   A01
# 4381738  M858719851        여성  60대     Z16  A05001516873        1   A05
#
#             br_c    pd_c     de_dt  de_hr     buy_am  buy_ct       pd_nm  \
# ...

# %%
len(re['cust'].unique()) / len(cus_merge['cust'].unique())
# Out:
# 0.10080131805586759

# %%
for i in re['clac_hlv_nm'].unique():
   print(re[re['clac_hlv_nm'] == i ].groupby('pd_nm')['buy_am'].sum().sort_values(ascending = False).head(10))
   print('-'*10)
# Out:
# pd_nm
# 여성골프티셔츠/탑     7739420.0
# 남성런닝/트레이닝화    7402240.0
# 남성골프점퍼/재킷     6870200.0
# 여성골프의류세트      5440600.0
# 남성트레이닝복       4820560.0
# 남성골프티셔츠       4585800.0
# 여성스포츠티셔츠/탑    3334900.0
# 여성골프점퍼/재킷     3040800.0
# 남성스포츠티셔츠      2584200.0
# 여성런닝/트레이닝화    2549100.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 기타여성속옷        7094100.0
# 여성속옷세트        2160200.0
# 브래지어          1958100.0
# 유아동내의         1369500.0
# 스타킹           1142690.0
# 남성일반양말        1078100.0
# 여성내의           684300.0
# 여성팬티           586700.0
# 홈웨어세트          535800.0
# 남성캐쥬얼스포츠양말     379900.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 여성재킷         133234780.0
# 기타여성의류세트      75628410.0
# 기타여성의류아우터     48716110.0
# 여성원피스         47906510.0
# 여성기타모피의류      37281600.0
# 여성코트          23737900.0
# 여성티셔츠/탑       19964420.0
# 여성블라우스        19260800.0
# 여성바지           8741590.0
# 여성스웨터/풀오버      5677400.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 냉동만두       3741800.0
# 기타냉동간편식    1231250.0
# ...

# %%
re['clac_hlv_nm'].unique()
# 스포츠패션, 주류, 완구, 헬스/피트니스, 구기/필드스포츠, 시즌스포츠, 여행/레저서비스, 상품권, 서적/음반/악기
# Out:
# array(['스포츠패션', '속옷/양말/홈웨어', '여성의류', '냉동식품', '음료', '청소/세탁/욕실용품', '주류',
#        '과자', '과일', '대용식', '원예/애완', '완구', '패션잡화', '퍼스널케어', '침구/수예',
#        '식기/조리기구', '모바일', '아웃도어/레저', '화장품/뷰티케어', '남성의류', '헬스/피트니스',
#        '문구/사무용품', '생활/주방가전', '유아동의류', '세제/위생', '주방잡화', '생활/렌탈서비스',
#        '기타(비상품)', '축산물', '유아식품', '건강식품', '구기/필드스포츠', '가구', '시즌스포츠',
#        '건강용품', '냉장/세탁가전', '커피/차', '인테리어/조명', '담배', '계절가전', '자동차용품',
#        '공구/안전용품', '영상/음향가전', '출산/육아용품', '컴퓨터', '여행/레저서비스', '상품권',
#        '서적/음반/악기'], dtype=object)

# %%
print(re[re['clac_hlv_nm'] == '스포츠패션' ].groupby('pd_nm')['buy_am'].sum().sort_values(ascending = False).head(10))
print('-'*10)
print(re[re['clac_hlv_nm'] == '주류' ].groupby('pd_nm')['buy_am'].sum().sort_values(ascending = False).head(10))
print('-'*10)
print(re[re['clac_hlv_nm'] == '완구' ].groupby('pd_nm')['buy_am'].sum().sort_values(ascending = False).head(10))
print('-'*10)
print(re[re['clac_hlv_nm'] == '헬스/피트니스' ].groupby('pd_nm')['buy_am'].sum().sort_values(ascending = False).head(10))
print('-'*10)
print(re[re['clac_hlv_nm'] == '구기/필드스포츠' ].groupby('pd_nm')['buy_am'].sum().sort_values(ascending = False).head(10))
print('-'*10)
print(re[re['clac_hlv_nm'] == '여행/레저서비스' ].groupby('pd_nm')['buy_am'].sum().sort_values(ascending = False).head(10))
print('-'*10)
print(re[re['clac_hlv_nm'] == '상품권' ].groupby('pd_nm')['buy_am'].sum().sort_values(ascending = False).head(10))
print('-'*10)
print(re[re['clac_hlv_nm'] == '서적/음반/악기' ].groupby('pd_nm')['buy_am'].sum().sort_values(ascending = False).head(10))
print('-'*10)
print(re[re['clac_hlv_nm'] == '시즌스포츠' ].groupby('pd_nm')['buy_am'].sum().sort_values(ascending = False).head(10))
# Out:
# pd_nm
# 여성골프티셔츠/탑     7739420.0
# 남성런닝/트레이닝화    7402240.0
# 남성골프점퍼/재킷     6870200.0
# 여성골프의류세트      5440600.0
# 남성트레이닝복       4820560.0
# 남성골프티셔츠       4585800.0
# 여성스포츠티셔츠/탑    3334900.0
# 여성골프점퍼/재킷     3040800.0
# 남성스포츠티셔츠      2584200.0
# 여성런닝/트레이닝화    2549100.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 레드와인     5482960.0
# 수입맥주     3441450.0
# 일반소주     3440110.0
# 국산맥주     2665510.0
# 막걸리      1599850.0
# 와인세트     1328100.0
# 기타양주     1122800.0
# 기타전통주    1053810.0
# 화이트와인     475520.0
# 청주        312220.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 비디오게임기        2195000.0
# 롤플레잉완구         734900.0
# 피규어            684200.0
# 패션인형           357100.0
# 비디오게임소프트웨어     349000.0
# 무선조종           247500.0
# 미니자동차          239200.0
# 레고             219300.0
# 콜렉션인형          179700.0
# 조립/프라모델        164400.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 요가/필라테스복       1532100.0
# 스포츠댄스의류/용품     1373800.0
# 피트니스용품          220100.0
# ...

# %%
print(re[re['clac_hlv_nm'] == '스포츠패션' ].groupby('pd_nm')['buy_ct'].count().sort_values(ascending = False).head(10))
print('-'*10)
print(re[re['clac_hlv_nm'] == '주류' ].groupby('pd_nm')['buy_ct'].count().sort_values(ascending = False).head(10))
print('-'*10)
print(re[re['clac_hlv_nm'] == '완구' ].groupby('pd_nm')['buy_ct'].count().sort_values(ascending = False).head(10))
print('-'*10)
print(re[re['clac_hlv_nm'] == '헬스/피트니스' ].groupby('pd_nm')['buy_ct'].count().sort_values(ascending = False).head(10))
print('-'*10)
print(re[re['clac_hlv_nm'] == '구기/필드스포츠' ].groupby('pd_nm')['buy_ct'].count().sort_values(ascending = False).head(10))
print('-'*10)
print(re[re['clac_hlv_nm'] == '여행/레저서비스' ].groupby('pd_nm')['buy_ct'].count().sort_values(ascending = False).head(10))
print('-'*10)
print(re[re['clac_hlv_nm'] == '상품권' ].groupby('pd_nm')['buy_ct'].count().sort_values(ascending = False).head(10))
print('-'*10)
print(re[re['clac_hlv_nm'] == '서적/음반/악기' ].groupby('pd_nm')['buy_ct'].count().sort_values(ascending = False).head(10))
print('-'*10)
print(re[re['clac_hlv_nm'] == '시즌스포츠' ].groupby('pd_nm')['buy_ct'].count().sort_values(ascending = False).head(10))
# Out:
# pd_nm
# 남성런닝/트레이닝화    92
# 여성스포츠티셔츠/탑    73
# 남성트레이닝복       58
# 여성골프티셔츠/탑     45
# 여성골프의류세트      39
# 남성스포츠티셔츠      30
# 여성런닝/트레이닝화    28
# 남성등산점퍼/재킷     25
# 남성골프점퍼/재킷     24
# 남성골프티셔츠       21
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 일반소주     701
# 막걸리      611
# 국산맥주     342
# 수입맥주     280
# 레드와인     202
# 청주        66
# 기타전통주     57
# 화이트와인     35
# 일본술       23
# 담금소주      19
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 미니자동차      26
# 피규어        20
# 롤플레잉완구     19
# 실외놀이완구     15
# 패션인형       12
# 조립/프라모델     7
# 레고          7
# 역할놀이        7
# 무선조종        6
# 비디오게임기      6
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 요가/필라테스복       32
# 스포츠댄스의류/용품     18
# 피트니스용품          3
# 기타요가/필라테스소품     1
# 요가/스포츠매트        1
# 웨이트기구           1
# 웨이트소품           1
# 웨이트용품           1
# 헬스바이크           1
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 기타구기/필드스포츠용품    22
# 골프패션잡화          18
# 골프필드용품          16
# 골프화              3
# 골프장갑             2
# ...

# %% [markdown]
# ## 공부하시는 분

# %%
s = ['M334081804', 'M057015266', 'M034346877', 'M924718355', 'M593577051',  'M627503091',  'M127381687', 'M124397382', 'M124357021', 'M756183973', 'M010037014','M796358488','M218092364', 'M662773006'	, 'M152809914', 'M786525396', 'M170771685', 'M666874425', 'M114180204','M584752498','M791919187','M087637262','M293279212','M571747420','M971700298','M096620499','M343601809', 'M089064605','M939559728','M862052801','M616775931','M472170714']

# %%
student = cus_merge[cus_merge['cust'].isin(s)]
student
# Out:
#                cust ma_fem_dv ages zon_hlv        rct_no  chnl_dv cop_c  \
# 1137     M087637262        남성  40대     Z08  A01333224514        1   A01
# 10592    M939559728        여성  20대     Z10  A01476962580        1   A01
# 10840    M971700298        남성  40대     Z07  A01006218399        1   A01
# 11374    M034346877        남성  30대     Z04  A01242757314        1   A01
# 11751    M127381687        여성  50대     Z10  A01484197175        1   A01
# ...             ...       ...  ...     ...           ...      ...   ...
# 4378762  M057015266        남성  40대     Z10  A04059385217        1   A04
# 4378778  M924718355        남성  20대     Z17  A04035486980        1   A04
# 4379104  M796358488        남성  30대     Z17  A04039958901        1   A04
# 4379111  M924718355        남성  20대     Z17  A04062546967        1   A04
# 4381656  M472170714        여성  20대     Z12  A04101210096        1   A04
#
#             br_c    pd_c     de_dt  de_hr    buy_am  buy_ct       pd_nm  \
# ...

# %%
for i in student['clac_hlv_nm'].unique():
   print(student[student['clac_hlv_nm'] == i ].groupby('pd_nm')['buy_am'].sum().sort_values(ascending = False).head(10))
   print('-'*10)
# Out:
# pd_nm
# 남성런닝/트레이닝화    764780.0
# 남성트레이닝복       364100.0
# 남성등산점퍼/재킷     310500.0
# 여성등산점퍼/재킷     216200.0
# 여성런닝/트레이닝화    158000.0
# 남성스포츠티셔츠       33000.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 브래지어      260600.0
# 스타킹        73912.0
# 여성팬티       43900.0
# 남성일반양말     24274.0
# 여성일반양말      8048.0
# 여성덧신류       5900.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 여성청바지     464400.0
# 여성점퍼      230200.0
# 여성베스트     128900.0
# 여성재킷       49000.0
# 여성정장세트     29000.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 바아이스크림     950757.0
# 콘아이스크림     668222.0
# 컵아이스크림     500926.0
# 튜브아이스크림    371466.0
# 얼음         321673.0
# 냉동만두       293301.0
# 홈아이스크림     262555.0
# 기타냉동간편식    242052.0
# 모나카        204164.0
# 냉동튀김       138641.0
# Name: buy_am, dtype: float64
# ----------
# pd_nm
# 콜라           2039245.0
# 커피음료         1604288.0
# 스포츠음료        1579574.0
# 비타민/에너지음료    1457535.0
# 생수           1332371.0
# 혼합탄산         1201348.0
# 사이다           881890.0
# ...

# %%
for i in student['clac_hlv_nm'].unique():
   print(student[student['clac_hlv_nm'] == i ].groupby('pd_nm')['buy_ct'].count().sort_values(ascending = False).head(10))
   print('-'*10)
# Out:
# pd_nm
# 남성트레이닝복       4
# 남성런닝/트레이닝화    3
# 여성등산점퍼/재킷     2
# 여성런닝/트레이닝화    2
# 남성등산점퍼/재킷     1
# 남성스포츠티셔츠      1
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 스타킹       7
# 여성팬티      6
# 남성일반양말    5
# 브래지어      4
# 여성일반양말    3
# 여성덧신류     1
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 여성청바지     4
# 여성베스트     3
# 여성재킷      1
# 여성점퍼      1
# 여성정장세트    1
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 바아이스크림     345
# 얼음         289
# 콘아이스크림     168
# 튜브아이스크림    123
# 컵아이스크림     111
# 모나카         59
# 냉동만두        51
# 홈아이스크림      31
# 기타냉동간편식     27
# 냉동튀김        19
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 콜라           641
# 스포츠음료        576
# 커피음료         548
# 혼합탄산         502
# 생수           502
# 비타민/에너지음료    462
# 파우치/즉석음료     347
# 과일음료         332
# 사이다          281
# 일반차음료        267
# Name: buy_ct, dtype: int64
# ----------
# pd_nm
# 종량제봉투     48
# 걸레/청소포     7
# 테이프크리너     6
# 수건         4
# 수도용품       3
# 기타청소용품     2
# 기타정리용품     1
# 목욕타올       1
# ...
